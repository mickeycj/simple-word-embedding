# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from gensim.utils import simple_preprocess
import nltk
from nltk.stem.wordnet import WordNetLemmatizer

english_words = set(nltk.corpus.words.words())
english_stop_words = nltk.corpus.stopwords.words("english")

lemmatizer = WordNetLemmatizer()

def preprocess(text):
    return " ".join(lemmatizer.lemmatize(w) for w in nltk.wordpunct_tokenize(text)
        if w.lower() in english_words and w.lower() not in english_stop_words or not w.isalpha())

def tokenize(document):
    return simple_preprocess(str(document).encode("utf-8"))

# %%
import pandas as pd

dname = './data/preprocessed-twitter-tweets'

pos = pd.read_csv('{}/{}.csv'.format(dname, 'processedPositive')).T
neu = pd.read_csv('{}/{}.csv'.format(dname, 'processedNeutral')).T
neg = pd.read_csv('{}/{}.csv'.format(dname, 'processedNegative')).T

documents = pd.concat([pos, neu, neg])
documents['tweets'] = documents.index
documents = documents.sample(frac=1).reset_index(drop=True)

documents.head(15)
# Out:
#                                                tweets
# 0    it looks like iOS 11 is due to kill it unhappy
# 1                      What results mean for others.
# 2                                       it is versus
# 3                  physicist still has his table full
# 4   convoy attacked on Parimpora-Panthachowk bypas...
# 5    rocks. next question - where is my astro unha...
# 6                                     How Modi won UP
# 7                 keeps key unchanged-- repo at 6.25%
# 8                               i miss minmin crying
# 9   Thanks for the retweets this week. Much apprec...
# 10                          follow mee plss unhappy
# 11  Calcutta's suddenly cannot have enough of moth...
# 12       please reading this breaks my heart unhappy
# 13  Hello I am getting cyber bullied by do somethi...
# 14   both look so so good at there current clubs. ...

# %%
training_docs = []
num_docs = float(len(documents.index))
for _, row in documents.iterrows():
    training_docs.append(tokenize(preprocess(row['tweets'])))

training_docs
# Out:
# [['like', 'due', 'kill', 'unhappy'],
#  ['mean'],
#  ['versus'],
#  ['physicist', 'still', 'table', 'full'],
#  ['convoy', 'bypass', 'police'],
#  ['next', 'question', 'unhappy'],
#  [],
#  ['key', 'unchanged'],
#  ['miss', 'cry'],
#  ['thanks', 'week', 'much', 'happy', 'want'],
#  ['follow', 'unhappy'],
#  ['suddenly', 'cannot', 'enough', 'mother'],
#  ['please', 'reading', 'heart', 'unhappy'],
#  ['hello', 'getting', 'something', 'unhappy'],
#  ['look', 'good', 'current', 'shame', 'never', 'cut', 'unhappy'],
#  ['work', 'much', 'better', 'unhappy'],
#  ['today', 'congress', 'address'],
#  ['please', 'beautiful', 'princess', 'help'],
#  ['awesome', 'id', 'love', 'see', 'like'],
#  ['happy', 'belated', 'birthday', 'another', 'duet', 'much'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['tell', 'unhappy'],
#  ['tried', 'everything'],
#  ['give', 'trial', 'run'],
#  [],
#  ['table', 'today'],
#  [],
#  ['last', 'night', 'dream', 'japan', 'see', 'request', 'unhappy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['miss', 'dog', 'unhappy'],
#  ['people', 'want'],
#  ['early', 'deal'],
#  ['put',
#   'trial',
#   'criminal',
#   'defamation',
#   'case',
#   'union',
#   'minister',
#   'matter'],
#  ['captain', 'singh'],
#  ['virulent', 'going', 'culture', 'census'],
#  ['also'],
#  ['versus', 'undercurrent'],
#  ['extension', 'privacy'],
#  ['today', 'unhappy', 'least', 'sale', 'pitching'],
#  ['sorry',
#   'tired',
#   'stream',
#   'get',
#   'sleep',
#   'try',
#   'fun',
#   'tomorrow',
#   'feeling',
#   'tonight'],
#  [],
#  [],
#  ['take', 'care', 'friend', 'happy'],
#  ['hold', 'promise', 'battle'],
#  ['ne', 'reunite', 'unhappy'],
#  ['lit', 'unhappy'],
#  ['thanks', 'top', 'new', 'great', 'week', 'happy'],
#  ['cant', 'piss', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['getting', 'harder', 'harder', 'stay', 'unhappy'],
#  ['twitter', 'premium', 'version', 'free', 'service'],
#  ['student', 'stir', 'intensify', 'strike', 'today'],
#  ['several', 'injured', 'storm', 'polling', 'low', 'turnout', 'till'],
#  ['floor', 'test'],
#  ['keep'],
#  ['amazing', 'stuff', 'happy', 'birth', 'control', 'gamma', 'ray'],
#  ['happy', 'brighten', 'day', 'happy'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['camera', 'shooting'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['got', 'rest'],
#  ['raj', 'calling', 'party', 'form', 'government'],
#  ['longer', 'even', 'want', 'unhappy'],
#  [],
#  ['alpha', 'invitation', 'well', 'received', 'happy'],
#  ['part'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['really', 'amount', 'unhappy', 'ride', 'meet', 'darby', 'end'],
#  ['happy'],
#  ['another', 'camp'],
#  ['dont', 'laugh', 'unhappy', 'base'],
#  ['live', 'ruckus', 'assembly', 'secret', 'ballot', 'demand'],
#  ['keep'],
#  ['also'],
#  ['day', 'read', 'said', 'hoax'],
#  ['bronchitis', 'love', 'happy'],
#  ['time'],
#  ['fitness'],
#  ['swear', 'past'],
#  ['zac', 'back', 'way', 'sad', 'unhappy'],
#  ['never', 'happy'],
#  [],
#  ['unhappy'],
#  ['probe', 'yet', 'video', 'army'],
#  ['happy'],
#  [],
#  [],
#  [],
#  ['graft', 'case'],
#  ['also'],
#  ['former', 'minister', 'ka', 'presidium', 'chairman'],
#  ['helicopter'],
#  ['day',
#   'since',
#   'promotion',
#   'ended',
#   'already',
#   'missing',
#   'much',
#   'unhappy'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['come', 'sad'],
#  ['switch', 'side'],
#  ['say', 'hi', 'sunshine', 'unhappy'],
#  ['high', 'commissioner'],
#  ['thanks',
#   'much',
#   'following',
#   'love',
#   'know',
#   'think',
#   'flooring',
#   'range',
#   'happy'],
#  ['hate', 'throwing', 'unhappy'],
#  ['painful', 'thing', 'ever', 'someone', 'unhappy'],
#  ['help'],
#  ['instant'],
#  ['hard', 'give', 'experience', 'pleasurable', 'pain'],
#  ['connection', 'men', 'polling', 'day', 'police'],
#  ['suspected', 'selling', 'us'],
#  ['know', 'time', 'waiting', 'long', 'time', 'unhappy'],
#  ['attached'],
#  ['oh', 'god', 'attend', 'together', 'sometime'],
#  ['year', 'old', 'new', 'ladylike', 'trust', 'troll'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['rock', 'clue', 'earth'],
#  ['friendly', 'fire', 'tour', 'unhappy'],
#  ['official'],
#  ['please', 'return', 'jacket', 'unhappy'],
#  ['contribution', 'posted', 'ago', 'cry', 'joy'],
#  ['awesome', 'recommendation', 'jess'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['golly',
#   'gosh',
#   'simply',
#   'dreadful',
#   'havoc',
#   'must',
#   'subsurface',
#   'black',
#   'salve'],
#  ['love',
#   'people',
#   'message',
#   'long',
#   'beautiful',
#   'find',
#   'like',
#   'unhappy',
#   'yes',
#   'agree',
#   'keep',
#   'going'],
#  ['opposing'],
#  ['happy'],
#  ['cost',
#   'abut',
#   'year',
#   'paying',
#   'half',
#   'full',
#   'education',
#   'get',
#   'treat'],
#  ['hi', 'cham'],
#  [],
#  ['shoehorn', 'plot', 'character', 'support'],
#  ['blind'],
#  ['nick', 'might', 'deliver', 'time', 'story', 'life'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['usually', 'speedboat', 'behind', 'get', 'river', 'unhappy'],
#  ['family'],
#  ['thanks', 'brother'],
#  ['half', 'time', 'unhappy'],
#  ['hate', 'cry', 'joy'],
#  ['iconoclasm', 'exponent', 'moving', 'beyond', 'artificial'],
#  ['confusion'],
#  ['need', 'learn', 'start', 'people', 'keep', 'chatting', 'unhappy'],
#  ['ill', 'fitting'],
#  ['room'],
#  ['feel',
#   'like',
#   'telling',
#   'get',
#   'social',
#   'medium',
#   'also',
#   'feel',
#   'really',
#   'mean',
#   'unhappy',
#   'silence',
#   'love',
#   'hope'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['miss', 'sad'],
#  ['finance', 'minister'],
#  ['growth', 'core', 'sector', 'slows', 'year', 'ago', 'month'],
#  ['let', 'alone', 'free'],
#  ['man', 'phone', 'made', 'like', 'always', 'wink'],
#  ['oh', 'yes', 'happy'],
#  ['worry'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['like', 'per', 'piece', 'unhappy'],
#  ['someone', 'worst', 'deserve', 'best'],
#  ['change', 'whole', 'life', 'happy'],
#  ['question', 'make', 'sure', 'use', 'happy'],
#  ['think', 'finally', 'figured', 'tattoo', 'getting', 'august'],
#  ['oh', 'unhappy', 'like', 'still'],
#  ['wish', 'could', 'say', 'picture', 'unhappy', 'high'],
#  ['moral', 'outrage', 'cannot', 'guide', 'get', 'messy'],
#  ['face', 'bloated', 'unhappy', 'baby', 'get', 'well', 'soon'],
#  ['visual', 'studio', 'installation', 'come', 'suddenly', 'unhappy'],
#  ['upsetting', 'abuse', 'get', 'unhappy'],
#  ['wait', 'actually', 'see', 'copy', 'smile'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['polling',
#   'underway',
#   'assembly',
#   'spread',
#   'across',
#   'seventh',
#   'final',
#   'phase'],
#  [],
#  ['really', 'need', 'build', 'unhappy'],
#  ['stress'],
#  [],
#  ['sworn', 'chief', 'minister'],
#  ['supreme', 'court', 'justice', 'explain', 'face'],
#  ['entry'],
#  ['want', 'victory', 'rally'],
#  ['long', 'time', 'chat', 'sad'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['day', 'sell', 'truck'],
#  ['warm'],
#  ['double', 'digit', 'sluggish', 'growth', 'high', 'growth', 'war'],
#  ['happy', 'bear'],
#  ['train', 'blast', 'case'],
#  ['great', 'day', 'today', 'happy'],
#  ['parent', 'friendly', 'like', 'please'],
#  ['since', 'stopped', 'snapping', 'made', 'massive', 'difference', 'get'],
#  ['make', 'built', 'westward', 'ho', 'estate', 'read'],
#  [],
#  ['tale', 'prime'],
#  ['understand', 'silly', 'like', 'make', 'smile', 'happy'],
#  ['dude'],
#  ['match', 'referee', 'went', 'book'],
#  ['hold', 'used', 'new', 'application', 'made', 'team', 'happy'],
#  ['feel', 'awful', 'today', 'unhappy', 'want', 'go', 'internship'],
#  ['thanks', 'happy'],
#  ['picture'],
#  ['miss', 'unhappy'],
#  ['also', 'making'],
#  ['decided', 'merge'],
#  ['yeah', 'update'],
#  ['hard', 'see', 'best', 'friend', 'another', 'girl', 'happy'],
#  ['half', 'brother', 'leader', 'kim', 'un'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['miss', 'unhappy'],
#  ['th', 'tweet', 'like', 'say', 'love'],
#  ['baby',
#   'unhappy',
#   'broke',
#   'mail',
#   'read',
#   'letter',
#   'thank',
#   'enough',
#   'best'],
#  [],
#  ['cloaked', 'debate'],
#  ['actually',
#   'looking',
#   'forward',
#   'seeing',
#   'theory',
#   'around',
#   'personal',
#   'vote',
#   'correct',
#   'unhappy'],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want'],
#  ['question', 'mark', 'video'],
#  ['pushing'],
#  ['stopped', 'got', 'rid', 'toy', 'bottom', 'unhappy'],
#  ['unofficial', 'ban'],
#  ['happening', 'get', 'game', 'different'],
#  ['found', 'home', 'doctor'],
#  ['gen', 'governor'],
#  ['fat', 'ass', 'girl', 'fat', 'fetish', 'hot'],
#  ['right', 'seriously', 'need', 'decent', 'butterfly', 'tattoo', 'design'],
#  ['thank'],
#  ['love', 'much', 'smile', 'smile'],
#  ['world', 'big', 'big', 'take', 'world', 'much', 'smile', 'happy'],
#  ['jealous', 'unhappy', 'please', 'go', 'see', 'green', 'room', 'sat'],
#  ['protein', 'venom', 'may', 'help', 'recover', 'faster'],
#  ['stupid'],
#  ['thumbnail', 'best', 'render', 'ever', 'dand'],
#  ['fear', 'law', 'may', 'force', 'private', 'shun', 'critical'],
#  ['rate'],
#  ['super', 'unhappy'],
#  [],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['ride', 'final', 'unhappy'],
#  ['hate', 'park', 'much', 'sad'],
#  ['day', 'ahead', 'confidence', 'vote'],
#  ['private', 'put', 'expansion', 'hold'],
#  ['core', 'slow'],
#  ['serious', 'regarding', 'captain', 'shoulder', 'injury'],
#  [],
#  ['case', 'contract', 'soup'],
#  ['constable',
#   'service',
#   'court',
#   'inquiry',
#   'bad',
#   'quality',
#   'food',
#   'base'],
#  ['old', 'twitter', 'unhappy'],
#  ['education', 'throw'],
#  ['thank', 'happy'],
#  ['unnamed'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['going', 'notice', 'unhappy'],
#  ['mad', 'cute', 'unhappy'],
#  ['new', 'second', 'home', 'coming', 'soon'],
#  ['met'],
#  ['yes', 'life'],
#  ['tired', 'nothing', 'great', 'unhappy'],
#  ['unhappy', 'unhappy', 'hope', 'sooner'],
#  ['brit'],
#  ['autograph', 'book', 'ready'],
#  ['pure', 'evil', 'people', 'unhappy'],
#  ['thats', 'grim', 'unhappy'],
#  ['demit', 'game', 'real', 'cry', 'joy'],
#  ['cute', 'unhappy'],
#  ['unhappy', 'struggle', 'valid'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['theory', 'population'],
#  ['would', 'great', 'trick', 'happy'],
#  ['put', 'ruling', 'combine', 'request'],
#  ['miss', 'bedroom', 'unhappy'],
#  [],
#  ['thank',
#   'much',
#   'willow',
#   'ring',
#   'birthday',
#   'amazing',
#   'stream',
#   'last',
#   'night'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['bill', 'pervert'],
#  ['team', 'come', 'minimal', 'side', 'effect'],
#  ['contact'],
#  ['perfect', 'dress'],
#  ['murder', 'activist', 'clause', 'law'],
#  ['make', 'mark', 'us', 'meet'],
#  ['indignation', 'remains', 'well', 'fed'],
#  ['spending',
#   'night',
#   'talking',
#   'beloved',
#   'perfect',
#   'love',
#   'man',
#   'happy'],
#  ['due', 'sudden', 'drop', 'visibility'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'want', 'free'],
#  ['bad', 'watch', 'unhappy', 'cake', 'cute', 'delicious'],
#  ['formidable', 'madame', 'business'],
#  ['law', 'change'],
#  ['presumably', 'support', 'list'],
#  ['unhappy'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['look', 'good', 'blue', 'happy'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['next', 'week', 'unhappy', 'wish', 'luck'],
#  ['company',
#   'fabulous',
#   'photographer',
#   'happy',
#   'look',
#   'determination',
#   'concrete',
#   'get'],
#  ['within', 'budget'],
#  ['thanks', 'happy'],
#  ['happy'],
#  ['link', 'seventeen', 'concert'],
#  ['happy'],
#  ['us', 'scare'],
#  ['get', 'dog'],
#  ['also'],
#  ['pork', 'happy'],
#  ['support'],
#  ['want', 'kiss', 'nose', 'tell', 'love', 'sad'],
#  ['yet', 'say', 'word', 'whether'],
#  ['miss', 'baby', 'unhappy'],
#  ['visa'],
#  ['sprout'],
#  ['thanks', 'notice'],
#  ['also'],
#  ['negative', 'pit', 'unhappiness'],
#  ['someone', 'issue', 'unhappy'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['right', 'see', 'people', 'like'],
#  ['unhappy'],
#  ['sign', 'barlow', 'yet', 'sad'],
#  ['win', 'draw', 'free', 'celebrate'],
#  ['dying', 'thirst', 'unhappy'],
#  ['need', 'different', 'pinned', 'tweet', 'unhappy'],
#  ['oh', 'baby', 'unhappy'],
#  ['grab', 'crew'],
#  ['returned', 'warm', 'welcome'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['premier', 'death'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['always', 'love', 'happy'],
#  ['miss', 'unhappy'],
#  ['passenger', 'chute', 'aircraft', 'airport', 'injured'],
#  ['visiting', 'prime', 'minister'],
#  ['would', 'great', 'trick', 'happy'],
#  [],
#  ['injured'],
#  ['person', 'chose', 'shut', 'unhappy'],
#  ['likely'],
#  ['least', 'cad', 'like', 'unhappy', 'cad'],
#  ['zoo', 'mark'],
#  ['type', 'ask', 'anything', 'like', 'happy', 'aa'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['ask', 'get', 'spend'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['bank', 'offer', 'rs'],
#  ['sept', 'terror', 'attack'],
#  ['bonding', 'happiness', 'family'],
#  ['happy'],
#  ['second', 'best', 'always', 'happy'],
#  ['elsewhere', 'imposition', 'plan'],
#  ['dysfunction', 'among'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  [],
#  ['body', 'upgrade', 'pitch', 'test'],
#  ['base', 'unhappy'],
#  [],
#  ['job', 'searching', 'got', 'none', 'got', 'abundance'],
#  ['reverse', 'special', 'link'],
#  ['agitation', 'day', 'trouble', 'soon', 'come'],
#  ['retard', 'sad'],
#  [],
#  ['menu'],
#  ['female', 'take', 'guarding', 'acid', 'attack', 'victim', 'hospital'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['wage', 'hike'],
#  ['miss', 'unhappy'],
#  ['sixth', 'spot', 'applicable', 'team', 'higher', 'pa'],
#  ['sense', 'belonging', 'among'],
#  ['veteran', 'see', 'breach'],
#  ['favorite', 'hobby', 'finding', 'negative', 'positive', 'thing', 'happy'],
#  ['please', 'stop', 'confining', 'unhappy'],
#  ['day'],
#  ['body', 'decided', 'boycott', 'function'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['stay', 'go', 'nobody', 'happy'],
#  ['good', 'morning', 'hope', 'slept', 'well', 'happy'],
#  ['wow',
#   'made',
#   'compressor',
#   'actually',
#   'turns',
#   'happy',
#   'may',
#   'useful',
#   'happy'],
#  ['crackdown'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['oh', 'sadly', 'wont', 'watch', 'right', 'forbid', 'see', 'unhappy'],
#  ['tell', 'idea'],
#  [],
#  ['happy', 'see', 'closer', 'con', 'five'],
#  ['hey', 'tony'],
#  ['please', 'talk', 'instant', 'message', 'lonely', 'need', 'cry'],
#  ['help', 'unhappy', 'early', 'birthday', 'gift'],
#  ['operator', 'acquire', 'business', 'seven', 'spectrum'],
#  ['happy', 'everyone', 'happy'],
#  ['sorry', 'one', 'bad', 'egg', 'embarrass', 'rest', 'unhappy'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['want', 'adult', 'today', 'birthday', 'unhappy'],
#  ['anyone', 'need', 'vent', 'unhappy'],
#  [],
#  ['resume', 'work', 'system', 'river'],
#  ['days', 'ram'],
#  ['want', 'follow', 'back', 'tweet', 'happy'],
#  ['see', 'hope'],
#  ['hello', 'everyone'],
#  ['army', 'fire', 'tactic'],
#  ['unhappy', 'come', 'people', 'like', 'state', 'intervention'],
#  ['opposition'],
#  ['know', 'ready', 'say', 'unhappy'],
#  ['slipped', 'budget'],
#  [],
#  ['player', 'player', 'rank', 'would', 'show', 'happy'],
#  ['worked',
#   'beautifully',
#   'redesign',
#   'import',
#   'page',
#   'suit',
#   'whole',
#   'application',
#   'would'],
#  [],
#  ['hey', 'stay', 'always', 'matter'],
#  ['thanks', 'week'],
#  ['school'],
#  ['know', 'problem', 'still', 'exist'],
#  ['mass'],
#  ['went', 'work', 'get', 'excited'],
#  ['let', 'know', 'like', 'one', 'happy'],
#  ['couple', 'unhappy'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['unhappy', 'emotion'],
#  [],
#  ['also'],
#  ['go', 'past'],
#  ['happy', 'million', 'keep', 'happy', 'million', 'close', 'another'],
#  ['hope', 'everything', 'go', 'right', 'unhappy'],
#  ['return', 'lake', 'next', 'winter'],
#  [],
#  ['rts', 'giveaway', 'origin', 'account', 'randomly', 'people'],
#  ['medical', 'body', 'handling', 'successful'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['lans', 'happy'],
#  ['historian', 'ram'],
#  ['maybe', 'definitely', 'happy', 'also'],
#  ['never', 'draw', 'unhappy'],
#  ['plan'],
#  ['minister'],
#  ['tap'],
#  ['also'],
#  ['get', 'latest', 'throughout', 'day'],
#  ['streaming',
#   'later',
#   'day',
#   'night',
#   'stream',
#   'since',
#   'go',
#   'take',
#   'care',
#   'contract'],
#  ['take', 'encounter'],
#  ['unhappy'],
#  ['please', 'turn', 'like', 'unhappy'],
#  ['unhappy'],
#  ['bin', 'mental'],
#  ['limit'],
#  ['violence'],
#  ['former',
#   'president',
#   'unqualified',
#   'unconditional',
#   'apology',
#   'supreme',
#   'court'],
#  ['pressure', 'ban'],
#  ['joy', 'get', 'back'],
#  ['still', 'strict'],
#  ['miss', 'busy', 'unhappy'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['favorite', 'unhappy'],
#  ['would', 'well', 'abolish'],
#  ['heartland', 'lab'],
#  ['seeing', 'past', 'present'],
#  ['say', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['would', 'sustained', 'fame', 'unhappy'],
#  ['new', 'show', 'buffalo', 'ask', 'opener', 'happy'],
#  ['made', 'new', 'really', 'fun', 'work', 'follow', 'want', 'keep'],
#  [],
#  [],
#  ['post', 'show', 'blue', 'hard', 'unhappy'],
#  ['supreme',
#   'court',
#   'chance',
#   'oppose',
#   'judge',
#   'appointment',
#   'national',
#   'security'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  [],
#  ['supreme', 'court', 'ruling', 'race'],
#  ['tutorial',
#   'distinguishing',
#   'information',
#   'knowledge',
#   'start',
#   'pm',
#   'happy'],
#  ['civic', 'poll', 'counting', 'begin', 'today', 'result'],
#  [],
#  ['want', 'choke', 'unhappy'],
#  ['put', 'password', 'wi', 'fi'],
#  ['development', 'filling', 'also', 'death'],
#  ['guess', 'getting', 'unicorn', 'sold', 'unhappy'],
#  ['day', 'left', 'arm'],
#  ['crept'],
#  ['project', 'test'],
#  ['think', 'one', 'part', 'body'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['supreme', 'court', 'chicken'],
#  ['also'],
#  [],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want'],
#  ['note', 'crunch', 'glass'],
#  ['dhow', 'al'],
#  ['heart', 'sad', 'hate', 'people'],
#  ['personnel', 'paramilitary'],
#  ['private', 'follow', 'flying', 'ban'],
#  ['erupt'],
#  ['havent', 'early', 'school', 'since', 'last', 'semester', 'unhappy'],
#  ['hear', 'various', 'constitutional', 'legitimacy', 'today'],
#  ['give', 'like', 'happy', 'choice'],
#  ['could', 'gain', 'partnership'],
#  ['governor', 'form', 'government'],
#  ['news'],
#  ['way', 'change', 'classification', 'bypass', 'order'],
#  ['enjoy', 'happy'],
#  ['leader', 'shot', 'dead', 'late', 'last', 'night'],
#  ['memorial'],
#  ['turned', 'back', 'day', 'get', 'dual', 'stream', 'setup', 'sorted'],
#  [],
#  ['ray'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want', 'free'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['still', 'bedroom', 'going', 'happy'],
#  ['new', 'video', 'game', 'super', 'happy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['skull', 'protest'],
#  ['would', 'great', 'trick', 'happy'],
#  ['see'],
#  ['little', 'video', 'made', 'love', 'life'],
#  ['miss', 'boy', 'sick', 'unhappy'],
#  ['unsold', 'stock'],
#  ['removal', 'scare'],
#  ['lead', 'greatness'],
#  ['know', 'unhappy'],
#  ['nephew', 'proxy'],
#  ['got', 'longer', 'unhappy'],
#  ['tweet', 'want', 'included', 'scrapbook', 'making', 'something'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['thanks',
#   'recent',
#   'follow',
#   'happy',
#   'connect',
#   'happy',
#   'great',
#   'want',
#   'free'],
#  ['merge', 'bank', 'greater', 'outreach'],
#  ['nope', 'unhappy'],
#  ['relief', 'small'],
#  ['cried', 'racism'],
#  ['tested', 'sweet', 'sweet'],
#  ['growth', 'rate', 'industrial', 'sector', 'moderate'],
#  ['cry', 'joy'],
#  ['happening', 'get', 'game', 'different'],
#  ['new', 'upcoming', 'revealed'],
#  ['look', 'like', 'ignore', 'racing', 'unhappy'],
#  ['could', 'write', 'theoretically', 'impossible', 'real', 'life', 'unhappy'],
#  ['potboiler'],
#  ['sad', 'unhappy'],
#  ['parliament'],
#  ['salary'],
#  ['mission', 'nice', 'day', 'though'],
#  ['great', 'night', 'hope', 'strip', 'club', 'happy', 'photo'],
#  ['want', 'drink', 'unhappy'],
#  ['quits'],
#  ['congratulate', 'people'],
#  ['sworn', 'chief', 'minister', 'tomorrow'],
#  ['russel', 'noodle', 'unhappy'],
#  ['want', 'permanent'],
#  ['satisfied', 'policy'],
#  [],
#  ['last', 'kiss', 'unhappy'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['unhappy'],
#  ['ram'],
#  [],
#  ['check', 'happy'],
#  ['clay', 'love', 'deserved', 'unhappy'],
#  ['miss', 'temperance', 'booth', 'much', 'unhappy'],
#  ['sorry', 'see', 'tweet', 'unhappy', 'please', 'could', 'address', 'look'],
#  [],
#  ['love', 'song'],
#  ['gone', 'day', 'work', 'work', 'work', 'unhappy'],
#  ['knight', 'day', 'pick', 'something', 'nice'],
#  ['economic', 'blockade', 'impact', 'process'],
#  ['never', 'happy'],
#  ['politics'],
#  ['also'],
#  ['new', 'one', 'bit', 'unstable', 'unhappy'],
#  ['happy'],
#  ['people', 'abuse', 'unhappy', 'loyal'],
#  ['state', 'bank', 'profit'],
#  ['oh'],
#  ['put', 'fire'],
#  ['unhappy', 'oki', 'welcome', 'sam'],
#  [],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['undercurrent', 'led', 'surge', 'story'],
#  [],
#  [],
#  ['allow', 'name'],
#  ['inspiration', 'fashion'],
#  ['dope', 'cool', 'word', 'finally', 'hip', 'young', 'smile'],
#  ['religious'],
#  ['would', 'awesome'],
#  ['rise'],
#  ['setting',
#   'judge',
#   'constitution',
#   'bench',
#   'decide',
#   'appeal',
#   'verdict',
#   'holding'],
#  ['ministry'],
#  ['also'],
#  ['admit', 'vanity'],
#  ['stayed', 'phone', 'ad', 'miss', 'unhappy'],
#  ['non', 'teaching', 'staff', 'call', 'end', 'stir'],
#  ['livid'],
#  ['yo', 'thank'],
#  [],
#  ['unruly',
#   'behaviour',
#   'violence',
#   'aviation',
#   'network',
#   'regrettable',
#   'incident'],
#  ['security', 'need'],
#  [],
#  ['trouble', 'play'],
#  ['round', 'as', 'cry'],
#  ['day', 'new', 'follower', 'happy', 'via'],
#  ['suppose', 'waiting', 'happy'],
#  ['bounty', 'damage', 'bill'],
#  ['groovy', 'happy'],
#  ['happen', 'easter', 'one', 'best', 'day', 'unhappy'],
#  ['wake',
#   'tomorrow',
#   'body',
#   'gotten',
#   'head',
#   'start',
#   'waking',
#   'every',
#   'day',
#   'week',
#   'unhappy'],
#  ['supreme', 'court', 'decided', 'future', 'rival'],
#  ['cloud', 'also'],
#  ['day', 'new', 'happy', 'via'],
#  ['break', 'russia'],
#  ['forever', 'trapped', 'void', 'realm', 'unhappy'],
#  ['cricket', 'body'],
#  ['hey', 'could', 'help', 'legitimate', 'really', 'need', 'account', 'rig'],
#  ['road', 'economy'],
#  ['president', 'supporting', 'legislation', 'related'],
#  ['gesture', 'spot'],
#  ['agree', 'issue', 'would', 'somehow', 'see', 'sad'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['motivation', 'study', 'unhappy'],
#  ['peacefully', 'sitting', 'reading', 'book', 'work'],
#  ['hacked', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  [],
#  ['order'],
#  ['idea', 'wrong'],
#  ['got', 'vive', 'tracker', 'office', 'intern'],
#  ['actually', 'cry', 'tweet', 'take', 'applicable', 'knock', 'unhappy'],
#  ['right', 'happy', 'still', 'condition'],
#  ['life', 'dark', 'corner', 'become', 'magical', 'got', 'st', 'year'],
#  ['sadly',
#   'yes',
#   'since',
#   'continue',
#   'losing',
#   'support',
#   'dropping',
#   'unhappy',
#   'going'],
#  ['next', 'question', 'unhappy'],
#  ['help',
#   'want',
#   'stop',
#   'feel',
#   'endless',
#   'suffering',
#   'pain',
#   'tried',
#   'deactivate',
#   'many',
#   'time',
#   'save',
#   'unhappy'],
#  ['cute', 'picture', 'though'],
#  ['supreme',
#   'court',
#   'trial',
#   'court',
#   'verdict',
#   'holding',
#   'corruption',
#   'case'],
#  ['looking',
#   'forward',
#   'come',
#   'see',
#   'booth',
#   'going',
#   'right',
#   'center',
#   'field',
#   'happy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['maybe', 'band', 'definitely', 'hi', 'name', 'happy'],
#  ['helm'],
#  ['editorial', 'mayor', 'cannot'],
#  ['aerobatic', 'display', 'inaugural'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'cont'],
#  ['said', 'silence', 'morgan', 'freeman', 'voice', 'happy'],
#  ['want', 'give', 'everything', 'happy', 'see', 'smile', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['sup'],
#  ['spell'],
#  ['development'],
#  ['remember',
#   'knowledge',
#   'worth',
#   'grade',
#   'announce',
#   'winner',
#   'tomorrow',
#   'morning',
#   'am',
#   'happy',
#   'purchase',
#   'happy'],
#  ['well', 'done', 'welcome', 'happy'],
#  ['entering', 'system', 'via', 'business', 'district'],
#  ['tweet', 'made', 'cry', 'cry'],
#  ['surround', 'positivity', 'happy'],
#  ['want', 'unhappy', 'yummy'],
#  ['routine', 'enforcement', 'surge'],
#  ['seeking', 'restrain', 'chief', 'minister', 'tomorrow'],
#  ['mine', 'back', 'say', 'happy'],
#  ['thanks', 'recent', 'follow'],
#  ['thought',
#   'mountain',
#   'dew',
#   'caffeine',
#   'little',
#   'energy',
#   'drink',
#   'never',
#   'sleep',
#   'unhappy'],
#  ['ban'],
#  [],
#  ['clear', 'right', 'speaker', 'decide'],
#  ['better', 'check'],
#  ['really', 'really', 'bloody', 'cry', 'joy'],
#  ['video'],
#  ['guilty', 'murder'],
#  ['thanks', 'great', 'review', 'smile'],
#  ['question', 'banking', 'switching', 'old'],
#  ['sweep', 'hand', 'puppet', 'bastard', 'lost', 'squeak', 'unhappy'],
#  ['want', 'meet', 'bad', 'unhappy'],
#  ['join', 'vote', 'singer', 'spread', 'word'],
#  ['note', 'self', 'dont', 'get', 'attached', 'cry'],
#  ['might', 'dressed', 'bit', 'better'],
#  ['someone', 'unhappy', 'available'],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['still', 'sign', 'small', 'area', 'would', 'obvious', 'sad', 'quite'],
#  ['make', 'cry', 'joy', 'need'],
#  ['way', 'home', 'happy', 'happy', 'si', 'sa'],
#  ['today'],
#  ['keep_smiling_y'],
#  ['victory', 'may', 'bad', 'news'],
#  ['maybe'],
#  ['finance', 'minister', 'given', 'additional', 'charge', 'ministry'],
#  ['friend', 'smile'],
#  ['phone', 'possibility', 'chance', 'would', 'notice', 'unhappy'],
#  ['house', 'till', 'pm'],
#  ['like', 'jittery', 'caffeine', 'sad'],
#  ['latest', 'school'],
#  ['road', 'safety', 'crusader', 'fight', 'bid', 'bypass', 'order', 'highway'],
#  ['love'],
#  [],
#  ['still', 'live'],
#  ['honestly',
#   'college',
#   'want',
#   'curl',
#   'ball',
#   'cry',
#   'day',
#   'straight',
#   'unhappy'],
#  ['summer', 'salad', 'inspiration', 'smile'],
#  ['siltation', 'threat', 'national', 'waterway'],
#  ['waiting', 'jail', 'break', 'happy'],
#  ['sad', 'unhappy'],
#  ['gone', 'house', 'whilst', 'flying', 'drone', 'happy'],
#  ['really', 'appreciate', 'hope', 'brilliant', 'day', 'happy'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['versus', 'cry', 'joy'],
#  ['miss', 'sad'],
#  ['happy', 'weed', 'day', 'without', 'unhappy'],
#  ['get', 'unhappy', 'ratio', 'amazing'],
#  ['made', 'day', 'great', 'story', 'happy'],
#  ['nation', 'must', 'begin', 'new', 'life'],
#  ['afraid'],
#  ['thanks', 'recent', 'follow', 'much', 'happy'],
#  ['really', 'serious', 'hope', 'judge', 'unhappy'],
#  ['menu', 'dinner', 'praise', 'praise'],
#  ['slipped', 'secrecy', 'clause'],
#  ['also', 'attractive', 'happy'],
#  ['really', 'really', 'need', 'right', 'unhappy'],
#  ['oh', 'god', 'unhappy', 'next', 'time'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['firing', 'underway'],
#  ['think', 'going', 'true'],
#  ['brutally',
#   'respectable',
#   'suit',
#   'enjoy',
#   'happy',
#   'contrast',
#   'appreciate',
#   'mo'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['prime', 'minister', 'made', 'man', 'beat'],
#  ['mystery', 'effect', 'data'],
#  ['today', 'annual', 'crore'],
#  [],
#  ['bore'],
#  ['yet'],
#  ['made', 'ensure', 'free', 'fair', 'election'],
#  ['noted', 'sir'],
#  ['miss', 'unhappy'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['pinned', 'tweet', 'patient', 'saved', 'happy'],
#  ['unhappy', 'damn', 'sad'],
#  ['airlift', 'blockade'],
#  [],
#  ['wish', 'could', 'vote', 'unhappy'],
#  ['rd', 'episode', 'everyone', 'sure', 'check', 'happy'],
#  ['molten', 'tar', 'family'],
#  ['happy'],
#  ['drive', 'become', 'chief', 'minister'],
#  ['court',
#   'summons',
#   'suspended',
#   'accused',
#   'criminal',
#   'defamation',
#   'plea'],
#  ['million', 'offering', 'smile'],
#  ['tweet', 'getting', 'holding', 'sticker', 'click', 'tweet'],
#  ['also', 'support'],
#  ['see', 'cry', 'today'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['much', 'free', 'legit', 'free', 'follow', 'first', 'get', 'patient'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lotus', 'garden'],
#  ['may', 'open', 'happy'],
#  ['rape', 'accused', 'leader', 'gayatri', 'roaming'],
#  ['cash', 'today'],
#  ['honestly',
#   'think',
#   'trying',
#   'get',
#   'rid',
#   'make',
#   'mockery',
#   'town',
#   'wont',
#   'admit',
#   'unhappy'],
#  ['girl', 'unhappy', 'wa', 'unnecessarily', 'expensive', 'try'],
#  ['happy', 'new', 'video', 'happy'],
#  ['baby'],
#  ['miss', 'unhappy'],
#  ['impartial', 'probe'],
#  ['army', 'key', 'highway', 'suffering'],
#  ['use', 'happy'],
#  ['pretty', 'happy'],
#  ['friend', 'promise', 'meant', 'broken'],
#  ['panic', 'top', 'hospital'],
#  ['miss', 'boo', 'much', 'unhappy'],
#  ['said'],
#  ['day', 'new', 'follower', 'happy', 'via'],
#  [],
#  ['lost', 'unhappy'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['unhappy', 'sorry', 'hear'],
#  ['miss', 'baby', 'unhappy'],
#  ['state', 'fourth', 'estate'],
#  ['half', 'naked', 'happy'],
#  ['sign'],
#  ['could', 'meet', 'next', 'time'],
#  ['governor', 'meet', 'new', 'legislature', 'party', 'leader', 'pm'],
#  ['stone', 'miss', 'brother', 'message'],
#  ['list'],
#  ['well'],
#  ['court', 'allow', 'trooper', 'wife', 'meet'],
#  [],
#  ['lost'],
#  ['medical', 'shorthand', 'abbreviation', 'use', 'work'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['supreme', 'court', 'highway', 'booze', 'hatch'],
#  ['girl', 'also'],
#  ['hope', 'time', 'come', 'back', 'fresh', 'happy', 'happy'],
#  ['become', 'apart', 'lose', 'happy'],
#  ['currently',
#   'standing',
#   'outside',
#   'shard',
#   'bag',
#   'full',
#   'empty',
#   'came',
#   'work',
#   'today',
#   'happy'],
#  ['told'],
#  ['liquor', 'baron', 'declared', 'offender'],
#  ['sarkar', 'ripping'],
#  ['physics', 'memorize', 'ha', 'ha', 'ha', 'happy'],
#  ['unhappy'],
#  ['high', 'court', 'cop', 'shield', 'willing', 'deal'],
#  ['go', 'away', 'unhappy'],
#  ['landslide', 'win', 'concede', 'defeat', 'fresh', 'paper'],
#  ['supporting', 'activity', 'violent', 'law', 'ram'],
#  ['mate', 'good', 'love', 'wished', 'center'],
#  ['cold', 'unhappy', 'see', 'feel', 'today'],
#  ['credit', 'also', 'go', 'happy'],
#  ['taking'],
#  ['instant', 'message', 'perfectly', 'fine', 'fellow', 'ken'],
#  ['call', 'ensure', 'justice', 'facing', 'evil', 'custom'],
#  ['thanks', 'top', 'community', 'last', 'week', 'happy'],
#  ['rose', 'come', 'really', 'enthusiast', 'much', 'may'],
#  ['hey'],
#  ['without'],
#  ['matter'],
#  ['know', 'cool', 'cry', 'joy'],
#  ['mutual', 'let', 'talk', 'sure', 'mutual', 'happy'],
#  ['ahead'],
#  ['hit'],
#  ['good', 'cry', 'joy', 'love', 'much'],
#  ['welfare'],
#  ['scheme', 'rupee'],
#  ['perch', 'peak'],
#  ['also'],
#  ['stage'],
#  ['dashed', 'would', 'weaken'],
#  ['barometer', 'patriotism'],
#  ['anyone', 'else', 'as', 'hole', 'unhappy'],
#  ['initiative', 'generate', 'shield'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy', 'get'],
#  ['dole'],
#  ['area', 'list', 'unhappy', 'think', 'go', 'anyway'],
#  ['today'],
#  ['self', 'buy', 'also', 'furry', 'unhappy'],
#  ['hi'],
#  ['father'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['going',
#   'poignant',
#   'moment',
#   'air',
#   'arm',
#   'give',
#   'send',
#   'true',
#   'war',
#   'horse'],
#  ['chief', 'press', 'conference', 'begin', 'shortly', 'stay', 'tuned'],
#  ['bit', 'rusty', 'unhappy'],
#  ['keeping', 'eye', 'house'],
#  [],
#  ['court', 'report', 'fracas'],
#  ['turn', 'soon', 'oh', 'god', 'still', 'baby', 'unhappy'],
#  ['follow', 'happy'],
#  ['rather'],
#  ['got', 'unhappy'],
#  ['vile', 'tactic', 'valley'],
#  ['gray', 'outside', 'today', 'unhappy'],
#  ['old', 'street', 'directory'],
#  ['top', 'engaged', 'week', 'happy'],
#  ['accidental', 'new', 'book'],
#  [],
#  [],
#  ['wont', 'able', 'stream', 'tonight', 'sorry', 'unhappy'],
#  ['hi',
#   'share',
#   'concern',
#   'unhappy',
#   'please',
#   'contact',
#   'get',
#   'touch',
#   'detailed',
#   'cont'],
#  ['sale', 'slice'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['reliance', 'prime', 'minister', 'picture', 'without', 'permission'],
#  ['tension', 'visit'],
#  ['super', 'wait', 'happy'],
#  ['second', 'thanks', 'spin', 'much', 'happy'],
#  ['friend', 'would', 'like', 'brand', 'new'],
#  ['sworn', 'deputy'],
#  ['happy', 'birthday', 'good', 'day', 'happy'],
#  ['homage', 'memorial', 'sealed', 'cover'],
#  ['aw', 'pride', 'kind', 'want', 'go', 'happy'],
#  ['trying', 'get', 'touch', 'appear', 'unhappy'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  [],
#  ['blessing'],
#  ['get', 'pork', 'diner', 'tho', 'egg', 'unhappy'],
#  ['fun'],
#  [],
#  ['aw',
#   'angel',
#   'love',
#   'lot',
#   'hope',
#   'going',
#   'best',
#   'lot',
#   'fun',
#   'already'],
#  ['unhappy'],
#  ['hi', 'han'],
#  ['cold', 'war'],
#  ['mighty', 'albatross', 'carried', 'missile'],
#  ['say'],
#  ['review', 'lifting'],
#  ['better', 'cry', 'joy', 'rs'],
#  ['hi', 'want', 'speak', 'business', 'partnership', 'happy'],
#  ['beautiful', 'day', 'happy'],
#  ['driver', 'happy', 'waiting', 'sun', 'ten'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['injured'],
#  ['also',
#   'beautiful',
#   'art',
#   'biggest',
#   'sale',
#   'anyone',
#   'interested',
#   'happy'],
#  ['hey',
#   'everyone',
#   'harry',
#   'maple',
#   'syrup',
#   'breakfast',
#   'great',
#   'way',
#   'start',
#   'day',
#   'happy',
#   'miss'],
#  ['hi'],
#  ['trump', 'repeal', 'privacy'],
#  ['turn', 'museum'],
#  ['bus', 'heading', 'good', 'day', 'happy'],
#  ['miss', 'baby', 'unhappy'],
#  ['international'],
#  ['know', 'feel'],
#  ['academic', 'siege'],
#  ['trade', 'happy', 'yeah', 'want'],
#  ['fracas'],
#  [],
#  ['supreme', 'court', 'record', 'unqualified', 'apology', 'counsel'],
#  ['major', 'waffle', 'right', 'sad'],
#  [],
#  ['hear', 'petition', 'order', 'beef', 'ban'],
#  ['dargah', 'trust', 'clear', 'sq'],
#  ['also'],
#  ['march', 'siege', 'parliament'],
#  ['crude', 'architecture', 'taking', 'world', 'city'],
#  ['engagement', 'gulf'],
#  ['hi'],
#  ['sure', 'happy'],
#  ['newly', 'meet', 'mar'],
#  ['even'],
#  ['home'],
#  ['two', 'encounter', 'nearly'],
#  ['bring', 'back', 'ginger'],
#  ['mine', 'sending', 'stuff', 'unhappy'],
#  ['detailed', 'governor', 'happening'],
#  [],
#  ['also'],
#  ['handling'],
#  ['good', 'watch', 'tv', 'application', 'free', 'happy'],
#  ['exactly', 'thinking', 'unhappy'],
#  ['feeling', 'today', 'unhappy'],
#  ['wow', 'decision'],
#  ['cry', 'joy'],
#  ['shoehorn', 'plot', 'character', 'support'],
#  ['mutiny', 'versus'],
#  ['survivor', 'simple', 'message'],
#  ['facing', 'arrest', 'warrant'],
#  ['shut'],
#  ['huge',
#   'thank',
#   'within',
#   'social',
#   'work',
#   'care',
#   'keep',
#   'great',
#   'work',
#   'happy'],
#  ['went', 'today', 'guess', 'forgot', 'idol'],
#  ['miss', 'open', 'education', 'seminar', 'happy'],
#  ['although', 'little', 'late', 'sad'],
#  ['learning'],
#  ['ordered', 'ban'],
#  ['hi',
#   'pretty',
#   'confident',
#   'isolated',
#   'case',
#   'would',
#   'glad',
#   'help',
#   'could'],
#  ['opening', 'happy'],
#  ['post', 'offer', 'happy'],
#  ['ill', 'work', 'second', 'come', 'unhappy'],
#  ['case', 'filing', 'status', 'report', 'international', 'tribunal'],
#  ['teaser', 'coming', 'today', 'pm', 'story'],
#  ['village'],
#  ['attack'],
#  ['supreme', 'court', 'verdict', 'lifting', 'shield'],
#  ['really', 'feel', 'lamp', 'unhappy'],
#  ['save', 'guy', 'life'],
#  ['st', 'warrant', 'judge'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'sent'],
#  ['instead', 'money'],
#  ['miss', 'going', 'past', 'house', 'though', 'nice', 'looking', 'building'],
#  ['two', 'south'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  [],
#  ['hello', 'everyone'],
#  ['backed', 'prevent', 'legal'],
#  ['thanks', 'happy'],
#  ['thank', 'miss', 'everyone', 'love'],
#  ['hope'],
#  ['oh', 'god', 'penny', 'unhappy'],
#  ['effective', 'show'],
#  ['love', 'like', 'reach', 'opportunity', 'could', 'hit', 'happy'],
#  ['tomorrow'],
#  ['morning', 'happy'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'get'],
#  ['poor', 'make', 'sad', 'unhappy', 'hope'],
#  ['see', 'next', 'tweet', 'different', 'keeping', 'calm'],
#  ['give', 'try', 'happy'],
#  ['dealer', 'said', 'due', 'disabled', 'losing', 'sad'],
#  ['dog', 'family', 'put', 'tomorrow', 'unhappy'],
#  ['hope',
#   'last',
#   'long',
#   'least',
#   'get',
#   'enjoy',
#   'weekend',
#   'happy',
#   'birthday',
#   'happy'],
#  ['kind', 'jealous', 'fault', 'working', 'hard', 'happy'],
#  ['foreign', 'secretary', 'visit', 'next', 'week', 'frank'],
#  ['thanks', 'smile', 'much', 'better', 'today', 'thanks', 'message'],
#  ['vocal', 'coach', 'post'],
#  ['folklore', 'history'],
#  ['militant', 'wing', 'speak'],
#  ['full', 'interview', 'inside', 'days'],
#  ['went', 'today', 'guess', 'forgot', 'idol'],
#  ['champion'],
#  ['stamping', 'hand', 'baggage', 'major'],
#  ['getting'],
#  ['perfectly', 'happy', 'single', 'see', 'happy', 'couple'],
#  ['mutual', 'let', 'talk', 'sure', 'mutual', 'happy'],
#  ['full', 'month', 'two'],
#  ['wedding', 'package', 'cause', 'poor', 'unhappy', 'massage', 'see'],
#  ['attack'],
#  ['hi', 'follow'],
#  ['would', 'trauma', 'ware', 'unhappy'],
#  ['gave', 'bus', 'board', 'flight', 'goodwill'],
#  [],
#  ['thanks', 'high', 'value', 'member', 'week'],
#  ['like', 'legal', 'available'],
#  ['rural', 'counter', 'call'],
#  ['unhappy'],
#  ['fielded', 'nephew'],
#  ['untold', 'story', 'plan', 'unseat'],
#  [],
#  ['holy',
#   'script',
#   'opening',
#   'scene',
#   'man',
#   'steel',
#   'krypton',
#   'got',
#   'compressed',
#   'wish',
#   'could',
#   'least'],
#  [],
#  ['get', 'haircut', 'know', 'good', 'place', 'unhappy'],
#  ['say'],
#  [],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['class', 'hall', 'heroic'],
#  ['dang', 'guess', 'ruined', 'unhappy'],
#  ['station', 'check', 'happy', 'surely', 'combination', 'xx', 'xx'],
#  ['get', 'accept', 'calf'],
#  ['set', 'panel', 'study', 'service', 'paramilitary'],
#  ['per', 'cent', 'per', 'cent'],
#  ['tired', 'unhappy'],
#  ['perfectly', 'happy', 'got'],
#  ['nothing', 'sell'],
#  ['miss', 'temperance', 'booth', 'much', 'unhappy'],
#  ['leftist', 'minority', 'voice'],
#  ['definitely', 'arm', 'unhappy'],
#  ['must', 'varsity'],
#  ['national', 'body', 'meeting'],
#  ['friendly',
#   'reminder',
#   'enjoy',
#   'movie',
#   'television',
#   'show',
#   'without',
#   'trash',
#   'another',
#   'happy'],
#  ['get',
#   'majority',
#   'congress',
#   'single',
#   'party',
#   'bagging',
#   'member',
#   'house'],
#  ...]

# %%
from gensim.models import Word2Vec

w2v = Word2Vec(size=150, window=10, min_count=1, sg=1, workers=10)
w2v.build_vocab(training_docs)
w2v.train(sentences=training_docs, total_examples=len(training_docs), epochs=w2v.epochs)

w2v

# %%
def doc2vec(docs):
    last_indices = []
    testing_docs = []
    tokenized_docs = []

    for _, row in docs.iterrows():
        tokens = tokenize(preprocess(row['tweets']))
        if len(last_indices) > 0:
            last_indices.append(last_indices[len(last_indices) - 1] + len(tokens))
        else:
            last_indices.append(len(tokens))
        testing_docs.extend(tokens)
        tokenized_docs.append(tokens)

    return tokenized_docs, testing_docs, last_indices

from sklearn.cluster import MiniBatchKMeans

kmeans = MiniBatchKMeans(n_clusters=8, batch_size=750)

def stream_cluster(vectors, vector_size, last_indices):
    document_vectors = []
    first_index = 0
    
    for last_index in last_indices:
        min_vector = []
        max_vector = []
        for i in range(vector_size):
            v_list = [v[i] for v in vectors[first_index:last_index]]
            if len(v_list) > 0:
                min_vector.append(min(v_list))
                max_vector.append(max(v_list))
        if len(min_vector) > 0 and len(max_vector) > 0:
            min_vector.extend(max_vector)
            document_vectors.append(min_vector)
        first_index = last_index
    clustering = kmeans.partial_fit(document_vectors)
    
    return clustering, clustering.labels_, document_vectors

# %%
last_index = int(len(documents.index) / 5)
documents_test = documents[:last_index]

tokenized_docs, testing_docs, last_indices = doc2vec(documents_test)

tokenized_docs
# Out:
# [['like', 'due', 'kill', 'unhappy'],
#  ['mean'],
#  ['versus'],
#  ['physicist', 'still', 'table', 'full'],
#  ['convoy', 'bypass', 'police'],
#  ['next', 'question', 'unhappy'],
#  [],
#  ['key', 'unchanged'],
#  ['miss', 'cry'],
#  ['thanks', 'week', 'much', 'happy', 'want'],
#  ['follow', 'unhappy'],
#  ['suddenly', 'cannot', 'enough', 'mother'],
#  ['please', 'reading', 'heart', 'unhappy'],
#  ['hello', 'getting', 'something', 'unhappy'],
#  ['look', 'good', 'current', 'shame', 'never', 'cut', 'unhappy'],
#  ['work', 'much', 'better', 'unhappy'],
#  ['today', 'congress', 'address'],
#  ['please', 'beautiful', 'princess', 'help'],
#  ['awesome', 'id', 'love', 'see', 'like'],
#  ['happy', 'belated', 'birthday', 'another', 'duet', 'much'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['tell', 'unhappy'],
#  ['tried', 'everything'],
#  ['give', 'trial', 'run'],
#  [],
#  ['table', 'today'],
#  [],
#  ['last', 'night', 'dream', 'japan', 'see', 'request', 'unhappy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['miss', 'dog', 'unhappy'],
#  ['people', 'want'],
#  ['early', 'deal'],
#  ['put',
#   'trial',
#   'criminal',
#   'defamation',
#   'case',
#   'union',
#   'minister',
#   'matter'],
#  ['captain', 'singh'],
#  ['virulent', 'going', 'culture', 'census'],
#  ['also'],
#  ['versus', 'undercurrent'],
#  ['extension', 'privacy'],
#  ['today', 'unhappy', 'least', 'sale', 'pitching'],
#  ['sorry',
#   'tired',
#   'stream',
#   'get',
#   'sleep',
#   'try',
#   'fun',
#   'tomorrow',
#   'feeling',
#   'tonight'],
#  [],
#  [],
#  ['take', 'care', 'friend', 'happy'],
#  ['hold', 'promise', 'battle'],
#  ['ne', 'reunite', 'unhappy'],
#  ['lit', 'unhappy'],
#  ['thanks', 'top', 'new', 'great', 'week', 'happy'],
#  ['cant', 'piss', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['getting', 'harder', 'harder', 'stay', 'unhappy'],
#  ['twitter', 'premium', 'version', 'free', 'service'],
#  ['student', 'stir', 'intensify', 'strike', 'today'],
#  ['several', 'injured', 'storm', 'polling', 'low', 'turnout', 'till'],
#  ['floor', 'test'],
#  ['keep'],
#  ['amazing', 'stuff', 'happy', 'birth', 'control', 'gamma', 'ray'],
#  ['happy', 'brighten', 'day', 'happy'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['camera', 'shooting'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['got', 'rest'],
#  ['raj', 'calling', 'party', 'form', 'government'],
#  ['longer', 'even', 'want', 'unhappy'],
#  [],
#  ['alpha', 'invitation', 'well', 'received', 'happy'],
#  ['part'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['really', 'amount', 'unhappy', 'ride', 'meet', 'darby', 'end'],
#  ['happy'],
#  ['another', 'camp'],
#  ['dont', 'laugh', 'unhappy', 'base'],
#  ['live', 'ruckus', 'assembly', 'secret', 'ballot', 'demand'],
#  ['keep'],
#  ['also'],
#  ['day', 'read', 'said', 'hoax'],
#  ['bronchitis', 'love', 'happy'],
#  ['time'],
#  ['fitness'],
#  ['swear', 'past'],
#  ['zac', 'back', 'way', 'sad', 'unhappy'],
#  ['never', 'happy'],
#  [],
#  ['unhappy'],
#  ['probe', 'yet', 'video', 'army'],
#  ['happy'],
#  [],
#  [],
#  [],
#  ['graft', 'case'],
#  ['also'],
#  ['former', 'minister', 'ka', 'presidium', 'chairman'],
#  ['helicopter'],
#  ['day',
#   'since',
#   'promotion',
#   'ended',
#   'already',
#   'missing',
#   'much',
#   'unhappy'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['come', 'sad'],
#  ['switch', 'side'],
#  ['say', 'hi', 'sunshine', 'unhappy'],
#  ['high', 'commissioner'],
#  ['thanks',
#   'much',
#   'following',
#   'love',
#   'know',
#   'think',
#   'flooring',
#   'range',
#   'happy'],
#  ['hate', 'throwing', 'unhappy'],
#  ['painful', 'thing', 'ever', 'someone', 'unhappy'],
#  ['help'],
#  ['instant'],
#  ['hard', 'give', 'experience', 'pleasurable', 'pain'],
#  ['connection', 'men', 'polling', 'day', 'police'],
#  ['suspected', 'selling', 'us'],
#  ['know', 'time', 'waiting', 'long', 'time', 'unhappy'],
#  ['attached'],
#  ['oh', 'god', 'attend', 'together', 'sometime'],
#  ['year', 'old', 'new', 'ladylike', 'trust', 'troll'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['rock', 'clue', 'earth'],
#  ['friendly', 'fire', 'tour', 'unhappy'],
#  ['official'],
#  ['please', 'return', 'jacket', 'unhappy'],
#  ['contribution', 'posted', 'ago', 'cry', 'joy'],
#  ['awesome', 'recommendation', 'jess'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['golly',
#   'gosh',
#   'simply',
#   'dreadful',
#   'havoc',
#   'must',
#   'subsurface',
#   'black',
#   'salve'],
#  ['love',
#   'people',
#   'message',
#   'long',
#   'beautiful',
#   'find',
#   'like',
#   'unhappy',
#   'yes',
#   'agree',
#   'keep',
#   'going'],
#  ['opposing'],
#  ['happy'],
#  ['cost',
#   'abut',
#   'year',
#   'paying',
#   'half',
#   'full',
#   'education',
#   'get',
#   'treat'],
#  ['hi', 'cham'],
#  [],
#  ['shoehorn', 'plot', 'character', 'support'],
#  ['blind'],
#  ['nick', 'might', 'deliver', 'time', 'story', 'life'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['usually', 'speedboat', 'behind', 'get', 'river', 'unhappy'],
#  ['family'],
#  ['thanks', 'brother'],
#  ['half', 'time', 'unhappy'],
#  ['hate', 'cry', 'joy'],
#  ['iconoclasm', 'exponent', 'moving', 'beyond', 'artificial'],
#  ['confusion'],
#  ['need', 'learn', 'start', 'people', 'keep', 'chatting', 'unhappy'],
#  ['ill', 'fitting'],
#  ['room'],
#  ['feel',
#   'like',
#   'telling',
#   'get',
#   'social',
#   'medium',
#   'also',
#   'feel',
#   'really',
#   'mean',
#   'unhappy',
#   'silence',
#   'love',
#   'hope'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['miss', 'sad'],
#  ['finance', 'minister'],
#  ['growth', 'core', 'sector', 'slows', 'year', 'ago', 'month'],
#  ['let', 'alone', 'free'],
#  ['man', 'phone', 'made', 'like', 'always', 'wink'],
#  ['oh', 'yes', 'happy'],
#  ['worry'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['like', 'per', 'piece', 'unhappy'],
#  ['someone', 'worst', 'deserve', 'best'],
#  ['change', 'whole', 'life', 'happy'],
#  ['question', 'make', 'sure', 'use', 'happy'],
#  ['think', 'finally', 'figured', 'tattoo', 'getting', 'august'],
#  ['oh', 'unhappy', 'like', 'still'],
#  ['wish', 'could', 'say', 'picture', 'unhappy', 'high'],
#  ['moral', 'outrage', 'cannot', 'guide', 'get', 'messy'],
#  ['face', 'bloated', 'unhappy', 'baby', 'get', 'well', 'soon'],
#  ['visual', 'studio', 'installation', 'come', 'suddenly', 'unhappy'],
#  ['upsetting', 'abuse', 'get', 'unhappy'],
#  ['wait', 'actually', 'see', 'copy', 'smile'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['polling',
#   'underway',
#   'assembly',
#   'spread',
#   'across',
#   'seventh',
#   'final',
#   'phase'],
#  [],
#  ['really', 'need', 'build', 'unhappy'],
#  ['stress'],
#  [],
#  ['sworn', 'chief', 'minister'],
#  ['supreme', 'court', 'justice', 'explain', 'face'],
#  ['entry'],
#  ['want', 'victory', 'rally'],
#  ['long', 'time', 'chat', 'sad'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['day', 'sell', 'truck'],
#  ['warm'],
#  ['double', 'digit', 'sluggish', 'growth', 'high', 'growth', 'war'],
#  ['happy', 'bear'],
#  ['train', 'blast', 'case'],
#  ['great', 'day', 'today', 'happy'],
#  ['parent', 'friendly', 'like', 'please'],
#  ['since', 'stopped', 'snapping', 'made', 'massive', 'difference', 'get'],
#  ['make', 'built', 'westward', 'ho', 'estate', 'read'],
#  [],
#  ['tale', 'prime'],
#  ['understand', 'silly', 'like', 'make', 'smile', 'happy'],
#  ['dude'],
#  ['match', 'referee', 'went', 'book'],
#  ['hold', 'used', 'new', 'application', 'made', 'team', 'happy'],
#  ['feel', 'awful', 'today', 'unhappy', 'want', 'go', 'internship'],
#  ['thanks', 'happy'],
#  ['picture'],
#  ['miss', 'unhappy'],
#  ['also', 'making'],
#  ['decided', 'merge'],
#  ['yeah', 'update'],
#  ['hard', 'see', 'best', 'friend', 'another', 'girl', 'happy'],
#  ['half', 'brother', 'leader', 'kim', 'un'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['miss', 'unhappy'],
#  ['th', 'tweet', 'like', 'say', 'love'],
#  ['baby',
#   'unhappy',
#   'broke',
#   'mail',
#   'read',
#   'letter',
#   'thank',
#   'enough',
#   'best'],
#  [],
#  ['cloaked', 'debate'],
#  ['actually',
#   'looking',
#   'forward',
#   'seeing',
#   'theory',
#   'around',
#   'personal',
#   'vote',
#   'correct',
#   'unhappy'],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want'],
#  ['question', 'mark', 'video'],
#  ['pushing'],
#  ['stopped', 'got', 'rid', 'toy', 'bottom', 'unhappy'],
#  ['unofficial', 'ban'],
#  ['happening', 'get', 'game', 'different'],
#  ['found', 'home', 'doctor'],
#  ['gen', 'governor'],
#  ['fat', 'ass', 'girl', 'fat', 'fetish', 'hot'],
#  ['right', 'seriously', 'need', 'decent', 'butterfly', 'tattoo', 'design'],
#  ['thank'],
#  ['love', 'much', 'smile', 'smile'],
#  ['world', 'big', 'big', 'take', 'world', 'much', 'smile', 'happy'],
#  ['jealous', 'unhappy', 'please', 'go', 'see', 'green', 'room', 'sat'],
#  ['protein', 'venom', 'may', 'help', 'recover', 'faster'],
#  ['stupid'],
#  ['thumbnail', 'best', 'render', 'ever', 'dand'],
#  ['fear', 'law', 'may', 'force', 'private', 'shun', 'critical'],
#  ['rate'],
#  ['super', 'unhappy'],
#  [],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['ride', 'final', 'unhappy'],
#  ['hate', 'park', 'much', 'sad'],
#  ['day', 'ahead', 'confidence', 'vote'],
#  ['private', 'put', 'expansion', 'hold'],
#  ['core', 'slow'],
#  ['serious', 'regarding', 'captain', 'shoulder', 'injury'],
#  [],
#  ['case', 'contract', 'soup'],
#  ['constable',
#   'service',
#   'court',
#   'inquiry',
#   'bad',
#   'quality',
#   'food',
#   'base'],
#  ['old', 'twitter', 'unhappy'],
#  ['education', 'throw'],
#  ['thank', 'happy'],
#  ['unnamed'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['going', 'notice', 'unhappy'],
#  ['mad', 'cute', 'unhappy'],
#  ['new', 'second', 'home', 'coming', 'soon'],
#  ['met'],
#  ['yes', 'life'],
#  ['tired', 'nothing', 'great', 'unhappy'],
#  ['unhappy', 'unhappy', 'hope', 'sooner'],
#  ['brit'],
#  ['autograph', 'book', 'ready'],
#  ['pure', 'evil', 'people', 'unhappy'],
#  ['thats', 'grim', 'unhappy'],
#  ['demit', 'game', 'real', 'cry', 'joy'],
#  ['cute', 'unhappy'],
#  ['unhappy', 'struggle', 'valid'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['theory', 'population'],
#  ['would', 'great', 'trick', 'happy'],
#  ['put', 'ruling', 'combine', 'request'],
#  ['miss', 'bedroom', 'unhappy'],
#  [],
#  ['thank',
#   'much',
#   'willow',
#   'ring',
#   'birthday',
#   'amazing',
#   'stream',
#   'last',
#   'night'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['bill', 'pervert'],
#  ['team', 'come', 'minimal', 'side', 'effect'],
#  ['contact'],
#  ['perfect', 'dress'],
#  ['murder', 'activist', 'clause', 'law'],
#  ['make', 'mark', 'us', 'meet'],
#  ['indignation', 'remains', 'well', 'fed'],
#  ['spending',
#   'night',
#   'talking',
#   'beloved',
#   'perfect',
#   'love',
#   'man',
#   'happy'],
#  ['due', 'sudden', 'drop', 'visibility'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'want', 'free'],
#  ['bad', 'watch', 'unhappy', 'cake', 'cute', 'delicious'],
#  ['formidable', 'madame', 'business'],
#  ['law', 'change'],
#  ['presumably', 'support', 'list'],
#  ['unhappy'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['look', 'good', 'blue', 'happy'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['next', 'week', 'unhappy', 'wish', 'luck'],
#  ['company',
#   'fabulous',
#   'photographer',
#   'happy',
#   'look',
#   'determination',
#   'concrete',
#   'get'],
#  ['within', 'budget'],
#  ['thanks', 'happy'],
#  ['happy'],
#  ['link', 'seventeen', 'concert'],
#  ['happy'],
#  ['us', 'scare'],
#  ['get', 'dog'],
#  ['also'],
#  ['pork', 'happy'],
#  ['support'],
#  ['want', 'kiss', 'nose', 'tell', 'love', 'sad'],
#  ['yet', 'say', 'word', 'whether'],
#  ['miss', 'baby', 'unhappy'],
#  ['visa'],
#  ['sprout'],
#  ['thanks', 'notice'],
#  ['also'],
#  ['negative', 'pit', 'unhappiness'],
#  ['someone', 'issue', 'unhappy'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['right', 'see', 'people', 'like'],
#  ['unhappy'],
#  ['sign', 'barlow', 'yet', 'sad'],
#  ['win', 'draw', 'free', 'celebrate'],
#  ['dying', 'thirst', 'unhappy'],
#  ['need', 'different', 'pinned', 'tweet', 'unhappy'],
#  ['oh', 'baby', 'unhappy'],
#  ['grab', 'crew'],
#  ['returned', 'warm', 'welcome'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['premier', 'death'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['always', 'love', 'happy'],
#  ['miss', 'unhappy'],
#  ['passenger', 'chute', 'aircraft', 'airport', 'injured'],
#  ['visiting', 'prime', 'minister'],
#  ['would', 'great', 'trick', 'happy'],
#  [],
#  ['injured'],
#  ['person', 'chose', 'shut', 'unhappy'],
#  ['likely'],
#  ['least', 'cad', 'like', 'unhappy', 'cad'],
#  ['zoo', 'mark'],
#  ['type', 'ask', 'anything', 'like', 'happy', 'aa'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['ask', 'get', 'spend'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['bank', 'offer', 'rs'],
#  ['sept', 'terror', 'attack'],
#  ['bonding', 'happiness', 'family'],
#  ['happy'],
#  ['second', 'best', 'always', 'happy'],
#  ['elsewhere', 'imposition', 'plan'],
#  ['dysfunction', 'among'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  [],
#  ['body', 'upgrade', 'pitch', 'test'],
#  ['base', 'unhappy'],
#  [],
#  ['job', 'searching', 'got', 'none', 'got', 'abundance'],
#  ['reverse', 'special', 'link'],
#  ['agitation', 'day', 'trouble', 'soon', 'come'],
#  ['retard', 'sad'],
#  [],
#  ['menu'],
#  ['female', 'take', 'guarding', 'acid', 'attack', 'victim', 'hospital'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['wage', 'hike'],
#  ['miss', 'unhappy'],
#  ['sixth', 'spot', 'applicable', 'team', 'higher', 'pa'],
#  ['sense', 'belonging', 'among'],
#  ['veteran', 'see', 'breach'],
#  ['favorite', 'hobby', 'finding', 'negative', 'positive', 'thing', 'happy'],
#  ['please', 'stop', 'confining', 'unhappy'],
#  ['day'],
#  ['body', 'decided', 'boycott', 'function'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['stay', 'go', 'nobody', 'happy'],
#  ['good', 'morning', 'hope', 'slept', 'well', 'happy'],
#  ['wow',
#   'made',
#   'compressor',
#   'actually',
#   'turns',
#   'happy',
#   'may',
#   'useful',
#   'happy'],
#  ['crackdown'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['oh', 'sadly', 'wont', 'watch', 'right', 'forbid', 'see', 'unhappy'],
#  ['tell', 'idea'],
#  [],
#  ['happy', 'see', 'closer', 'con', 'five'],
#  ['hey', 'tony'],
#  ['please', 'talk', 'instant', 'message', 'lonely', 'need', 'cry'],
#  ['help', 'unhappy', 'early', 'birthday', 'gift'],
#  ['operator', 'acquire', 'business', 'seven', 'spectrum'],
#  ['happy', 'everyone', 'happy'],
#  ['sorry', 'one', 'bad', 'egg', 'embarrass', 'rest', 'unhappy'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['want', 'adult', 'today', 'birthday', 'unhappy'],
#  ['anyone', 'need', 'vent', 'unhappy'],
#  [],
#  ['resume', 'work', 'system', 'river'],
#  ['days', 'ram'],
#  ['want', 'follow', 'back', 'tweet', 'happy'],
#  ['see', 'hope'],
#  ['hello', 'everyone'],
#  ['army', 'fire', 'tactic'],
#  ['unhappy', 'come', 'people', 'like', 'state', 'intervention'],
#  ['opposition'],
#  ['know', 'ready', 'say', 'unhappy'],
#  ['slipped', 'budget'],
#  [],
#  ['player', 'player', 'rank', 'would', 'show', 'happy'],
#  ['worked',
#   'beautifully',
#   'redesign',
#   'import',
#   'page',
#   'suit',
#   'whole',
#   'application',
#   'would'],
#  [],
#  ['hey', 'stay', 'always', 'matter'],
#  ['thanks', 'week'],
#  ['school'],
#  ['know', 'problem', 'still', 'exist'],
#  ['mass'],
#  ['went', 'work', 'get', 'excited'],
#  ['let', 'know', 'like', 'one', 'happy'],
#  ['couple', 'unhappy'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['unhappy', 'emotion'],
#  [],
#  ['also'],
#  ['go', 'past'],
#  ['happy', 'million', 'keep', 'happy', 'million', 'close', 'another'],
#  ['hope', 'everything', 'go', 'right', 'unhappy'],
#  ['return', 'lake', 'next', 'winter'],
#  [],
#  ['rts', 'giveaway', 'origin', 'account', 'randomly', 'people'],
#  ['medical', 'body', 'handling', 'successful'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['lans', 'happy'],
#  ['historian', 'ram'],
#  ['maybe', 'definitely', 'happy', 'also'],
#  ['never', 'draw', 'unhappy'],
#  ['plan'],
#  ['minister'],
#  ['tap'],
#  ['also'],
#  ['get', 'latest', 'throughout', 'day'],
#  ['streaming',
#   'later',
#   'day',
#   'night',
#   'stream',
#   'since',
#   'go',
#   'take',
#   'care',
#   'contract'],
#  ['take', 'encounter'],
#  ['unhappy'],
#  ['please', 'turn', 'like', 'unhappy'],
#  ['unhappy'],
#  ['bin', 'mental'],
#  ['limit'],
#  ['violence'],
#  ['former',
#   'president',
#   'unqualified',
#   'unconditional',
#   'apology',
#   'supreme',
#   'court'],
#  ['pressure', 'ban'],
#  ['joy', 'get', 'back'],
#  ['still', 'strict'],
#  ['miss', 'busy', 'unhappy'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['favorite', 'unhappy'],
#  ['would', 'well', 'abolish'],
#  ['heartland', 'lab'],
#  ['seeing', 'past', 'present'],
#  ['say', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['would', 'sustained', 'fame', 'unhappy'],
#  ['new', 'show', 'buffalo', 'ask', 'opener', 'happy'],
#  ['made', 'new', 'really', 'fun', 'work', 'follow', 'want', 'keep'],
#  [],
#  [],
#  ['post', 'show', 'blue', 'hard', 'unhappy'],
#  ['supreme',
#   'court',
#   'chance',
#   'oppose',
#   'judge',
#   'appointment',
#   'national',
#   'security'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  [],
#  ['supreme', 'court', 'ruling', 'race'],
#  ['tutorial',
#   'distinguishing',
#   'information',
#   'knowledge',
#   'start',
#   'pm',
#   'happy'],
#  ['civic', 'poll', 'counting', 'begin', 'today', 'result'],
#  [],
#  ['want', 'choke', 'unhappy'],
#  ['put', 'password', 'wi', 'fi'],
#  ['development', 'filling', 'also', 'death'],
#  ['guess', 'getting', 'unicorn', 'sold', 'unhappy'],
#  ['day', 'left', 'arm'],
#  ['crept'],
#  ['project', 'test'],
#  ['think', 'one', 'part', 'body'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['supreme', 'court', 'chicken'],
#  ['also'],
#  [],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want'],
#  ['note', 'crunch', 'glass'],
#  ['dhow', 'al'],
#  ['heart', 'sad', 'hate', 'people'],
#  ['personnel', 'paramilitary'],
#  ['private', 'follow', 'flying', 'ban'],
#  ['erupt'],
#  ['havent', 'early', 'school', 'since', 'last', 'semester', 'unhappy'],
#  ['hear', 'various', 'constitutional', 'legitimacy', 'today'],
#  ['give', 'like', 'happy', 'choice'],
#  ['could', 'gain', 'partnership'],
#  ['governor', 'form', 'government'],
#  ['news'],
#  ['way', 'change', 'classification', 'bypass', 'order'],
#  ['enjoy', 'happy'],
#  ['leader', 'shot', 'dead', 'late', 'last', 'night'],
#  ['memorial'],
#  ['turned', 'back', 'day', 'get', 'dual', 'stream', 'setup', 'sorted'],
#  [],
#  ['ray'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want', 'free'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['still', 'bedroom', 'going', 'happy'],
#  ['new', 'video', 'game', 'super', 'happy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['skull', 'protest'],
#  ['would', 'great', 'trick', 'happy'],
#  ['see'],
#  ['little', 'video', 'made', 'love', 'life'],
#  ['miss', 'boy', 'sick', 'unhappy'],
#  ['unsold', 'stock'],
#  ['removal', 'scare'],
#  ['lead', 'greatness'],
#  ['know', 'unhappy'],
#  ['nephew', 'proxy'],
#  ['got', 'longer', 'unhappy'],
#  ['tweet', 'want', 'included', 'scrapbook', 'making', 'something'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['thanks',
#   'recent',
#   'follow',
#   'happy',
#   'connect',
#   'happy',
#   'great',
#   'want',
#   'free'],
#  ['merge', 'bank', 'greater', 'outreach'],
#  ['nope', 'unhappy'],
#  ['relief', 'small'],
#  ['cried', 'racism'],
#  ['tested', 'sweet', 'sweet'],
#  ['growth', 'rate', 'industrial', 'sector', 'moderate'],
#  ['cry', 'joy'],
#  ['happening', 'get', 'game', 'different'],
#  ['new', 'upcoming', 'revealed'],
#  ['look', 'like', 'ignore', 'racing', 'unhappy'],
#  ['could', 'write', 'theoretically', 'impossible', 'real', 'life', 'unhappy'],
#  ['potboiler'],
#  ['sad', 'unhappy'],
#  ['parliament'],
#  ['salary'],
#  ['mission', 'nice', 'day', 'though'],
#  ['great', 'night', 'hope', 'strip', 'club', 'happy', 'photo'],
#  ['want', 'drink', 'unhappy'],
#  ['quits'],
#  ['congratulate', 'people'],
#  ['sworn', 'chief', 'minister', 'tomorrow'],
#  ['russel', 'noodle', 'unhappy'],
#  ['want', 'permanent'],
#  ['satisfied', 'policy'],
#  [],
#  ['last', 'kiss', 'unhappy'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['unhappy'],
#  ['ram'],
#  [],
#  ['check', 'happy'],
#  ['clay', 'love', 'deserved', 'unhappy'],
#  ['miss', 'temperance', 'booth', 'much', 'unhappy'],
#  ['sorry', 'see', 'tweet', 'unhappy', 'please', 'could', 'address', 'look'],
#  [],
#  ['love', 'song'],
#  ['gone', 'day', 'work', 'work', 'work', 'unhappy'],
#  ['knight', 'day', 'pick', 'something', 'nice'],
#  ['economic', 'blockade', 'impact', 'process'],
#  ['never', 'happy'],
#  ['politics'],
#  ['also'],
#  ['new', 'one', 'bit', 'unstable', 'unhappy'],
#  ['happy'],
#  ['people', 'abuse', 'unhappy', 'loyal'],
#  ['state', 'bank', 'profit'],
#  ['oh'],
#  ['put', 'fire'],
#  ['unhappy', 'oki', 'welcome', 'sam'],
#  [],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['undercurrent', 'led', 'surge', 'story'],
#  [],
#  [],
#  ['allow', 'name'],
#  ['inspiration', 'fashion'],
#  ['dope', 'cool', 'word', 'finally', 'hip', 'young', 'smile'],
#  ['religious'],
#  ['would', 'awesome'],
#  ['rise'],
#  ['setting',
#   'judge',
#   'constitution',
#   'bench',
#   'decide',
#   'appeal',
#   'verdict',
#   'holding'],
#  ['ministry'],
#  ['also'],
#  ['admit', 'vanity'],
#  ['stayed', 'phone', 'ad', 'miss', 'unhappy'],
#  ['non', 'teaching', 'staff', 'call', 'end', 'stir'],
#  ['livid'],
#  ['yo', 'thank'],
#  [],
#  ['unruly',
#   'behaviour',
#   'violence',
#   'aviation',
#   'network',
#   'regrettable',
#   'incident'],
#  ['security', 'need'],
#  [],
#  ['trouble', 'play'],
#  ['round', 'as', 'cry'],
#  ['day', 'new', 'follower', 'happy', 'via'],
#  ['suppose', 'waiting', 'happy'],
#  ['bounty', 'damage', 'bill'],
#  ['groovy', 'happy'],
#  ['happen', 'easter', 'one', 'best', 'day', 'unhappy'],
#  ['wake',
#   'tomorrow',
#   'body',
#   'gotten',
#   'head',
#   'start',
#   'waking',
#   'every',
#   'day',
#   'week',
#   'unhappy'],
#  ['supreme', 'court', 'decided', 'future', 'rival'],
#  ['cloud', 'also'],
#  ['day', 'new', 'happy', 'via'],
#  ['break', 'russia'],
#  ['forever', 'trapped', 'void', 'realm', 'unhappy'],
#  ['cricket', 'body'],
#  ['hey', 'could', 'help', 'legitimate', 'really', 'need', 'account', 'rig'],
#  ['road', 'economy'],
#  ['president', 'supporting', 'legislation', 'related'],
#  ['gesture', 'spot'],
#  ['agree', 'issue', 'would', 'somehow', 'see', 'sad'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['motivation', 'study', 'unhappy'],
#  ['peacefully', 'sitting', 'reading', 'book', 'work'],
#  ['hacked', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  [],
#  ['order'],
#  ['idea', 'wrong'],
#  ['got', 'vive', 'tracker', 'office', 'intern'],
#  ['actually', 'cry', 'tweet', 'take', 'applicable', 'knock', 'unhappy'],
#  ['right', 'happy', 'still', 'condition'],
#  ['life', 'dark', 'corner', 'become', 'magical', 'got', 'st', 'year'],
#  ['sadly',
#   'yes',
#   'since',
#   'continue',
#   'losing',
#   'support',
#   'dropping',
#   'unhappy',
#   'going'],
#  ['next', 'question', 'unhappy'],
#  ['help',
#   'want',
#   'stop',
#   'feel',
#   'endless',
#   'suffering',
#   'pain',
#   'tried',
#   'deactivate',
#   'many',
#   'time',
#   'save',
#   'unhappy'],
#  ['cute', 'picture', 'though'],
#  ['supreme',
#   'court',
#   'trial',
#   'court',
#   'verdict',
#   'holding',
#   'corruption',
#   'case'],
#  ['looking',
#   'forward',
#   'come',
#   'see',
#   'booth',
#   'going',
#   'right',
#   'center',
#   'field',
#   'happy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['maybe', 'band', 'definitely', 'hi', 'name', 'happy'],
#  ['helm'],
#  ['editorial', 'mayor', 'cannot'],
#  ['aerobatic', 'display', 'inaugural'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'cont'],
#  ['said', 'silence', 'morgan', 'freeman', 'voice', 'happy'],
#  ['want', 'give', 'everything', 'happy', 'see', 'smile', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['sup'],
#  ['spell'],
#  ['development'],
#  ['remember',
#   'knowledge',
#   'worth',
#   'grade',
#   'announce',
#   'winner',
#   'tomorrow',
#   'morning',
#   'am',
#   'happy',
#   'purchase',
#   'happy'],
#  ['well', 'done', 'welcome', 'happy'],
#  ['entering', 'system', 'via', 'business', 'district'],
#  ['tweet', 'made', 'cry', 'cry'],
#  ['surround', 'positivity', 'happy'],
#  ['want', 'unhappy', 'yummy'],
#  ['routine', 'enforcement', 'surge'],
#  ['seeking', 'restrain', 'chief', 'minister', 'tomorrow'],
#  ['mine', 'back', 'say', 'happy'],
#  ['thanks', 'recent', 'follow'],
#  ['thought',
#   'mountain',
#   'dew',
#   'caffeine',
#   'little',
#   'energy',
#   'drink',
#   'never',
#   'sleep',
#   'unhappy'],
#  ['ban'],
#  [],
#  ['clear', 'right', 'speaker', 'decide'],
#  ['better', 'check'],
#  ['really', 'really', 'bloody', 'cry', 'joy'],
#  ['video'],
#  ['guilty', 'murder'],
#  ['thanks', 'great', 'review', 'smile'],
#  ['question', 'banking', 'switching', 'old'],
#  ['sweep', 'hand', 'puppet', 'bastard', 'lost', 'squeak', 'unhappy'],
#  ['want', 'meet', 'bad', 'unhappy'],
#  ['join', 'vote', 'singer', 'spread', 'word'],
#  ['note', 'self', 'dont', 'get', 'attached', 'cry'],
#  ['might', 'dressed', 'bit', 'better'],
#  ['someone', 'unhappy', 'available'],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['still', 'sign', 'small', 'area', 'would', 'obvious', 'sad', 'quite'],
#  ['make', 'cry', 'joy', 'need'],
#  ['way', 'home', 'happy', 'happy', 'si', 'sa'],
#  ['today'],
#  ['keep_smiling_y'],
#  ['victory', 'may', 'bad', 'news'],
#  ['maybe'],
#  ['finance', 'minister', 'given', 'additional', 'charge', 'ministry'],
#  ['friend', 'smile'],
#  ['phone', 'possibility', 'chance', 'would', 'notice', 'unhappy'],
#  ['house', 'till', 'pm'],
#  ['like', 'jittery', 'caffeine', 'sad'],
#  ['latest', 'school'],
#  ['road', 'safety', 'crusader', 'fight', 'bid', 'bypass', 'order', 'highway'],
#  ['love'],
#  [],
#  ['still', 'live'],
#  ['honestly',
#   'college',
#   'want',
#   'curl',
#   'ball',
#   'cry',
#   'day',
#   'straight',
#   'unhappy'],
#  ['summer', 'salad', 'inspiration', 'smile'],
#  ['siltation', 'threat', 'national', 'waterway'],
#  ['waiting', 'jail', 'break', 'happy'],
#  ['sad', 'unhappy'],
#  ['gone', 'house', 'whilst', 'flying', 'drone', 'happy'],
#  ['really', 'appreciate', 'hope', 'brilliant', 'day', 'happy'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['versus', 'cry', 'joy'],
#  ['miss', 'sad'],
#  ['happy', 'weed', 'day', 'without', 'unhappy'],
#  ['get', 'unhappy', 'ratio', 'amazing'],
#  ['made', 'day', 'great', 'story', 'happy'],
#  ['nation', 'must', 'begin', 'new', 'life'],
#  ['afraid'],
#  ['thanks', 'recent', 'follow', 'much', 'happy'],
#  ['really', 'serious', 'hope', 'judge', 'unhappy'],
#  ['menu', 'dinner', 'praise', 'praise'],
#  ['slipped', 'secrecy', 'clause'],
#  ['also', 'attractive', 'happy'],
#  ['really', 'really', 'need', 'right', 'unhappy'],
#  ['oh', 'god', 'unhappy', 'next', 'time'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['firing', 'underway'],
#  ['think', 'going', 'true'],
#  ['brutally',
#   'respectable',
#   'suit',
#   'enjoy',
#   'happy',
#   'contrast',
#   'appreciate',
#   'mo'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['prime', 'minister', 'made', 'man', 'beat'],
#  ['mystery', 'effect', 'data'],
#  ['today', 'annual', 'crore'],
#  [],
#  ['bore'],
#  ['yet'],
#  ['made', 'ensure', 'free', 'fair', 'election'],
#  ['noted', 'sir'],
#  ['miss', 'unhappy'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['pinned', 'tweet', 'patient', 'saved', 'happy'],
#  ['unhappy', 'damn', 'sad'],
#  ['airlift', 'blockade'],
#  [],
#  ['wish', 'could', 'vote', 'unhappy'],
#  ['rd', 'episode', 'everyone', 'sure', 'check', 'happy'],
#  ['molten', 'tar', 'family'],
#  ['happy'],
#  ['drive', 'become', 'chief', 'minister'],
#  ['court',
#   'summons',
#   'suspended',
#   'accused',
#   'criminal',
#   'defamation',
#   'plea'],
#  ['million', 'offering', 'smile'],
#  ['tweet', 'getting', 'holding', 'sticker', 'click', 'tweet'],
#  ['also', 'support'],
#  ['see', 'cry', 'today'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['much', 'free', 'legit', 'free', 'follow', 'first', 'get', 'patient'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lotus', 'garden'],
#  ['may', 'open', 'happy'],
#  ['rape', 'accused', 'leader', 'gayatri', 'roaming'],
#  ['cash', 'today'],
#  ['honestly',
#   'think',
#   'trying',
#   'get',
#   'rid',
#   'make',
#   'mockery',
#   'town',
#   'wont',
#   'admit',
#   'unhappy'],
#  ['girl', 'unhappy', 'wa', 'unnecessarily', 'expensive', 'try'],
#  ['happy', 'new', 'video', 'happy'],
#  ['baby'],
#  ['miss', 'unhappy'],
#  ['impartial', 'probe'],
#  ['army', 'key', 'highway', 'suffering'],
#  ['use', 'happy'],
#  ['pretty', 'happy'],
#  ['friend', 'promise', 'meant', 'broken'],
#  ['panic', 'top', 'hospital'],
#  ['miss', 'boo', 'much', 'unhappy'],
#  ['said'],
#  ['day', 'new', 'follower', 'happy', 'via'],
#  [],
#  ['lost', 'unhappy'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['unhappy', 'sorry', 'hear'],
#  ['miss', 'baby', 'unhappy'],
#  ['state', 'fourth', 'estate'],
#  ['half', 'naked', 'happy'],
#  ['sign'],
#  ['could', 'meet', 'next', 'time'],
#  ['governor', 'meet', 'new', 'legislature', 'party', 'leader', 'pm'],
#  ['stone', 'miss', 'brother', 'message'],
#  ['list'],
#  ['well'],
#  ['court', 'allow', 'trooper', 'wife', 'meet'],
#  [],
#  ['lost'],
#  ['medical', 'shorthand', 'abbreviation', 'use', 'work'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['supreme', 'court', 'highway', 'booze', 'hatch'],
#  ['girl', 'also'],
#  ['hope', 'time', 'come', 'back', 'fresh', 'happy', 'happy'],
#  ['become', 'apart', 'lose', 'happy'],
#  ['currently',
#   'standing',
#   'outside',
#   'shard',
#   'bag',
#   'full',
#   'empty',
#   'came',
#   'work',
#   'today',
#   'happy']]

# %%
vectors = list(map(lambda word: w2v.wv[word], testing_docs))

vectors[:1]
# Out:
# [array([ 0.00238459, -0.03510084, -0.09075089, -0.01923401, -0.07362858,
#         -0.0351901 , -0.04651758,  0.02633143, -0.00778141,  0.07152639,
#         -0.18311621, -0.02533881, -0.12324546, -0.0891151 , -0.1748734 ,
#         -0.0948323 , -0.0228548 , -0.09283423,  0.07747453,  0.11168096,
#          0.01514961,  0.00600822, -0.10589401,  0.06043209, -0.01824423,
#          0.12368233,  0.07921502, -0.13378091,  0.00426658, -0.11942744,
#         -0.12330525, -0.1123973 , -0.1258716 ,  0.06898737, -0.187171  ,
#         -0.04723676, -0.02984368, -0.15233803, -0.01727172, -0.1342542 ,
#         -0.02071373, -0.09113612,  0.21011426, -0.01502392, -0.06103258,
#         -0.05154557,  0.22392108, -0.05037166,  0.19439599,  0.05712034,
#         -0.07022048,  0.04029144,  0.04544317, -0.00638363, -0.060417  ,
#         -0.10512706,  0.01641648, -0.02564002, -0.00808017,  0.10630167,
#         -0.02908321, -0.00245452, -0.09934234,  0.04758047,  0.05943349,
#          0.04119796, -0.16798595,  0.04287523, -0.06476748,  0.11654128,
#         -0.15798013,  0.02676976, -0.11344105, -0.00400706, -0.15008213,
#          0.06950454,  0.09089266,  0.19698323,  0.08820403,  0.17430986,
#          0.15082195, -0.08846921,  0.05966157, -0.16066433, -0.03258578,
#          0.10419343, -0.02441876, -0.01068014,  0.01172994, -0.03980823,
#         -0.13213143,  0.03927487, -0.02408975, -0.00929624,  0.02569899,
#         -0.04163064, -0.01893525, -0.0840556 ,  0.11590768,  0.04903567,
#          0.24667457, -0.07512411, -0.01316146,  0.05333574, -0.13177413,
#         -0.06877416,  0.00520505, -0.08174483,  0.06824394,  0.06334936,
#         -0.0841013 , -0.13039607, -0.18430874,  0.03344997, -0.05892751,
#         -0.06239882,  0.06149381,  0.03351857, -0.08687901,  0.0689979 ,
#          0.04590095, -0.07496714, -0.16624217,  0.11988853,  0.10298354,
#          0.01104363,  0.00605968, -0.07627267, -0.09154437, -0.01058485,
#          0.05336906, -0.11095362, -0.06375919, -0.15093975, -0.04624941,
#         -0.13279217,  0.18731563,  0.00245301, -0.17765372,  0.0211579 ,
#          0.10867356, -0.19511874, -0.09671043, -0.24915157, -0.11770087,
#          0.07631732, -0.04132013, -0.02181869,  0.00862398,  0.20870475],
#        dtype=float32)]

# %%
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

from sklearn import metrics

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5548120141029358
# Calinski-Harabaz Index: 1024.0996385567587
# Davies-Bouldin Index: 0.6553123301704322

# %%
first_index = last_index
last_index = int(len(documents.index)/ 5 * 2)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5404684543609619
# Calinski-Harabaz Index: 1047.129095337243
# Davies-Bouldin Index: 0.6600749432326024

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 3)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5429835319519043
# Calinski-Harabaz Index: 1088.1915405290952
# Davies-Bouldin Index: 0.6466463975469459

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 4)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5231156349182129
# Calinski-Harabaz Index: 966.8132630231855
# Davies-Bouldin Index: 0.6940759534807669

# %%
first_index = last_index
last_index = int(len(documents.index))
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5257409811019897
# Calinski-Harabaz Index: 1004.2611452756448
# Davies-Bouldin Index: 0.700394942856913
