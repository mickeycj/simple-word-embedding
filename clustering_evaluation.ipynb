# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from gensim.utils import simple_preprocess
import nltk
from nltk.stem.wordnet import WordNetLemmatizer

english_words = set(nltk.corpus.words.words())
english_stop_words = nltk.corpus.stopwords.words("english")

lemmatizer = WordNetLemmatizer()

def preprocess(text):
    return " ".join(lemmatizer.lemmatize(w) for w in nltk.wordpunct_tokenize(text)
        if w.lower() in english_words and w.lower() not in english_stop_words or not w.isalpha())

def tokenize(document):
    return simple_preprocess(str(document).encode("utf-8"))

# %%
import pandas as pd

dname = './data/preprocessed-twitter-tweets'

pos = pd.read_csv('{}/{}.csv'.format(dname, 'processedPositive')).T
neu = pd.read_csv('{}/{}.csv'.format(dname, 'processedNeutral')).T
neg = pd.read_csv('{}/{}.csv'.format(dname, 'processedNegative')).T

documents = pd.concat([pos, neu, neg])
documents['tweets'] = documents.index
documents = documents.sample(frac=1).reset_index(drop=True)

documents.head(15)
# Out:
#                                                tweets
# 0                          If you live only for money
# 1   i find it so difficult to says no to him unhap...
# 2   No merit in claims that can be tampered with; ...
# 3                my favourite lipstick hilang crying
# 4   I'm scared unhappy  I mean. Why the heck did I...
# 5                       Wow awesome GOG! thanks happy
# 6                             Preacher...... unhappy
# 7    govt sparks traffic chaos with plans for gran...
# 8   this is damn.... theres people who sincerely w...
# 9   Supreme Court gives govt a chance to oppose ju...
# 10                               he could be whatever
# 11                    1 short of two-thirds majority.
# 12          Bihar to tell why govt rejected an idea.
# 13                                   love it unhappy
# 14  Members from camp meet Assembly Speaker P Dhan...

# %%
training_docs = []
num_docs = float(len(documents.index))
for _, row in documents.iterrows():
    training_docs.append(tokenize(preprocess(row['tweets'])))

training_docs
# Out:
# [['live', 'money'],
#  ['find', 'difficult', 'unhappy'],
#  ['merit', 'wild', 'baseless'],
#  ['lipstick', 'cry'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['wow', 'awesome', 'gog', 'thanks', 'happy'],
#  ['preacher', 'unhappy'],
#  ['spark', 'traffic', 'chaos', 'grand', 'gate'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['supreme',
#   'court',
#   'chance',
#   'oppose',
#   'judge',
#   'appointment',
#   'national',
#   'security'],
#  ['could', 'whatever'],
#  ['short', 'two', 'majority'],
#  ['tell', 'idea'],
#  ['love', 'unhappy'],
#  ['camp', 'meet', 'assembly', 'speaker'],
#  ['moment'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['former', 'captain', 'team'],
#  ['riot', 'refugee', 'resolve', 'also'],
#  ['hold', 'st', 'cabinet', 'meeting', 'today'],
#  ['thank', 'much', 'friend', 'smile'],
#  ['reason', 'last', 'miss', 'like', 'month', 'notice', 'unhappy'],
#  ['front'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['would', 'going', 'prison', 'unhappy'],
#  ['man', 'phone', 'made', 'like', 'always', 'wink'],
#  ['private', 'fear', 'plan', 'monitor', 'give', 'local', 'death', 'grip'],
#  ['could', 'meet', 'next', 'time'],
#  ['miss', 'baby', 'unhappy'],
#  ['wolf', 'bite', 'yet', 'happy', 'help', 'get', 'steam'],
#  ['definitely', 'looking', 'gave', 'try', 'anyway', 'happy'],
#  ['body', 'everything', 'mind', 'kind'],
#  ['quiz', 'industry'],
#  ['lose'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['unhappy'],
#  ['build', 'case'],
#  ['cast', 'shadow'],
#  ['definitely', 'arm', 'unhappy'],
#  ['happy', 'ming', 'love', 'love', 'happy'],
#  [],
#  ['saved', 'death', 'eclipse'],
#  ['sad', 'say', 'actually', 'remember', 'unhappy', 'happen'],
#  [],
#  ['extradition', 'could', 'take'],
#  ['still', 'cant', 'unhappy'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['future', 'get', 'wrong'],
#  ['turn', 'avenger'],
#  [],
#  ['unhappy'],
#  ['hard', 'notice', 'unhappy'],
#  ['also'],
#  ['childish', 'commando', 'happy'],
#  ['adopted', 'son'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lost', 'one', 'import', 'unhappy'],
#  ['know', 'sorry', 'enough', 'sorry', 'unhappy'],
#  ['wait', 'see', 'film', 'wished', 'would', 'bu'],
#  [],
#  [],
#  ['mission', 'restore', 'complex'],
#  ['ask', 'two', 'special', 'lined', 'unhappy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['dope', 'cool', 'word', 'finally', 'hip', 'young', 'smile'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['snap'],
#  ['come', 'back', 'unhappy'],
#  ['ahead'],
#  ['happy', 'belated', 'birthday', 'another', 'duet', 'much'],
#  ['super', 'unhappy'],
#  ['may', 'show'],
#  ['twitter', 'premium', 'version', 'free', 'service'],
#  ['midst', 'incendiary', 'wish'],
#  [],
#  ['happy'],
#  ['question', 'happy'],
#  ['struggle', 'unhappy'],
#  ['attack'],
#  ['today'],
#  ['miss', 'already', 'unhappy'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  [],
#  ['air', 'tighten', 'security', 'stall'],
#  ['also'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['half', 'time', 'load'],
#  [],
#  ['cosmic', 'give', 'month', 'unhappy'],
#  ['happy', 'happy'],
#  ['celebrate', 'uncelebrated'],
#  ['happy'],
#  ['return', 'unit'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['keep', 'awake', 'happy'],
#  ['tired', 'nothing', 'great', 'unhappy'],
#  ['decide',
#   'new',
#   'legislative',
#   'party',
#   'leader',
#   'future',
#   'course',
#   'action',
#   'also'],
#  ['prefer',
#   'enjoy',
#   'happy',
#   'km',
#   'away',
#   'also',
#   'quite',
#   'nice',
#   'honestly',
#   'anywhere',
#   'away',
#   'crazy'],
#  ['feel', 'bad', 'unhappy'],
#  ['last', 'kiss', 'unhappy'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['am', 'forget', 'eat', 'breakfast', 'happy'],
#  ['also'],
#  [],
#  ['fighting'],
#  ['feeling'],
#  ['bit', 'rusty', 'unhappy'],
#  ['lost', 'deposit', 'garden', 'stronghold'],
#  ['go'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['motivation', 'study', 'unhappy'],
#  ['oil', 'hit', 'three', 'month', 'low', 'rig', 'count'],
#  ['year', 'old', 'new', 'ladylike', 'trust', 'troll'],
#  ['zoo', 'mark'],
#  ['come', 'back', 'ghost', 'unhappy', 'love'],
#  ['definitely', 'arm', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['get', 'accept', 'calf'],
#  ['puzzle', 'like', 'next', 'please'],
#  ['raj', 'calling', 'party', 'form', 'government'],
#  ['good', 'watch', 'tv', 'application', 'free', 'happy'],
#  ['thanks', 'happy'],
#  ['hope'],
#  ['ready',
#   'one',
#   'week',
#   'old',
#   'chocolate',
#   'female',
#   'puppy',
#   'sterling',
#   'happy',
#   'girl',
#   'sweetheart'],
#  ['get', 'help', 'un'],
#  ['help', 'unhappy', 'early', 'birthday', 'gift'],
#  ['hair', 'crisp', 'unhappy'],
#  ['sup'],
#  ['history', 'around'],
#  ['autonomy'],
#  [],
#  ['supreme', 'court', 'caution', 'stealing'],
#  ['would', 'love', 'guest', 'sometime', 'minute', 'smile', 'interested'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['report'],
#  ['sign'],
#  ['work', 'get', 'backing'],
#  ['friendly', 'service'],
#  ['unhappy', 'fairly', 'warm'],
#  ['beyond', 'sad', 'unhappy'],
#  ['confusion'],
#  ['tried', 'still', 'unhappy'],
#  [],
#  ['unhappy'],
#  ['increase', 'ordered'],
#  ['editorial', 'mayor', 'cannot'],
#  ['old', 'continue'],
#  ['definitely', 'arm', 'unhappy'],
#  ['bow', 'story'],
#  ['unnamed'],
#  ['need', 'direct', 'coffee', 'feed', 'happy'],
#  ['sad'],
#  ['hi', 'instant', 'message', 'friend', 'friend'],
#  ['look', 'good', 'current', 'shame', 'never', 'cut', 'unhappy'],
#  ['tale', 'prime'],
#  ['stay', 'cool'],
#  ['greatness', 'winning'],
#  ['good', 'evening', 'happy'],
#  ['guess',
#   'getting',
#   'much',
#   'acting',
#   'work',
#   'day',
#   'much',
#   'time',
#   'unhappy'],
#  ['finished', 'gym'],
#  ['lost',
#   'two',
#   'two',
#   'favorite',
#   'people',
#   'silence',
#   'unhappy',
#   'good',
#   'night'],
#  ['enforcement', 'directorate', 'chief', 'singh', 'fixed', 'tenure'],
#  ['cloaked', 'debate'],
#  ['may', 'open', 'happy'],
#  ['care',
#   'youth',
#   'mental',
#   'health',
#   'rw',
#   'show',
#   'young',
#   'audience',
#   'graphic',
#   'rape',
#   'suicide'],
#  ['think', 'probably', 'beyond', 'repair', 'tea', 'etiquette', 'happy'],
#  ['happy'],
#  ['ill', 'fitting'],
#  ['rd', 'episode', 'everyone', 'sure', 'check', 'happy'],
#  ['say'],
#  ['awesome'],
#  ['scrap'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['damn', 'unfortunate', 'unhappy'],
#  ['best', 'damn', 'avocado', 'batsyy_'],
#  ['denial', 'normal', 'say'],
#  ['trump'],
#  ['divide', 'woo', 'home', 'turf'],
#  ['take', 'season'],
#  ['want',
#   'someone',
#   'little',
#   'back',
#   'trace',
#   'thing',
#   'put',
#   'sleep',
#   'unhappy'],
#  ['want',
#   'cant',
#   'go',
#   'unhappy',
#   'honestly',
#   'like',
#   'messy',
#   'break',
#   'unhappy'],
#  ['let', 'alone', 'free'],
#  ['please', 'follow', 'trying', 'long', 'unhappy', 'love', 'much', 'baby'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['beetle', 'litchi', 'crop'],
#  [],
#  ['music', 'direction'],
#  ['piss', 'cry'],
#  ['death', 'currency'],
#  ['gazette', 'wont', 'applied', 'retrospectively', 'admitted'],
#  ['also'],
#  [],
#  [],
#  ['happy'],
#  ['message', 'us'],
#  ['suspended'],
#  ['know', 'really', 'stranger', 'satisfied', 'entertainment', 'provide'],
#  ['defence', 'minister'],
#  ['emergency', 'clause', 'end'],
#  ['great'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['best', 'please'],
#  ['like', 'happy'],
#  ['us', 'scare'],
#  ['long', 'time', 'chat', 'sad'],
#  ['love', 'ben', 'get', 'watch', 'want', 'without', 'interruption', 'happy'],
#  ['funds', 'fear', 'research'],
#  ['belt', 'party'],
#  ['match', 'versus', 'gut', 'feeling', 'dig', 'supreme', 'court', 'also'],
#  ['time', 'something', 'ot'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['healthy'],
#  ['also'],
#  ['entertaining', 'insightful', 'one', 'really', 'enjoying', 'lot', 'season'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['bedroom', 'journalism', 'trial'],
#  ['perfectly', 'happy', 'got'],
#  ['hey', 'thanks', 'follow', 'coastal', 'living', 'mean', 'reply', 'photo'],
#  ['yet',
#   'invest',
#   'child',
#   'emotional',
#   'education',
#   'taking',
#   'child',
#   'school',
#   'holiday',
#   'early',
#   'un'],
#  ['poor', 'baby', 'unhappy', 'hate', 'people'],
#  ['bill', 'check'],
#  ['today', 'congress', 'address'],
#  ['thanks', 'great', 'review', 'smile'],
#  ['short', 'thanks', 'friend'],
#  ['supreme', 'court', 'explain', 'need', 'censorship'],
#  ['court', 'death'],
#  ['good', 'news', 'thriving', 'reserve'],
#  ['spent', 'night', 'filling', 'breach', 'wall'],
#  ['happy'],
#  ['like', 'one', 'song', 'really', 'love'],
#  ['addition'],
#  ['quickly'],
#  ['print', 'edition', 'today'],
#  ['suspect', 'attack'],
#  ['model'],
#  ['true', 'waste', 'day', 'social', 'medium', 'reading', 'hand'],
#  ['court', 'probe', 'corruption', 'charge'],
#  ['stayed', 'phone', 'ad', 'miss', 'unhappy'],
#  ['unhappy'],
#  ['headline',
#   'inflation',
#   'measured',
#   'consumer',
#   'price',
#   'index',
#   'control',
#   'third',
#   'successive',
#   'financial',
#   'year'],
#  ['right', 'seriously', 'need', 'decent', 'butterfly', 'tattoo', 'design'],
#  ['professional',
#   'much',
#   'want',
#   'help',
#   'death',
#   'might',
#   'make',
#   'situation'],
#  ['miss', 'unhappy'],
#  ['thanks',
#   'recent',
#   'follow',
#   'happy',
#   'connect',
#   'happy',
#   'great',
#   'want',
#   'free'],
#  ['happy'],
#  ['good', 'show', 'next', 'jump'],
#  ['bore'],
#  ['days', 'good'],
#  ['happy', 'kyle'],
#  ['mutton'],
#  ['froze', 'mid', 'install', 'hrs', 'pull', 'plug', 'cry'],
#  ['welcome', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['say', 'hi', 'unhappy'],
#  ['live', 'resignation'],
#  ['excited',
#   'ball',
#   'start',
#   'smile',
#   'baby',
#   'minor',
#   'absolutely',
#   'love',
#   'watching',
#   'play'],
#  ['many', 'mine', 'talk', 'sexually', 'past', 'found', 'another', 'unhappy'],
#  ['want', 'go', 'game', 'unhappy'],
#  [],
#  ['whimper'],
#  ['bad', 'idea'],
#  ['new', 'era', 'amity'],
#  ['customer', 'journey', 'keynote', 'partner', 'event', 'incredible', 'event'],
#  ['really', 'zero', 'dawn', 'idea', 'play', 'next', 'unhappy'],
#  ['good', 'luck', 'swampy', 'happy'],
#  ['happy', 'everyone', 'happy'],
#  ['got', 'rest'],
#  ['chief', 'minister'],
#  ['get', 'unhappy', 'ratio', 'amazing'],
#  ['negative', 'pit', 'unhappiness'],
#  ['march', 'siege', 'parliament'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['boycott', 'parliament', 'raincoat', 'remark'],
#  ['raj', 'tender', 'resignation'],
#  ['backed', 'prevent', 'legal'],
#  ['operator', 'acquire', 'business', 'seven', 'spectrum'],
#  ['growth', 'rate', 'industrial', 'sector', 'moderate'],
#  ['tonight'],
#  ['alpha', 'invitation', 'well', 'received', 'happy'],
#  ['getting', 'morning', 'hassle', 'unhappy'],
#  ['thanks', 'passionate', 'hope', 'like', 'happy'],
#  ['miss', 'petite', 'happy', 'happy', 'looking', 'forward', 'weekend'],
#  [],
#  ['old', 'twitter', 'unhappy'],
#  ['unhappy'],
#  ['supreme',
#   'court',
#   'response',
#   'plea',
#   'frame',
#   'national',
#   'policy',
#   'promote'],
#  ['myth', 'good', 'team'],
#  ['one', 'meeting'],
#  ['well'],
#  [],
#  ['stock', 'home', 'syndrome'],
#  ['find'],
#  ['miss', 'bedroom', 'unhappy'],
#  ['returned', 'warm', 'welcome'],
#  ['accepted', 'resignation', 'council', 'immediate'],
#  ['trying',
#   'bank',
#   'sleep',
#   'week',
#   'happy',
#   'doubt',
#   'able',
#   'sleep',
#   'night'],
#  ['may', 'able', 'hold', 'college', 'year'],
#  ['law', 'take', 'course', 'occupation', 'doesnt', 'end'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['village', 'bridge'],
#  ['march', 'ft', 'long', 'flag'],
#  ['supreme', 'court', 'may', 'hear', 'key', 'summer', 'break'],
#  ['top', 'make', 'pay', 'cash'],
#  ['question', 'banking', 'switching', 'old'],
#  [],
#  ['cheer', 'new', 'administrator', 'team', 'happy'],
#  ['surround', 'positivity', 'happy'],
#  ['come', 'prey'],
#  ['tried', 'new', 'trying', 'dumb', 'life'],
#  ['focus'],
#  ['dude'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['mine', 'back', 'say', 'happy'],
#  ['crude', 'architecture', 'taking', 'world', 'city'],
#  ['keep', 'trying', 'quit', 'work', 'unhappy', 'pick', 'please', 'give'],
#  ['ha', 'unhappy'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['unit', 'finally', 'full', 'time', 'chief'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['days', 'ram'],
#  ['especially', 'people', 'low', 'patience', 'level', 'happy'],
#  ['hi', 'please', 'pinned', 'post', 'happy'],
#  ['love'],
#  ['visit', 'today', 'st', 'time', 'taking', 'oath'],
#  ['much', 'happy', 'want'],
#  ['spike'],
#  ['thanks'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['naming', 'game'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy'],
#  ['flash', 'khan'],
#  ['manifesto'],
#  [],
#  ['fix', 'soon', 'delay', 'tomorrow', 'unhappy'],
#  ['let', 'forget', 'also', 'white', 'birthday', 'today', 'miss', 'unhappy'],
#  ['hi', 'cham'],
#  ['cry'],
#  ['keep', 'unhappy'],
#  ['great', 'work', 'lovely', 'place', 'thank'],
#  ['theory', 'population'],
#  ['indirect', 'happy'],
#  ['old', 'leyland'],
#  ['bot', 'perfect', 'happy'],
#  ['work', 'morning', 'unhappy'],
#  ['heartland', 'lab'],
#  ['welfare'],
#  ['take'],
#  ['coo', 'pay', 'hike'],
#  [],
#  ['also'],
#  ['happy', 'see', 'closer', 'con', 'five'],
#  ['better', 'unhappy'],
#  ['middleman', 'nephew', 'bribe', 'election', 'commission'],
#  ['like', 'happy'],
#  ['tested', 'sweet', 'sweet'],
#  ['unnamed'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['unhappy'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['late', 'night'],
#  ['wish', 'meeting', 'unhappy'],
#  ['large'],
#  ['treaty',
#   'could',
#   'provide',
#   'security',
#   'tech',
#   'culture',
#   'development',
#   'happy'],
#  ['feared', 'bus', 'river', 'area', 'district', 'police'],
#  ['custom', 'fill', 'unhappy'],
#  ['first',
#   'group',
#   'came',
#   'forward',
#   'yesterday',
#   'racist',
#   'mob',
#   'violence'],
#  [],
#  ['counting', 'constituency'],
#  ['got', 'th', 'add', 'ant', 'possible', 'thanks', 'happy'],
#  ['relate', 'much', 'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['available', 'festival', 'running'],
#  ['happen', 'easter', 'one', 'best', 'day', 'unhappy'],
#  [],
#  ['support'],
#  ['wife', 'split', 'coo'],
#  ['miss', 'unhappy'],
#  ['president', 'supporting', 'legislation', 'related'],
#  ['made', 'ensure', 'free', 'fair', 'election'],
#  ['sudden', 'blaze', 'bungalow'],
#  ['beating', 'two', 'anyway', 'stop', 'match'],
#  ['hard', 'give', 'experience', 'pleasurable', 'pain'],
#  ['ride', 'final', 'unhappy'],
#  ['supreme',
#   'court',
#   'bid',
#   'put',
#   'sport',
#   'ministry',
#   'bureaucrat',
#   'panel',
#   'run'],
#  ['bit', 'tired'],
#  ['leader'],
#  ['livid'],
#  ['much', 'happy'],
#  ['keep_smiling_y'],
#  ['sorry', 'always', 'ask', 'follow', 'happy'],
#  ['parliament'],
#  ['blocked', 'another', 'notch', 'belt', 'happy'],
#  ['soldier', 'painful', 'journey'],
#  ['people', 'propose', 'future', 'happy'],
#  ['case',
#   'meat',
#   'exporter',
#   'graft',
#   'case',
#   'former',
#   'chief',
#   'singh',
#   'also'],
#  ['beauty'],
#  ['great', 'good', 'un', 'unthinkable', 'picture', 'dug', 'mysel'],
#  ['demand', 'justice', 'right', 'cattle', 'trade'],
#  ['good', 'morning', 'never', 'fail', 'make', 'smile', 'happy'],
#  ['economic',
#   'survey',
#   'tabled',
#   'parliament',
#   'shortly',
#   'know',
#   'economic',
#   'survey'],
#  ['also'],
#  ['trump', 'administration', 'economics'],
#  ['may'],
#  ['got', 'unhappy'],
#  ['suddenly', 'miss', 'ate', 'unhappy'],
#  ['might', 'set', 'whole', 'place', 'fire'],
#  ['high', 'commissioner'],
#  ['yogi', 'work'],
#  ['unhappy'],
#  ['cost',
#   'abut',
#   'year',
#   'paying',
#   'half',
#   'full',
#   'education',
#   'get',
#   'treat'],
#  ['seen', 'good'],
#  ['really', 'want', 'one', 'iconic', 'shirt', 'unhappy'],
#  ['nice', 'morning', 'working', 'today', 'lovely', 'atmosphere'],
#  ['end', 'another', 'batch', 'edge', 'happy'],
#  ['better', 'unhappy'],
#  ['people', 'happy'],
#  ['unhappy'],
#  ['st', 'time'],
#  ['watched', 'produce', 'gum', 'poor', 'bless', 'soul', 'unhappy'],
#  ['sixth', 'spot', 'applicable', 'team', 'higher', 'pa'],
#  ['today', 'never', 'forget', 'smile', 'happy'],
#  ['actually', 'live', 'honesty', 'integrity'],
#  ['love', 'daughter', 'cry'],
#  [],
#  [],
#  ['thanks', 'notice'],
#  ['back', 'unhappy'],
#  ['crore'],
#  ['soon', 'make', 'happy'],
#  ['finance', 'minister', 'table'],
#  ['like', 'biggest', 'unhappy'],
#  ['day', 'new', 'happy', 'via'],
#  ['ich', 'unhappy'],
#  ['trying', 'rescue', 'trapped'],
#  ['would',
#   'love',
#   'work',
#   'train',
#   'company',
#   'great',
#   'dream',
#   'come',
#   'true'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['last', 'happy'],
#  ['bought', 'cold', 'storage', 'license', 'west'],
#  ['cant',
#   'find',
#   'striped',
#   'shirt',
#   'unhappy',
#   'instant',
#   'message',
#   'wearing',
#   'one',
#   'favorite',
#   'thing',
#   'middle'],
#  ['super', 'scary', 'unhappy'],
#  ['scheme'],
#  ['deep',
#   'scratch',
#   'paint',
#   'gone',
#   'see',
#   'bare',
#   'metal',
#   'need',
#   'fixed',
#   'avoid',
#   'getting',
#   'car',
#   'soon',
#   'unhappy'],
#  ['thank'],
#  ['sad', 'story', 'unhappy'],
#  ['governor', 'call'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['nope', 'unhappy'],
#  ['small', 'unhappy'],
#  [],
#  ['menace', 'born', 'eating'],
#  ['go', 'way', 'good', 'one', 'extreme', 'driving', 'today', 'smile'],
#  ['polling', 'first', 'phase'],
#  ['join',
#   'celebrate',
#   'earth',
#   'planting',
#   'head',
#   'page',
#   'information',
#   'happy'],
#  ['unhappy', 'unfollowed', 'many', 'people', 'ugh'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['soup', 'slow', 'pork'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['nothing', 'date', 'make'],
#  ['part', 'day', 'everyday', 'leave', 'unhappy'],
#  ['last', 'event', 'chapter'],
#  ['mutual', 'let', 'talk', 'sure', 'mutual', 'happy'],
#  ['stupid'],
#  ['dog', 'family', 'put', 'tomorrow', 'unhappy'],
#  ['ah', 'baba', 'idea', 'may', 'never', 'victim', 'case'],
#  ['trade', 'happy', 'yeah', 'want'],
#  ['sworn', 'chief', 'minister', 'tomorrow'],
#  ['assembly', 'election', 'result', 'live', 'congress', 'ahead'],
#  [],
#  ['summons', 'home', 'west'],
#  ['conservative', 'message', 'strong', 'stable', 'leadership', 'happy'],
#  ['though'],
#  ['song', 'always', 'one', 'unhappy'],
#  [],
#  ['go',
#   'five',
#   'get',
#   'decent',
#   'protective',
#   'case',
#   'cute',
#   'happy',
#   'got',
#   'mi'],
#  ['appeasement', 'none', 'policy'],
#  ['judge', 'bench', 'set', 'hear', 'right', 'possible'],
#  ['tete', 'tete', 'former', 'president'],
#  ['notice', 'anything', 'unusual', 'happy', 'birthday', 'lovely', 'happy'],
#  ['preliminary', 'enquiry', 'health', 'minister', 'money'],
#  ['back', 'unhappy'],
#  ['kind', 'empty', 'venue', 'unhappy'],
#  ['th', 'tweet', 'like', 'say', 'love'],
#  ['yes', 'life'],
#  ['part', 'happy'],
#  ['way', 'tackle', 'world'],
#  ['blast', 'love'],
#  ['running', 'patience'],
#  ['bos'],
#  ['finance', 'minister'],
#  ['pork', 'happy'],
#  ['excited', 'event', 'next', 'week', 'come', 'happy'],
#  ['damn', 'touching', 'unhappy'],
#  ['learn', 'live', 'without', 'flashing', 'red', 'light'],
#  ['told', 'bugger', 'hung', 'waned', 'access', 'someone', 'like'],
#  ['crore', 'period', 'year', 'ago'],
#  ['board', 'stand', 'potboiler', 'also'],
#  ['bring', 'man', 'unhappy'],
#  ['really', 'appreciate', 'hope', 'brilliant', 'day', 'happy'],
#  ['also'],
#  ['slipped', 'budget'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['said', 'largely', 'run', 'mac', 'os', 'miss', 'unhappy'],
#  ['getting', 'unhappy'],
#  ['see'],
#  ['unhappy'],
#  ['gentleman', 'commander', 'happy'],
#  ['setting',
#   'judge',
#   'constitution',
#   'bench',
#   'decide',
#   'appeal',
#   'verdict',
#   'holding'],
#  ['admit', 'vanity'],
#  ['muddle'],
#  ['may'],
#  [],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['literally', 'see', 'thing', 'back', 'stage'],
#  ['forced', 'noon', 'session', 'misuse', 'opposition', 'chief'],
#  ['suddenly'],
#  ['cry', 'joy', 'oh', 'hope', 'year'],
#  ['suppose', 'waiting', 'happy'],
#  ['go', 'know'],
#  ['win', 'influence', 'people'],
#  ['supreme',
#   'court',
#   'unfortunate',
#   'ground',
#   'plea',
#   'order',
#   'take',
#   'case'],
#  ['resistance', 'nothing', 'citizenry', 'yet', 'match'],
#  ['moral', 'outrage', 'cannot', 'guide', 'get', 'messy'],
#  ['happy'],
#  ['becoming', 'hostile'],
#  ['state', 'bank', 'profit'],
#  ['process', 'social', 'change', 'seldom', 'linear', 'pretty'],
#  ['injured'],
#  ['comment'],
#  ['law', 'nature', 'happy'],
#  ['ask', 'get', 'spend'],
#  ['service', 'inquiry'],
#  ['day',
#   'since',
#   'promotion',
#   'ended',
#   'already',
#   'missing',
#   'much',
#   'unhappy'],
#  ['someone', 'gift', 'pi', 'unhappy'],
#  ['shoehorn', 'plot', 'character', 'support'],
#  [],
#  ['go', 'back', 'school', 'music', 'think', 'time', 'happy'],
#  ['got', 'pen', 'today', 'man', 'cry'],
#  ['would', 'awesome'],
#  ['see'],
#  ['real', 'happy'],
#  ['st', 'woman', 'foreign', 'secretary'],
#  ['another', 'art', 'raffle', 'everything', 'need', 'know', 'picture'],
#  ['thanks',
#   'follow',
#   'happy',
#   'help',
#   'business',
#   'anyway',
#   'please',
#   'get',
#   'touch'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['stamp', 'missing', 'choice'],
#  [],
#  ['panic', 'top', 'hospital'],
#  ['might', 'dressed', 'bit', 'better'],
#  ['trying',
#   'stay',
#   'positive',
#   'help',
#   'jealous',
#   'princess',
#   'life',
#   'cuddle',
#   'eat',
#   'unhappy'],
#  ['people', 'want'],
#  ['accept', 'people', 'mandate'],
#  ['thank', 'happy'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['aunt'],
#  ['rusty',
#   'game',
#   'since',
#   'like',
#   'kept',
#   'dying',
#   'crocodile',
#   'part',
#   'cry'],
#  ['also'],
#  ['industry'],
#  ['pop', 'request', 'assassin', 'shower', 'gel', 'happy'],
#  ['ban'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['agree', 'put', 'brain', 'cry', 'joy'],
#  ['thank', 'happy'],
#  [],
#  ['man', 'great', 'leap', 'backwards', 'talk'],
#  ['sadly',
#   'yes',
#   'since',
#   'continue',
#   'losing',
#   'support',
#   'dropping',
#   'unhappy',
#   'going'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['junior', 'home', 'minister', 'made', 'without', 'seen', 'video'],
#  [],
#  ['sarkar', 'ripping'],
#  ['exit', 'could', 'bad'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['star', 'battle'],
#  ['talking', 'want', 'bb', 'tattoo', 'broke', 'unhappy'],
#  ['legislator', 'camp'],
#  ['ever', 'thank', 'hunt'],
#  ['dying', 'thirst', 'unhappy'],
#  ['nice',
#   'really',
#   'nice',
#   'stuff',
#   'mostly',
#   'black',
#   'get',
#   'away',
#   'june',
#   'wedding',
#   'though',
#   'unhappy'],
#  ['likely', 'take', 'final', 'call'],
#  ['unhappy'],
#  ['positive', 'loving', 'always', 'happy'],
#  ['reading', 'hope', 'something', 'great', 'smile'],
#  ['happy', 'happy', 'pas'],
#  ['cry', 'joy'],
#  ['take'],
#  ['probably', 'seen', 'yet', 'unhappy'],
#  ['rude', 'unhappy'],
#  ['nice', 'gif', 'happy'],
#  ['got', 'bred', 'local', 'pig', 'variety'],
#  ['selling', 'army', 'bomb', 'meet', 'sad'],
#  ['life', 'reflection', 'way', 'think', 'change', 'way', 'think'],
#  ['rupee', 'increase', 'dignified', 'living', 'plea'],
#  ['minister'],
#  [],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['better', 'check'],
#  ['rural', 'counter', 'call'],
#  ['get', 'today'],
#  ['whatever', 'biggest', 'issue'],
#  ['text', 'video', 'drawing', 'line', 'tool', 'paint', 'tool', 'sai', 'happy'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['dear'],
#  ['good', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'get'],
#  ['noon'],
#  ['never', 'mind'],
#  ['anti', 'squad', 'video'],
#  ['one', 'cat', 'yang', 'someone', 'took', 'unhappy'],
#  ['shut',
#   'instant',
#   'message',
#   'mad',
#   'lot',
#   'people',
#   'flawed',
#   'opinion',
#   'mental',
#   'health',
#   'mine',
#   'show',
#   'unhappy'],
#  ['supreme',
#   'court',
#   'arrest',
#   'warrant',
#   'get',
#   'high',
#   'court',
#   'judge',
#   'face',
#   'case'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['yeah'],
#  ['er'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['pay', 'happy'],
#  ['please', 'follow', 'trying', 'get', 'follow', 'long', 'time', 'unhappy'],
#  ['usually', 'speedboat', 'behind', 'get', 'river', 'unhappy'],
#  ['damned'],
#  ['days', 'cricket', 'commoner', 'prince'],
#  ['father'],
#  ['way'],
#  ['think', 'would', 'drive', 'mad', 'turned', 'unhappy'],
#  ['yogi'],
#  ['drive', 'become', 'chief', 'minister'],
#  ['airport'],
#  ['get', 'help', 'un'],
#  ['notice', 'unhappy'],
#  ['cram', 'reading', 'unhappy'],
#  ['unhappy'],
#  ['le'],
#  ['us', 'say'],
#  ['visa'],
#  ['week', 'get', 'dirty', 'happy', 'cum', 'see'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['turn', 'soon', 'oh', 'god', 'still', 'baby', 'unhappy'],
#  ['institute', 'head', 'das', 'skill', 'ne'],
#  ['good', 'morning', 'every', 'one'],
#  ['made', 'look', 'benign', 'use', 'lower', 'base', 'comparison'],
#  ['quaint', 'dig', 'budget', 'even', 'le'],
#  ['exclusive', 'fir', 'leadership'],
#  ['news', 'exclusive', 'arms'],
#  ['list', 'may', 'good', 'idea'],
#  ['bicycle', 'officer', 'learnt', 'ground', 'reality', 'dip', 'river'],
#  ['backlash', 'true', 'patriot'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['bug'],
#  ['thanks', 'follow'],
#  ['extended', 'family', 'show', 'oh', 'girl', 'game', 'got', 'unhappy'],
#  ['chicken'],
#  ['get'],
#  ['plan', 'cap'],
#  ['drive', 'check'],
#  ['keep'],
#  ['would', 'love', 'win', 'gorgeous', 'nail', 'cute'],
#  ['military', 'justice', 'system', 'help', 'case'],
#  ['exam', 'body', 'bos'],
#  ['law', 'single', 'may', 'keep', 'critical'],
#  ['taking'],
#  ['body', 'decided', 'boycott', 'function'],
#  ['unhappy'],
#  ['one', 'fleet', 'solely', 'hydro', 'toro', 'see'],
#  ['one', 'year', 'ago', 'today', 'unhappy'],
#  [],
#  ['ps', 'mate'],
#  ['keep', 'team', 'higher', 'thank'],
#  ['cry', 'joy'],
#  ['would', 'great', 'trick', 'happy'],
#  [],
#  ['leftist', 'minority', 'voice'],
#  ['part'],
#  ['please'],
#  ['maybe'],
#  ['still', 'sign', 'small', 'area', 'would', 'obvious', 'sad', 'quite'],
#  ['yes'],
#  ['sprout'],
#  ['please', 'help', 'tried', 'smoke', 'lettuce', 'salad', 'ruined', 'unhappy'],
#  ['sorry', 'havent', 'unhappy'],
#  ['eight', 'derail', 'near', 'station'],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want', 'free'],
#  ['plus', 'want', 'win', 'silence', 'happy'],
#  ['cash', 'lock', 'also'],
#  ['like', 'black', 'lingerie', 'picture', 'happy'],
#  ['job', 'searching', 'got', 'none', 'got', 'abundance'],
#  ['trial', 'happy'],
#  ['unhappy', 'silver'],
#  ['another',
#   'great',
#   'song',
#   'listen',
#   'good',
#   'may',
#   'well',
#   'like',
#   'happy'],
#  ['minute', 'understanding', 'thing', 'still', 'unhappy'],
#  ['fuel', 'supply', 'chain', 'ban', 'old'],
#  ['liquor', 'baron', 'declared', 'offender'],
#  ['resume', 'work', 'system', 'river'],
#  ['bank', 'job'],
#  ['heat', 'wave', 'coming'],
#  ['listen', 'beautiful', 'video', 'si'],
#  ['supreme', 'court', 'age', 'plea', 'skip', 'jail'],
#  ['trauma', 'driving', 'without', 'red'],
#  ['governor', 'congress', 'singh', 'resign', 'process', 'formation', 'next'],
#  ['remember',
#   'knowledge',
#   'worth',
#   'grade',
#   'announce',
#   'winner',
#   'tomorrow',
#   'morning',
#   'am',
#   'happy',
#   'purchase',
#   'happy'],
#  ['standoff', 'left', 'entrance', 'thrown', 'side', 'many', 'hurt'],
#  ['detailed', 'governor', 'happening'],
#  ['give', 'one', 'every', 'student', 'happy'],
#  ['happy', 'birthday', 'happy'],
#  ['miss', 'sad'],
#  ['note', 'crunch', 'glass'],
#  ['happy'],
#  ['got', 'summer', 'happiness', 'unhappy'],
#  ['happy'],
#  ['patience'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['scan', 'happy'],
#  ['please'],
#  ['bit', 'rusty', 'unhappy'],
#  ['financial', 'deal'],
#  ['school', 'taught', 'anything'],
#  ['sure',
#   'knew',
#   'make',
#   'great',
#   'network',
#   'fox',
#   'going',
#   'downhill',
#   'wi'],
#  ['for'],
#  ['happy', 'birthday', 'chopin', 'style', 'piano', 'improvisation'],
#  ['wish', 'sad'],
#  ['thought',
#   'mountain',
#   'dew',
#   'caffeine',
#   'little',
#   'energy',
#   'drink',
#   'never',
#   'sleep',
#   'unhappy'],
#  ['unconscious'],
#  ['si', 'grim', 'reaper', 'sunny', 'love', 'story', 'unhappy'],
#  ['runner', 'slot'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['cricket', 'body'],
#  ['thanks', 'voting', 'happy'],
#  ['new', 'thesis', 'another', 'genius', 'sir'],
#  ['caution', 'site', 'mayor', 'also', 'minister', 'housing', 'environment'],
#  ['dying', 'thirst', 'unhappy'],
#  ['bos', 'averse', 'joining', 'non'],
#  ['also'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy', 'want'],
#  ['miss', 'unhappy', 'working', 'local', 'nervous', 'college'],
#  ['bantay', 'unhappy'],
#  [],
#  ['today'],
#  ['thanks', 'lot'],
#  ['day', 'ahead', 'confidence', 'vote'],
#  ['happy',
#   'birthday',
#   'cry',
#   'joy',
#   'cool',
#   'hope',
#   'day',
#   'go',
#   'super',
#   'good'],
#  ['video'],
#  ['gen', 'governor'],
#  ['miss', 'unhappy'],
#  ['turned', 'back', 'day', 'get', 'dual', 'stream', 'setup', 'sorted'],
#  ['happy', 'birthday', 'happy'],
#  ['watch', 'union', 'budget', 'live', 'news', 'onwards'],
#  ['want', 'explode', 'like', 'grenade', 'point', 'people', 'die', 'sad'],
#  ['yogi'],
#  ['dysfunction'],
#  ['cold', 'war'],
#  ['telegraph', 'advantage'],
#  ['rts', 'giveaway', 'origin', 'account', 'randomly', 'people'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['went'],
#  ['stop', 'becoming'],
#  ['close', 'suit'],
#  ['wonder'],
#  ['never', 'draw', 'unhappy'],
#  ['preference', 'one'],
#  ['old', 'unhappy'],
#  ['without'],
#  ['join', 'vote', 'singer', 'spread', 'word'],
#  ['unhappy'],
#  ['bad', 'watch', 'unhappy', 'cake', 'cute', 'delicious'],
#  ['one', 'left', 'see', 'unhappy'],
#  ['swear', 'sometimes', 'cool', 'break', 'happy'],
#  ['nothing', 'sell'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['unhappy'],
#  ['fantastic', 'kissy', 'kissy'],
#  ['go', 'utmost', 'harshness'],
#  ['knee', 'similar', 'colour', 'henry', 'unhappy'],
#  ['say'],
#  ['great', 'groove', 'tune', 'thinking', 'rewind'],
#  ['know', 'happy'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['hopefully', 'happy', 'look', 'bad', 'moment'],
#  ['need', 'know', 'election', 'commission', 'open', 'challenge', 'hack'],
#  ['good', 'morning', 'every', 'one'],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want'],
#  ['tweet', 'meant', 'article', 'happy'],
#  ['unite', 'act', 'sex', 'determination'],
#  ['understand', 'silly', 'like', 'make', 'smile', 'happy'],
#  ['look', 'like', 'unhappy'],
#  [],
#  ['demand'],
#  ['groovy', 'happy'],
#  ['need', 'unhappy', 'jily_jelly'],
#  ['want', 'shah', 'oh'],
#  ['beautiful', 'lady', 'full', 'fun', 'body', 'confidence'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['season'],
#  ['woke'],
#  ['never', 'give', 'make', 'smile', 'happy'],
#  ['cant', 'piss', 'unhappy'],
#  ['oh', 'boo'],
#  ['mine', 'sending', 'stuff', 'unhappy'],
#  [],
#  ['unhappy'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['full', 'raid', 'gear', 'sad'],
#  ['strong', 'hard', 'unhappy'],
#  ['black', 'mark', 'report', 'card'],
#  ['come', 'sad'],
#  ['popular', 'entertainment', 'important', 'issue'],
#  ['thanks', 'passionate', 'hope', 'like', 'happy'],
#  ['first', 'round', 'exit', 'tech', 'cry', 'unhappy'],
#  ['case'],
#  ['unhappy', 'laughing', 'as', 'humble', 'always', 'bomb'],
#  ['josie'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['chapter', 'one', 'piece', 'definitely', 'good', 'one'],
#  ['deserve', 'better', 'hope', 'unhappy'],
#  [],
#  ['miss', 'unhappy'],
#  ['follow', 'unhappy'],
#  ['want', 'follow', 'back', 'tweet', 'happy'],
#  ['five', 'attain', 'martyrdom', 'detailed', 'statement', 'attached'],
#  ['went', 'today', 'guess', 'forgot', 'idol'],
#  ['death', 'st', 'solo', 'trip', 'also'],
#  ['tell', 'happy'],
#  ['force', 'shamed'],
#  ['indeed'],
#  ['made', 'dinner', 'two', 'tonight', 'happy'],
#  ['still', 'need', 'lucky', 'charm', 'campaign', 'bus'],
#  ['one', 'unhappy', 'tying', 'get', 'still', 'watch'],
#  ['happy'],
#  ['unelectable', 'happy'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy', 'want'],
#  ['insane', 'good', 'luck', 'took', 'yesterday', 'afternoon'],
#  ['sad', 'unhappy', 'like'],
#  ['thats', 'sick', 'thanks', 'much', 'making', 'kin', 'love'],
#  ['happy'],
#  ['day', 'go', 'happy'],
#  ['really', 'see', 'around', 'school', 'unhappy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['said', 'silence', 'morgan', 'freeman', 'voice', 'happy'],
#  ['presence'],
#  ['instead', 'money'],
#  ['slashed', 'research'],
#  ['used', 'care', 'motivation', 'happy'],
#  ['love'],
#  ['fun', 'funny', 'book', 'warn', 'kindle', 'night', 'happy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['would', 'sustained', 'fame', 'unhappy'],
#  ['arrive', 'unhappy', 'tomorrow'],
#  ['say', 'end'],
#  ['follow', 'saga', 'diary', 'year', 'worth', 'saga'],
#  ['law', 'change'],
#  ['please', 'stop', 'making'],
#  ['still', 'live'],
#  ['wow',
#   'made',
#   'compressor',
#   'actually',
#   'turns',
#   'happy',
#   'may',
#   'useful',
#   'happy'],
#  ['face', 'action', 'drinking', 'alcohol', 'anywhere', 'world'],
#  ['anyone', 'need', 'vent', 'unhappy'],
#  ['today', 'birthday', 'unhappy'],
#  ['tension', 'visit'],
#  ['want', 'victory', 'rally'],
#  ['graft', 'case'],
#  [],
#  ['eat', 'steak', 'well', 'done', 'please', 'happy'],
#  [],
#  ['say', 'sorry', 'man'],
#  ['wake',
#   'tomorrow',
#   'body',
#   'gotten',
#   'head',
#   'start',
#   'waking',
#   'every',
#   'day',
#   'week',
#   'unhappy'],
#  ['please', 'read'],
#  [],
#  [],
#  ['may', 'one', 'properly', 'unhappy'],
#  ['lot', 'month'],
#  ['shot', 'us'],
#  ['forth', 'searching', 'liquor', 'baron', 'disclosure', 'asset', 'court'],
#  ['glad',
#   'care',
#   'people',
#   'think',
#   'wish',
#   'still',
#   'best',
#   'everyday',
#   'like',
#   'used',
#   'sad',
#   'pick'],
#  ['ought', 'win'],
#  ['miss', 'unhappy'],
#  ['road', 'economy'],
#  ['need', 'know', 'across', 'eight', 'video'],
#  ['question', 'paper', 'scam'],
#  ['inspiration', 'fashion'],
#  ['back', 'worry', 'silence'],
#  ['mission', 'nice', 'day', 'though'],
#  ['go', 'sad'],
#  ['trying', 'cheer', 'unhappy'],
#  ['feel',
#   'like',
#   'telling',
#   'get',
#   'social',
#   'medium',
#   'also',
#   'feel',
#   'really',
#   'mean',
#   'unhappy',
#   'silence',
#   'love',
#   'hope'],
#  ['afraid'],
#  ['miss', 'unhappy'],
#  ['getting', 'harder', 'harder', 'stay', 'unhappy'],
#  ['law', 'job'],
#  ['transport', 'minister', 'cabinet', 'meet'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'sent'],
#  ['watch', 'live', 'stream', 'budget', 'speech', 'link'],
#  ['summer',
#   'school',
#   'vocabulary',
#   'unhappy',
#   'need',
#   'air',
#   'please',
#   'tell'],
#  ['basketball', 'theyre', 'restrict', 'threw'],
#  ['kind',
#   'like',
#   'right',
#   'sad',
#   'someone',
#   'please',
#   'make',
#   'nobby',
#   'glass',
#   'slip'],
#  [],
#  ['yes'],
#  ['ready',
#   'next',
#   'fire',
#   'lighting',
#   'session',
#   'keen',
#   'early',
#   'already',
#   'smile'],
#  ['yogi', 'venue', 'meeting', 'amid', 'talk', 'chief', 'minister'],
#  ['life', 'also'],
#  ['tour'],
#  ['fitness'],
#  [],
#  ['one', 'offering', 'poor', 'old', 'lady', 'seat', 'unhappy'],
#  ['happy', 'old'],
#  ['easter',
#   'flown',
#   'unhappy',
#   'ready',
#   'give',
#   'home',
#   'like',
#   'branded',
#   'cereal'],
#  ['china', 'visit'],
#  ['went', 'today', 'guess', 'forgot', 'idol'],
#  ['hate', 'losing', 'unhappy', 'cruel', 'people', 'deactivate', 'unhappy'],
#  ['night', 'sad', 'real', 'life', 'cant', 'sleep', 'unhappy'],
#  ['follow', 'train', 'follow', 'active', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['diary'],
#  ['day', 'extreme', 'prediction'],
#  ['unhappy'],
#  ['tap'],
#  ['hello', 'everyone'],
#  ['thank', 'miss', 'everyone', 'love'],
#  ['versus', 'cry', 'joy'],
#  ['congratulate', 'people'],
#  ['people', 'know', 'always', 'think', 'quiet', 'people', 'know', 'wish'],
#  ['know', 'ready', 'say', 'unhappy'],
#  ['hate', 'people', 'steal'],
#  ['hope', 'everything', 'go', 'right', 'unhappy'],
#  ['try', 'front', 'door'],
#  ['happy', 'birthday', 'hoe', 'good', 'day'],
#  ['someone', 'worst', 'deserve', 'best'],
#  ['answer', 'steam', 'trade', 'link', 'ill', 'send', 'right', 'away'],
#  ['continue', 'right', 'lighting', 'swear', 'sorry', 'sad'],
#  [],
#  ['told'],
#  ['consular', 'access'],
#  ['career', 'unhappy'],
#  ['hair', 'color', 'pretty'],
#  ['chief', 'growth', 'rate'],
#  ['good', 'luck', 'vote', 'smile'],
#  ['art', 'form'],
#  ['polling', 'underway', 'assembly', 'spread', 'across', 'phase'],
#  ['always', 'love', 'happy'],
#  ['production', 'grew'],
#  ['cry'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['good', 'morning', 'every', 'one'],
#  ['making', 'law', 'ban', 'sitting', 'draft'],
#  ['great', 'thing', 'sad', 'unhappy'],
#  ['minister', 'senior', 'leader'],
#  ['saying', 'read', 'book', 'today'],
#  ['cried', 'racism'],
#  ['nation', 'must', 'begin', 'new', 'life'],
#  [],
#  ['thanks', 'feedback', 'starting', 'phase'],
#  [],
#  ['parliament', 'early', 'national'],
#  ['st',
#   'day',
#   'entertainment',
#   'film',
#   'big',
#   'fan',
#   'story',
#   'finally',
#   'get'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['wrote', 'still', 'notice', 'cry'],
#  ['talking', 'girl', 'behind', 'unhappy'],
#  ['excuse', 'see', 'unhappy'],
#  ['saw', 'reply', 'unhappy'],
#  ['think', 'pretty', 'enough', 'unhappy'],
#  ['thank', 'happy'],
#  ['mike', 'happy'],
#  ['get'],
#  ['setting', 'court', 'home'],
#  ['say', 'unhappy'],
#  ['satisfied', 'policy'],
#  ['patience'],
#  ['open'],
#  ['chaos', 'call', 'secret', 'vote'],
#  ['uncheck', 'new', 'happy'],
#  ['guess', 'said', 'adopted', 'son'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['virulent', 'also'],
#  ['feeling', 'bad', 'unhappy'],
#  ['love', 'unhappy'],
#  ['please',
#   'let',
#   'meet',
#   'cry',
#   'joy',
#   'really',
#   'hope',
#   'could',
#   'win',
#   'first',
#   'cover'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['miss', 'sad'],
#  ['station', 'check', 'happy', 'surely', 'combination', 'xx', 'xx'],
#  ['quest', 'quest', 'book'],
#  ['men', 'die', 'trying', 'save', 'friend'],
#  ['unhappy'],
#  ['every', 'time', 'shepherd', 'hold', 'back', 'unhappy'],
#  ['join', 'camp', 'flock'],
#  ['amazing', 'stuff', 'happy', 'birth', 'control', 'gamma', 'ray'],
#  ['alright',
#   'like',
#   'back',
#   'behind',
#   'page',
#   'drop',
#   'daily',
#   'visit',
#   'post',
#   'unhappy'],
#  ['love', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['want', 'bad', 'unhappy'],
#  ['well'],
#  ['sun', 'shining', 'happy'],
#  ['white', 'genocide', 'thing', 'figment', 'imagination', 'victim', 'nothing'],
#  ['risen'],
#  ['set', 'panel', 'study', 'service', 'paramilitary'],
#  ['fun',
#   'welcome',
#   'back',
#   'first',
#   'day',
#   'happy',
#   'dirty',
#   'really',
#   'miss'],
#  ['post', 'much', 'lately', 'school', 'unhappy'],
#  ['really', 'need', 'build', 'unhappy'],
#  ...]

# %%
from gensim.models import Word2Vec

w2v = Word2Vec(size=150, window=10, min_count=1, sg=1, workers=10)
w2v.build_vocab(training_docs)
w2v.train(sentences=training_docs, total_examples=len(training_docs), epochs=w2v.epochs)

w2v

# %%
def doc2vec(docs):
    last_indices = []
    testing_docs = []
    tokenized_docs = []

    for _, row in docs.iterrows():
        tokens = tokenize(preprocess(row['tweets']))
        if len(last_indices) > 0:
            last_indices.append(last_indices[len(last_indices) - 1] + len(tokens))
        else:
            last_indices.append(len(tokens))
        testing_docs.extend(tokens)
        tokenized_docs.append(tokens)

    return tokenized_docs, testing_docs, last_indices

from sklearn.cluster import MiniBatchKMeans

kmeans = MiniBatchKMeans(n_clusters=8, batch_size=750)

def stream_cluster(vectors, vector_size, last_indices):
    document_vectors = []
    first_index = 0
    
    for last_index in last_indices:
        min_vector = []
        max_vector = []
        for i in range(vector_size):
            v_list = [v[i] for v in vectors[first_index:last_index]]
            if len(v_list) > 0:
                min_vector.append(min(v_list))
                max_vector.append(max(v_list))
        if len(min_vector) > 0 and len(max_vector) > 0:
            min_vector.extend(max_vector)
            document_vectors.append(min_vector)
        first_index = last_index
    clustering = kmeans.partial_fit(document_vectors)
    
    return clustering, clustering.labels_, document_vectors

# %%
last_index = int(len(documents.index) / 5)
documents_test = documents[:last_index]

tokenized_docs, testing_docs, last_indices = doc2vec(documents_test)

tokenized_docs
# Out:
# [['live', 'money'],
#  ['find', 'difficult', 'unhappy'],
#  ['merit', 'wild', 'baseless'],
#  ['lipstick', 'cry'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['wow', 'awesome', 'gog', 'thanks', 'happy'],
#  ['preacher', 'unhappy'],
#  ['spark', 'traffic', 'chaos', 'grand', 'gate'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['supreme',
#   'court',
#   'chance',
#   'oppose',
#   'judge',
#   'appointment',
#   'national',
#   'security'],
#  ['could', 'whatever'],
#  ['short', 'two', 'majority'],
#  ['tell', 'idea'],
#  ['love', 'unhappy'],
#  ['camp', 'meet', 'assembly', 'speaker'],
#  ['moment'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['former', 'captain', 'team'],
#  ['riot', 'refugee', 'resolve', 'also'],
#  ['hold', 'st', 'cabinet', 'meeting', 'today'],
#  ['thank', 'much', 'friend', 'smile'],
#  ['reason', 'last', 'miss', 'like', 'month', 'notice', 'unhappy'],
#  ['front'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['would', 'going', 'prison', 'unhappy'],
#  ['man', 'phone', 'made', 'like', 'always', 'wink'],
#  ['private', 'fear', 'plan', 'monitor', 'give', 'local', 'death', 'grip'],
#  ['could', 'meet', 'next', 'time'],
#  ['miss', 'baby', 'unhappy'],
#  ['wolf', 'bite', 'yet', 'happy', 'help', 'get', 'steam'],
#  ['definitely', 'looking', 'gave', 'try', 'anyway', 'happy'],
#  ['body', 'everything', 'mind', 'kind'],
#  ['quiz', 'industry'],
#  ['lose'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['unhappy'],
#  ['build', 'case'],
#  ['cast', 'shadow'],
#  ['definitely', 'arm', 'unhappy'],
#  ['happy', 'ming', 'love', 'love', 'happy'],
#  [],
#  ['saved', 'death', 'eclipse'],
#  ['sad', 'say', 'actually', 'remember', 'unhappy', 'happen'],
#  [],
#  ['extradition', 'could', 'take'],
#  ['still', 'cant', 'unhappy'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['future', 'get', 'wrong'],
#  ['turn', 'avenger'],
#  [],
#  ['unhappy'],
#  ['hard', 'notice', 'unhappy'],
#  ['also'],
#  ['childish', 'commando', 'happy'],
#  ['adopted', 'son'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lost', 'one', 'import', 'unhappy'],
#  ['know', 'sorry', 'enough', 'sorry', 'unhappy'],
#  ['wait', 'see', 'film', 'wished', 'would', 'bu'],
#  [],
#  [],
#  ['mission', 'restore', 'complex'],
#  ['ask', 'two', 'special', 'lined', 'unhappy'],
#  ['definitely', 'arm', 'unhappy'],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['dope', 'cool', 'word', 'finally', 'hip', 'young', 'smile'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['snap'],
#  ['come', 'back', 'unhappy'],
#  ['ahead'],
#  ['happy', 'belated', 'birthday', 'another', 'duet', 'much'],
#  ['super', 'unhappy'],
#  ['may', 'show'],
#  ['twitter', 'premium', 'version', 'free', 'service'],
#  ['midst', 'incendiary', 'wish'],
#  [],
#  ['happy'],
#  ['question', 'happy'],
#  ['struggle', 'unhappy'],
#  ['attack'],
#  ['today'],
#  ['miss', 'already', 'unhappy'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  [],
#  ['air', 'tighten', 'security', 'stall'],
#  ['also'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy', 'want'],
#  ['half', 'time', 'load'],
#  [],
#  ['cosmic', 'give', 'month', 'unhappy'],
#  ['happy', 'happy'],
#  ['celebrate', 'uncelebrated'],
#  ['happy'],
#  ['return', 'unit'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['keep', 'awake', 'happy'],
#  ['tired', 'nothing', 'great', 'unhappy'],
#  ['decide',
#   'new',
#   'legislative',
#   'party',
#   'leader',
#   'future',
#   'course',
#   'action',
#   'also'],
#  ['prefer',
#   'enjoy',
#   'happy',
#   'km',
#   'away',
#   'also',
#   'quite',
#   'nice',
#   'honestly',
#   'anywhere',
#   'away',
#   'crazy'],
#  ['feel', 'bad', 'unhappy'],
#  ['last', 'kiss', 'unhappy'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['am', 'forget', 'eat', 'breakfast', 'happy'],
#  ['also'],
#  [],
#  ['fighting'],
#  ['feeling'],
#  ['bit', 'rusty', 'unhappy'],
#  ['lost', 'deposit', 'garden', 'stronghold'],
#  ['go'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['motivation', 'study', 'unhappy'],
#  ['oil', 'hit', 'three', 'month', 'low', 'rig', 'count'],
#  ['year', 'old', 'new', 'ladylike', 'trust', 'troll'],
#  ['zoo', 'mark'],
#  ['come', 'back', 'ghost', 'unhappy', 'love'],
#  ['definitely', 'arm', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['get', 'accept', 'calf'],
#  ['puzzle', 'like', 'next', 'please'],
#  ['raj', 'calling', 'party', 'form', 'government'],
#  ['good', 'watch', 'tv', 'application', 'free', 'happy'],
#  ['thanks', 'happy'],
#  ['hope'],
#  ['ready',
#   'one',
#   'week',
#   'old',
#   'chocolate',
#   'female',
#   'puppy',
#   'sterling',
#   'happy',
#   'girl',
#   'sweetheart'],
#  ['get', 'help', 'un'],
#  ['help', 'unhappy', 'early', 'birthday', 'gift'],
#  ['hair', 'crisp', 'unhappy'],
#  ['sup'],
#  ['history', 'around'],
#  ['autonomy'],
#  [],
#  ['supreme', 'court', 'caution', 'stealing'],
#  ['would', 'love', 'guest', 'sometime', 'minute', 'smile', 'interested'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['report'],
#  ['sign'],
#  ['work', 'get', 'backing'],
#  ['friendly', 'service'],
#  ['unhappy', 'fairly', 'warm'],
#  ['beyond', 'sad', 'unhappy'],
#  ['confusion'],
#  ['tried', 'still', 'unhappy'],
#  [],
#  ['unhappy'],
#  ['increase', 'ordered'],
#  ['editorial', 'mayor', 'cannot'],
#  ['old', 'continue'],
#  ['definitely', 'arm', 'unhappy'],
#  ['bow', 'story'],
#  ['unnamed'],
#  ['need', 'direct', 'coffee', 'feed', 'happy'],
#  ['sad'],
#  ['hi', 'instant', 'message', 'friend', 'friend'],
#  ['look', 'good', 'current', 'shame', 'never', 'cut', 'unhappy'],
#  ['tale', 'prime'],
#  ['stay', 'cool'],
#  ['greatness', 'winning'],
#  ['good', 'evening', 'happy'],
#  ['guess',
#   'getting',
#   'much',
#   'acting',
#   'work',
#   'day',
#   'much',
#   'time',
#   'unhappy'],
#  ['finished', 'gym'],
#  ['lost',
#   'two',
#   'two',
#   'favorite',
#   'people',
#   'silence',
#   'unhappy',
#   'good',
#   'night'],
#  ['enforcement', 'directorate', 'chief', 'singh', 'fixed', 'tenure'],
#  ['cloaked', 'debate'],
#  ['may', 'open', 'happy'],
#  ['care',
#   'youth',
#   'mental',
#   'health',
#   'rw',
#   'show',
#   'young',
#   'audience',
#   'graphic',
#   'rape',
#   'suicide'],
#  ['think', 'probably', 'beyond', 'repair', 'tea', 'etiquette', 'happy'],
#  ['happy'],
#  ['ill', 'fitting'],
#  ['rd', 'episode', 'everyone', 'sure', 'check', 'happy'],
#  ['say'],
#  ['awesome'],
#  ['scrap'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['damn', 'unfortunate', 'unhappy'],
#  ['best', 'damn', 'avocado', 'batsyy_'],
#  ['denial', 'normal', 'say'],
#  ['trump'],
#  ['divide', 'woo', 'home', 'turf'],
#  ['take', 'season'],
#  ['want',
#   'someone',
#   'little',
#   'back',
#   'trace',
#   'thing',
#   'put',
#   'sleep',
#   'unhappy'],
#  ['want',
#   'cant',
#   'go',
#   'unhappy',
#   'honestly',
#   'like',
#   'messy',
#   'break',
#   'unhappy'],
#  ['let', 'alone', 'free'],
#  ['please', 'follow', 'trying', 'long', 'unhappy', 'love', 'much', 'baby'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['beetle', 'litchi', 'crop'],
#  [],
#  ['music', 'direction'],
#  ['piss', 'cry'],
#  ['death', 'currency'],
#  ['gazette', 'wont', 'applied', 'retrospectively', 'admitted'],
#  ['also'],
#  [],
#  [],
#  ['happy'],
#  ['message', 'us'],
#  ['suspended'],
#  ['know', 'really', 'stranger', 'satisfied', 'entertainment', 'provide'],
#  ['defence', 'minister'],
#  ['emergency', 'clause', 'end'],
#  ['great'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['best', 'please'],
#  ['like', 'happy'],
#  ['us', 'scare'],
#  ['long', 'time', 'chat', 'sad'],
#  ['love', 'ben', 'get', 'watch', 'want', 'without', 'interruption', 'happy'],
#  ['funds', 'fear', 'research'],
#  ['belt', 'party'],
#  ['match', 'versus', 'gut', 'feeling', 'dig', 'supreme', 'court', 'also'],
#  ['time', 'something', 'ot'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['healthy'],
#  ['also'],
#  ['entertaining', 'insightful', 'one', 'really', 'enjoying', 'lot', 'season'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['bedroom', 'journalism', 'trial'],
#  ['perfectly', 'happy', 'got'],
#  ['hey', 'thanks', 'follow', 'coastal', 'living', 'mean', 'reply', 'photo'],
#  ['yet',
#   'invest',
#   'child',
#   'emotional',
#   'education',
#   'taking',
#   'child',
#   'school',
#   'holiday',
#   'early',
#   'un'],
#  ['poor', 'baby', 'unhappy', 'hate', 'people'],
#  ['bill', 'check'],
#  ['today', 'congress', 'address'],
#  ['thanks', 'great', 'review', 'smile'],
#  ['short', 'thanks', 'friend'],
#  ['supreme', 'court', 'explain', 'need', 'censorship'],
#  ['court', 'death'],
#  ['good', 'news', 'thriving', 'reserve'],
#  ['spent', 'night', 'filling', 'breach', 'wall'],
#  ['happy'],
#  ['like', 'one', 'song', 'really', 'love'],
#  ['addition'],
#  ['quickly'],
#  ['print', 'edition', 'today'],
#  ['suspect', 'attack'],
#  ['model'],
#  ['true', 'waste', 'day', 'social', 'medium', 'reading', 'hand'],
#  ['court', 'probe', 'corruption', 'charge'],
#  ['stayed', 'phone', 'ad', 'miss', 'unhappy'],
#  ['unhappy'],
#  ['headline',
#   'inflation',
#   'measured',
#   'consumer',
#   'price',
#   'index',
#   'control',
#   'third',
#   'successive',
#   'financial',
#   'year'],
#  ['right', 'seriously', 'need', 'decent', 'butterfly', 'tattoo', 'design'],
#  ['professional',
#   'much',
#   'want',
#   'help',
#   'death',
#   'might',
#   'make',
#   'situation'],
#  ['miss', 'unhappy'],
#  ['thanks',
#   'recent',
#   'follow',
#   'happy',
#   'connect',
#   'happy',
#   'great',
#   'want',
#   'free'],
#  ['happy'],
#  ['good', 'show', 'next', 'jump'],
#  ['bore'],
#  ['days', 'good'],
#  ['happy', 'kyle'],
#  ['mutton'],
#  ['froze', 'mid', 'install', 'hrs', 'pull', 'plug', 'cry'],
#  ['welcome', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['say', 'hi', 'unhappy'],
#  ['live', 'resignation'],
#  ['excited',
#   'ball',
#   'start',
#   'smile',
#   'baby',
#   'minor',
#   'absolutely',
#   'love',
#   'watching',
#   'play'],
#  ['many', 'mine', 'talk', 'sexually', 'past', 'found', 'another', 'unhappy'],
#  ['want', 'go', 'game', 'unhappy'],
#  [],
#  ['whimper'],
#  ['bad', 'idea'],
#  ['new', 'era', 'amity'],
#  ['customer', 'journey', 'keynote', 'partner', 'event', 'incredible', 'event'],
#  ['really', 'zero', 'dawn', 'idea', 'play', 'next', 'unhappy'],
#  ['good', 'luck', 'swampy', 'happy'],
#  ['happy', 'everyone', 'happy'],
#  ['got', 'rest'],
#  ['chief', 'minister'],
#  ['get', 'unhappy', 'ratio', 'amazing'],
#  ['negative', 'pit', 'unhappiness'],
#  ['march', 'siege', 'parliament'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['boycott', 'parliament', 'raincoat', 'remark'],
#  ['raj', 'tender', 'resignation'],
#  ['backed', 'prevent', 'legal'],
#  ['operator', 'acquire', 'business', 'seven', 'spectrum'],
#  ['growth', 'rate', 'industrial', 'sector', 'moderate'],
#  ['tonight'],
#  ['alpha', 'invitation', 'well', 'received', 'happy'],
#  ['getting', 'morning', 'hassle', 'unhappy'],
#  ['thanks', 'passionate', 'hope', 'like', 'happy'],
#  ['miss', 'petite', 'happy', 'happy', 'looking', 'forward', 'weekend'],
#  [],
#  ['old', 'twitter', 'unhappy'],
#  ['unhappy'],
#  ['supreme',
#   'court',
#   'response',
#   'plea',
#   'frame',
#   'national',
#   'policy',
#   'promote'],
#  ['myth', 'good', 'team'],
#  ['one', 'meeting'],
#  ['well'],
#  [],
#  ['stock', 'home', 'syndrome'],
#  ['find'],
#  ['miss', 'bedroom', 'unhappy'],
#  ['returned', 'warm', 'welcome'],
#  ['accepted', 'resignation', 'council', 'immediate'],
#  ['trying',
#   'bank',
#   'sleep',
#   'week',
#   'happy',
#   'doubt',
#   'able',
#   'sleep',
#   'night'],
#  ['may', 'able', 'hold', 'college', 'year'],
#  ['law', 'take', 'course', 'occupation', 'doesnt', 'end'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['village', 'bridge'],
#  ['march', 'ft', 'long', 'flag'],
#  ['supreme', 'court', 'may', 'hear', 'key', 'summer', 'break'],
#  ['top', 'make', 'pay', 'cash'],
#  ['question', 'banking', 'switching', 'old'],
#  [],
#  ['cheer', 'new', 'administrator', 'team', 'happy'],
#  ['surround', 'positivity', 'happy'],
#  ['come', 'prey'],
#  ['tried', 'new', 'trying', 'dumb', 'life'],
#  ['focus'],
#  ['dude'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['mine', 'back', 'say', 'happy'],
#  ['crude', 'architecture', 'taking', 'world', 'city'],
#  ['keep', 'trying', 'quit', 'work', 'unhappy', 'pick', 'please', 'give'],
#  ['ha', 'unhappy'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['unit', 'finally', 'full', 'time', 'chief'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['days', 'ram'],
#  ['especially', 'people', 'low', 'patience', 'level', 'happy'],
#  ['hi', 'please', 'pinned', 'post', 'happy'],
#  ['love'],
#  ['visit', 'today', 'st', 'time', 'taking', 'oath'],
#  ['much', 'happy', 'want'],
#  ['spike'],
#  ['thanks'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['naming', 'game'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy'],
#  ['flash', 'khan'],
#  ['manifesto'],
#  [],
#  ['fix', 'soon', 'delay', 'tomorrow', 'unhappy'],
#  ['let', 'forget', 'also', 'white', 'birthday', 'today', 'miss', 'unhappy'],
#  ['hi', 'cham'],
#  ['cry'],
#  ['keep', 'unhappy'],
#  ['great', 'work', 'lovely', 'place', 'thank'],
#  ['theory', 'population'],
#  ['indirect', 'happy'],
#  ['old', 'leyland'],
#  ['bot', 'perfect', 'happy'],
#  ['work', 'morning', 'unhappy'],
#  ['heartland', 'lab'],
#  ['welfare'],
#  ['take'],
#  ['coo', 'pay', 'hike'],
#  [],
#  ['also'],
#  ['happy', 'see', 'closer', 'con', 'five'],
#  ['better', 'unhappy'],
#  ['middleman', 'nephew', 'bribe', 'election', 'commission'],
#  ['like', 'happy'],
#  ['tested', 'sweet', 'sweet'],
#  ['unnamed'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['unhappy'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['late', 'night'],
#  ['wish', 'meeting', 'unhappy'],
#  ['large'],
#  ['treaty',
#   'could',
#   'provide',
#   'security',
#   'tech',
#   'culture',
#   'development',
#   'happy'],
#  ['feared', 'bus', 'river', 'area', 'district', 'police'],
#  ['custom', 'fill', 'unhappy'],
#  ['first',
#   'group',
#   'came',
#   'forward',
#   'yesterday',
#   'racist',
#   'mob',
#   'violence'],
#  [],
#  ['counting', 'constituency'],
#  ['got', 'th', 'add', 'ant', 'possible', 'thanks', 'happy'],
#  ['relate', 'much', 'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['available', 'festival', 'running'],
#  ['happen', 'easter', 'one', 'best', 'day', 'unhappy'],
#  [],
#  ['support'],
#  ['wife', 'split', 'coo'],
#  ['miss', 'unhappy'],
#  ['president', 'supporting', 'legislation', 'related'],
#  ['made', 'ensure', 'free', 'fair', 'election'],
#  ['sudden', 'blaze', 'bungalow'],
#  ['beating', 'two', 'anyway', 'stop', 'match'],
#  ['hard', 'give', 'experience', 'pleasurable', 'pain'],
#  ['ride', 'final', 'unhappy'],
#  ['supreme',
#   'court',
#   'bid',
#   'put',
#   'sport',
#   'ministry',
#   'bureaucrat',
#   'panel',
#   'run'],
#  ['bit', 'tired'],
#  ['leader'],
#  ['livid'],
#  ['much', 'happy'],
#  ['keep_smiling_y'],
#  ['sorry', 'always', 'ask', 'follow', 'happy'],
#  ['parliament'],
#  ['blocked', 'another', 'notch', 'belt', 'happy'],
#  ['soldier', 'painful', 'journey'],
#  ['people', 'propose', 'future', 'happy'],
#  ['case',
#   'meat',
#   'exporter',
#   'graft',
#   'case',
#   'former',
#   'chief',
#   'singh',
#   'also'],
#  ['beauty'],
#  ['great', 'good', 'un', 'unthinkable', 'picture', 'dug', 'mysel'],
#  ['demand', 'justice', 'right', 'cattle', 'trade'],
#  ['good', 'morning', 'never', 'fail', 'make', 'smile', 'happy'],
#  ['economic',
#   'survey',
#   'tabled',
#   'parliament',
#   'shortly',
#   'know',
#   'economic',
#   'survey'],
#  ['also'],
#  ['trump', 'administration', 'economics'],
#  ['may'],
#  ['got', 'unhappy'],
#  ['suddenly', 'miss', 'ate', 'unhappy'],
#  ['might', 'set', 'whole', 'place', 'fire'],
#  ['high', 'commissioner'],
#  ['yogi', 'work'],
#  ['unhappy'],
#  ['cost',
#   'abut',
#   'year',
#   'paying',
#   'half',
#   'full',
#   'education',
#   'get',
#   'treat'],
#  ['seen', 'good'],
#  ['really', 'want', 'one', 'iconic', 'shirt', 'unhappy'],
#  ['nice', 'morning', 'working', 'today', 'lovely', 'atmosphere'],
#  ['end', 'another', 'batch', 'edge', 'happy'],
#  ['better', 'unhappy'],
#  ['people', 'happy'],
#  ['unhappy'],
#  ['st', 'time'],
#  ['watched', 'produce', 'gum', 'poor', 'bless', 'soul', 'unhappy'],
#  ['sixth', 'spot', 'applicable', 'team', 'higher', 'pa'],
#  ['today', 'never', 'forget', 'smile', 'happy'],
#  ['actually', 'live', 'honesty', 'integrity'],
#  ['love', 'daughter', 'cry'],
#  [],
#  [],
#  ['thanks', 'notice'],
#  ['back', 'unhappy'],
#  ['crore'],
#  ['soon', 'make', 'happy'],
#  ['finance', 'minister', 'table'],
#  ['like', 'biggest', 'unhappy'],
#  ['day', 'new', 'happy', 'via'],
#  ['ich', 'unhappy'],
#  ['trying', 'rescue', 'trapped'],
#  ['would',
#   'love',
#   'work',
#   'train',
#   'company',
#   'great',
#   'dream',
#   'come',
#   'true'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['last', 'happy'],
#  ['bought', 'cold', 'storage', 'license', 'west'],
#  ['cant',
#   'find',
#   'striped',
#   'shirt',
#   'unhappy',
#   'instant',
#   'message',
#   'wearing',
#   'one',
#   'favorite',
#   'thing',
#   'middle'],
#  ['super', 'scary', 'unhappy'],
#  ['scheme'],
#  ['deep',
#   'scratch',
#   'paint',
#   'gone',
#   'see',
#   'bare',
#   'metal',
#   'need',
#   'fixed',
#   'avoid',
#   'getting',
#   'car',
#   'soon',
#   'unhappy'],
#  ['thank'],
#  ['sad', 'story', 'unhappy'],
#  ['governor', 'call'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['nope', 'unhappy'],
#  ['small', 'unhappy'],
#  [],
#  ['menace', 'born', 'eating'],
#  ['go', 'way', 'good', 'one', 'extreme', 'driving', 'today', 'smile'],
#  ['polling', 'first', 'phase'],
#  ['join',
#   'celebrate',
#   'earth',
#   'planting',
#   'head',
#   'page',
#   'information',
#   'happy'],
#  ['unhappy', 'unfollowed', 'many', 'people', 'ugh'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['soup', 'slow', 'pork'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['nothing', 'date', 'make'],
#  ['part', 'day', 'everyday', 'leave', 'unhappy'],
#  ['last', 'event', 'chapter'],
#  ['mutual', 'let', 'talk', 'sure', 'mutual', 'happy'],
#  ['stupid'],
#  ['dog', 'family', 'put', 'tomorrow', 'unhappy'],
#  ['ah', 'baba', 'idea', 'may', 'never', 'victim', 'case'],
#  ['trade', 'happy', 'yeah', 'want'],
#  ['sworn', 'chief', 'minister', 'tomorrow'],
#  ['assembly', 'election', 'result', 'live', 'congress', 'ahead'],
#  [],
#  ['summons', 'home', 'west'],
#  ['conservative', 'message', 'strong', 'stable', 'leadership', 'happy'],
#  ['though'],
#  ['song', 'always', 'one', 'unhappy'],
#  [],
#  ['go',
#   'five',
#   'get',
#   'decent',
#   'protective',
#   'case',
#   'cute',
#   'happy',
#   'got',
#   'mi'],
#  ['appeasement', 'none', 'policy'],
#  ['judge', 'bench', 'set', 'hear', 'right', 'possible'],
#  ['tete', 'tete', 'former', 'president'],
#  ['notice', 'anything', 'unusual', 'happy', 'birthday', 'lovely', 'happy'],
#  ['preliminary', 'enquiry', 'health', 'minister', 'money'],
#  ['back', 'unhappy'],
#  ['kind', 'empty', 'venue', 'unhappy'],
#  ['th', 'tweet', 'like', 'say', 'love'],
#  ['yes', 'life'],
#  ['part', 'happy'],
#  ['way', 'tackle', 'world'],
#  ['blast', 'love'],
#  ['running', 'patience'],
#  ['bos'],
#  ['finance', 'minister'],
#  ['pork', 'happy'],
#  ['excited', 'event', 'next', 'week', 'come', 'happy'],
#  ['damn', 'touching', 'unhappy'],
#  ['learn', 'live', 'without', 'flashing', 'red', 'light'],
#  ['told', 'bugger', 'hung', 'waned', 'access', 'someone', 'like'],
#  ['crore', 'period', 'year', 'ago'],
#  ['board', 'stand', 'potboiler', 'also'],
#  ['bring', 'man', 'unhappy'],
#  ['really', 'appreciate', 'hope', 'brilliant', 'day', 'happy'],
#  ['also'],
#  ['slipped', 'budget'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['said', 'largely', 'run', 'mac', 'os', 'miss', 'unhappy'],
#  ['getting', 'unhappy'],
#  ['see'],
#  ['unhappy'],
#  ['gentleman', 'commander', 'happy'],
#  ['setting',
#   'judge',
#   'constitution',
#   'bench',
#   'decide',
#   'appeal',
#   'verdict',
#   'holding'],
#  ['admit', 'vanity'],
#  ['muddle'],
#  ['may'],
#  [],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['literally', 'see', 'thing', 'back', 'stage'],
#  ['forced', 'noon', 'session', 'misuse', 'opposition', 'chief'],
#  ['suddenly'],
#  ['cry', 'joy', 'oh', 'hope', 'year'],
#  ['suppose', 'waiting', 'happy'],
#  ['go', 'know'],
#  ['win', 'influence', 'people'],
#  ['supreme',
#   'court',
#   'unfortunate',
#   'ground',
#   'plea',
#   'order',
#   'take',
#   'case'],
#  ['resistance', 'nothing', 'citizenry', 'yet', 'match'],
#  ['moral', 'outrage', 'cannot', 'guide', 'get', 'messy'],
#  ['happy'],
#  ['becoming', 'hostile'],
#  ['state', 'bank', 'profit'],
#  ['process', 'social', 'change', 'seldom', 'linear', 'pretty'],
#  ['injured'],
#  ['comment'],
#  ['law', 'nature', 'happy'],
#  ['ask', 'get', 'spend'],
#  ['service', 'inquiry'],
#  ['day',
#   'since',
#   'promotion',
#   'ended',
#   'already',
#   'missing',
#   'much',
#   'unhappy'],
#  ['someone', 'gift', 'pi', 'unhappy'],
#  ['shoehorn', 'plot', 'character', 'support'],
#  [],
#  ['go', 'back', 'school', 'music', 'think', 'time', 'happy'],
#  ['got', 'pen', 'today', 'man', 'cry'],
#  ['would', 'awesome'],
#  ['see'],
#  ['real', 'happy'],
#  ['st', 'woman', 'foreign', 'secretary'],
#  ['another', 'art', 'raffle', 'everything', 'need', 'know', 'picture'],
#  ['thanks',
#   'follow',
#   'happy',
#   'help',
#   'business',
#   'anyway',
#   'please',
#   'get',
#   'touch'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['stamp', 'missing', 'choice'],
#  [],
#  ['panic', 'top', 'hospital'],
#  ['might', 'dressed', 'bit', 'better'],
#  ['trying',
#   'stay',
#   'positive',
#   'help',
#   'jealous',
#   'princess',
#   'life',
#   'cuddle',
#   'eat',
#   'unhappy'],
#  ['people', 'want'],
#  ['accept', 'people', 'mandate'],
#  ['thank', 'happy'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['aunt'],
#  ['rusty',
#   'game',
#   'since',
#   'like',
#   'kept',
#   'dying',
#   'crocodile',
#   'part',
#   'cry'],
#  ['also'],
#  ['industry'],
#  ['pop', 'request', 'assassin', 'shower', 'gel', 'happy'],
#  ['ban'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['agree', 'put', 'brain', 'cry', 'joy'],
#  ['thank', 'happy'],
#  [],
#  ['man', 'great', 'leap', 'backwards', 'talk'],
#  ['sadly',
#   'yes',
#   'since',
#   'continue',
#   'losing',
#   'support',
#   'dropping',
#   'unhappy',
#   'going'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['junior', 'home', 'minister', 'made', 'without', 'seen', 'video'],
#  [],
#  ['sarkar', 'ripping'],
#  ['exit', 'could', 'bad'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['star', 'battle'],
#  ['talking', 'want', 'bb', 'tattoo', 'broke', 'unhappy'],
#  ['legislator', 'camp'],
#  ['ever', 'thank', 'hunt'],
#  ['dying', 'thirst', 'unhappy'],
#  ['nice',
#   'really',
#   'nice',
#   'stuff',
#   'mostly',
#   'black',
#   'get',
#   'away',
#   'june',
#   'wedding',
#   'though',
#   'unhappy'],
#  ['likely', 'take', 'final', 'call'],
#  ['unhappy'],
#  ['positive', 'loving', 'always', 'happy'],
#  ['reading', 'hope', 'something', 'great', 'smile'],
#  ['happy', 'happy', 'pas'],
#  ['cry', 'joy'],
#  ['take'],
#  ['probably', 'seen', 'yet', 'unhappy'],
#  ['rude', 'unhappy'],
#  ['nice', 'gif', 'happy'],
#  ['got', 'bred', 'local', 'pig', 'variety'],
#  ['selling', 'army', 'bomb', 'meet', 'sad'],
#  ['life', 'reflection', 'way', 'think', 'change', 'way', 'think'],
#  ['rupee', 'increase', 'dignified', 'living', 'plea'],
#  ['minister'],
#  [],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['better', 'check'],
#  ['rural', 'counter', 'call'],
#  ['get', 'today'],
#  ['whatever', 'biggest', 'issue'],
#  ['text', 'video', 'drawing', 'line', 'tool', 'paint', 'tool', 'sai', 'happy'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['dear'],
#  ['good', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'get'],
#  ['noon'],
#  ['never', 'mind'],
#  ['anti', 'squad', 'video'],
#  ['one', 'cat', 'yang', 'someone', 'took', 'unhappy'],
#  ['shut',
#   'instant',
#   'message',
#   'mad',
#   'lot',
#   'people',
#   'flawed',
#   'opinion',
#   'mental',
#   'health',
#   'mine',
#   'show',
#   'unhappy'],
#  ['supreme',
#   'court',
#   'arrest',
#   'warrant',
#   'get',
#   'high',
#   'court',
#   'judge',
#   'face',
#   'case'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['yeah'],
#  ['er'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['pay', 'happy'],
#  ['please', 'follow', 'trying', 'get', 'follow', 'long', 'time', 'unhappy'],
#  ['usually', 'speedboat', 'behind', 'get', 'river', 'unhappy'],
#  ['damned'],
#  ['days', 'cricket', 'commoner', 'prince'],
#  ['father'],
#  ['way'],
#  ['think', 'would', 'drive', 'mad', 'turned', 'unhappy'],
#  ['yogi'],
#  ['drive', 'become', 'chief', 'minister'],
#  ['airport'],
#  ['get', 'help', 'un'],
#  ['notice', 'unhappy'],
#  ['cram', 'reading', 'unhappy'],
#  ['unhappy'],
#  ['le'],
#  ['us', 'say'],
#  ['visa'],
#  ['week', 'get', 'dirty', 'happy', 'cum', 'see'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['turn', 'soon', 'oh', 'god', 'still', 'baby', 'unhappy'],
#  ['institute', 'head', 'das', 'skill', 'ne'],
#  ['good', 'morning', 'every', 'one'],
#  ['made', 'look', 'benign', 'use', 'lower', 'base', 'comparison'],
#  ['quaint', 'dig', 'budget', 'even', 'le'],
#  ['exclusive', 'fir', 'leadership'],
#  ['news', 'exclusive', 'arms'],
#  ['list', 'may', 'good', 'idea'],
#  ['bicycle', 'officer', 'learnt', 'ground', 'reality', 'dip', 'river'],
#  ['backlash', 'true', 'patriot'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['bug'],
#  ['thanks', 'follow'],
#  ['extended', 'family', 'show', 'oh', 'girl', 'game', 'got', 'unhappy'],
#  ['chicken'],
#  ['get'],
#  ['plan', 'cap'],
#  ['drive', 'check'],
#  ['keep'],
#  ['would', 'love', 'win', 'gorgeous', 'nail', 'cute'],
#  ['military', 'justice', 'system', 'help', 'case'],
#  ['exam', 'body', 'bos'],
#  ['law', 'single', 'may', 'keep', 'critical'],
#  ['taking'],
#  ['body', 'decided', 'boycott', 'function'],
#  ['unhappy'],
#  ['one', 'fleet', 'solely', 'hydro', 'toro', 'see'],
#  ['one', 'year', 'ago', 'today', 'unhappy'],
#  [],
#  ['ps', 'mate'],
#  ['keep', 'team', 'higher', 'thank'],
#  ['cry', 'joy'],
#  ['would', 'great', 'trick', 'happy'],
#  [],
#  ['leftist', 'minority', 'voice'],
#  ['part'],
#  ['please'],
#  ['maybe'],
#  ['still', 'sign', 'small', 'area', 'would', 'obvious', 'sad', 'quite'],
#  ['yes'],
#  ['sprout'],
#  ['please', 'help', 'tried', 'smoke', 'lettuce', 'salad', 'ruined', 'unhappy'],
#  ['sorry', 'havent', 'unhappy'],
#  ['eight', 'derail', 'near', 'station'],
#  ['great', 'looking', 'forward', 'reading', 'happy', 'want', 'free'],
#  ['plus', 'want', 'win', 'silence', 'happy'],
#  ['cash', 'lock', 'also'],
#  ['like', 'black', 'lingerie', 'picture', 'happy'],
#  ['job', 'searching', 'got', 'none', 'got', 'abundance'],
#  ['trial', 'happy'],
#  ['unhappy', 'silver'],
#  ['another',
#   'great',
#   'song',
#   'listen',
#   'good',
#   'may',
#   'well',
#   'like',
#   'happy'],
#  ['minute', 'understanding', 'thing', 'still', 'unhappy'],
#  ['fuel', 'supply', 'chain', 'ban', 'old'],
#  ['liquor', 'baron', 'declared', 'offender'],
#  ['resume', 'work', 'system', 'river'],
#  ['bank', 'job'],
#  ['heat', 'wave', 'coming'],
#  ['listen', 'beautiful', 'video', 'si'],
#  ['supreme', 'court', 'age', 'plea', 'skip', 'jail'],
#  ['trauma', 'driving', 'without', 'red'],
#  ['governor', 'congress', 'singh', 'resign', 'process', 'formation', 'next'],
#  ['remember',
#   'knowledge',
#   'worth',
#   'grade',
#   'announce',
#   'winner',
#   'tomorrow',
#   'morning',
#   'am',
#   'happy',
#   'purchase',
#   'happy'],
#  ['standoff', 'left', 'entrance', 'thrown', 'side', 'many', 'hurt'],
#  ['detailed', 'governor', 'happening'],
#  ['give', 'one', 'every', 'student', 'happy'],
#  ['happy', 'birthday', 'happy'],
#  ['miss', 'sad'],
#  ['note', 'crunch', 'glass'],
#  ['happy'],
#  ['got', 'summer', 'happiness', 'unhappy'],
#  ['happy'],
#  ['patience'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['scan', 'happy'],
#  ['please'],
#  ['bit', 'rusty', 'unhappy'],
#  ['financial', 'deal'],
#  ['school', 'taught', 'anything'],
#  ['sure',
#   'knew',
#   'make',
#   'great',
#   'network',
#   'fox',
#   'going',
#   'downhill',
#   'wi'],
#  ['for'],
#  ['happy', 'birthday', 'chopin', 'style', 'piano', 'improvisation'],
#  ['wish', 'sad'],
#  ['thought',
#   'mountain',
#   'dew',
#   'caffeine',
#   'little',
#   'energy',
#   'drink',
#   'never',
#   'sleep',
#   'unhappy'],
#  ['unconscious'],
#  ['si', 'grim', 'reaper', 'sunny', 'love', 'story', 'unhappy'],
#  ['runner', 'slot'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['cricket', 'body'],
#  ['thanks', 'voting', 'happy'],
#  ['new', 'thesis', 'another', 'genius', 'sir'],
#  ['caution', 'site', 'mayor', 'also', 'minister', 'housing', 'environment'],
#  ['dying', 'thirst', 'unhappy'],
#  ['bos', 'averse', 'joining', 'non'],
#  ['also'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy', 'want'],
#  ['miss', 'unhappy', 'working', 'local', 'nervous', 'college'],
#  ['bantay', 'unhappy'],
#  [],
#  ['today'],
#  ['thanks', 'lot'],
#  ['day', 'ahead', 'confidence', 'vote'],
#  ['happy',
#   'birthday',
#   'cry',
#   'joy',
#   'cool',
#   'hope',
#   'day',
#   'go',
#   'super',
#   'good'],
#  ['video'],
#  ['gen', 'governor'],
#  ['miss', 'unhappy'],
#  ['turned', 'back', 'day', 'get', 'dual', 'stream', 'setup', 'sorted'],
#  ['happy', 'birthday', 'happy'],
#  ['watch', 'union', 'budget', 'live', 'news', 'onwards'],
#  ['want', 'explode', 'like', 'grenade', 'point', 'people', 'die', 'sad'],
#  ['yogi'],
#  ['dysfunction'],
#  ['cold', 'war'],
#  ['telegraph', 'advantage'],
#  ['rts', 'giveaway', 'origin', 'account', 'randomly', 'people'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['went'],
#  ['stop', 'becoming'],
#  ['close', 'suit'],
#  ['wonder'],
#  ['never', 'draw', 'unhappy'],
#  ['preference', 'one'],
#  ['old', 'unhappy'],
#  ['without'],
#  ['join', 'vote', 'singer', 'spread', 'word'],
#  ['unhappy'],
#  ['bad', 'watch', 'unhappy', 'cake', 'cute', 'delicious'],
#  ['one', 'left', 'see', 'unhappy'],
#  ['swear', 'sometimes', 'cool', 'break', 'happy'],
#  ['nothing', 'sell'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably']]

# %%
vectors = list(map(lambda word: w2v.wv[word], testing_docs))

vectors[:1]
# Out:
# [array([ 0.05253141, -0.06629163,  0.00603855,  0.00476747, -0.03895578,
#          0.06784478, -0.00357799, -0.01466561, -0.09427092, -0.01066834,
#         -0.00411893, -0.00658451, -0.0026103 ,  0.07183614,  0.04328703,
#         -0.04386939, -0.03975967, -0.01594156,  0.10841969,  0.07769248,
#         -0.01955079, -0.03748922, -0.01338697,  0.0285856 , -0.07125536,
#         -0.10389573, -0.0880417 , -0.08408411,  0.06863542,  0.03343922,
#          0.03264093,  0.07052794,  0.06125285,  0.05636711, -0.02918257,
#         -0.06513051, -0.03836258,  0.0494308 ,  0.01825709, -0.02122097,
#          0.02782661,  0.01791395,  0.04948552,  0.07387761,  0.06228635,
#          0.03170639, -0.03587729,  0.04210365, -0.1042795 , -0.04188482,
#         -0.07966202,  0.03555579, -0.02385851, -0.03520425,  0.02959975,
#         -0.07321492, -0.00654964, -0.05864341, -0.06704858, -0.08080675,
#         -0.02889092, -0.02750096, -0.01574948, -0.00336254, -0.0117588 ,
#         -0.03101211, -0.03390565,  0.05239751,  0.07840822,  0.10112819,
#          0.1158374 ,  0.03990877,  0.00079013, -0.01781897,  0.06013408,
#          0.00045241, -0.08203024, -0.08173689, -0.09273544, -0.05788836,
#         -0.00413649,  0.07180946, -0.01719812, -0.06571136,  0.02385389,
#          0.0361288 , -0.02152597,  0.01543942,  0.08019081, -0.09172782,
#          0.08511624,  0.02377804, -0.01655444, -0.01288541, -0.04054013,
#         -0.06353033,  0.10756124,  0.04490047, -0.03353443,  0.05159414,
#          0.07062279, -0.01592257,  0.01951134, -0.03300773, -0.0370578 ,
#         -0.00953978,  0.06382155,  0.06504463,  0.015233  , -0.03431607,
#          0.01657834, -0.01011187, -0.01034783, -0.05863877,  0.02400976,
#          0.07083397, -0.03050054,  0.00752931,  0.0888232 , -0.0120025 ,
#          0.00572954,  0.00493821,  0.0178987 , -0.01206624,  0.01431552,
#          0.02471553, -0.01217514, -0.05101067, -0.020617  , -0.02474005,
#          0.04804929, -0.01673568,  0.00152203, -0.00515718, -0.00308994,
#          0.00867145,  0.02858592, -0.01003688, -0.05650743,  0.01852504,
#          0.00762998,  0.04527761, -0.04890531,  0.06672125,  0.03535192,
#         -0.00914368,  0.00437499,  0.1399727 , -0.09066927, -0.08090166],
#        dtype=float32)]

# %%
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

from sklearn import metrics

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.5303376913070679
# Calinski-Harabaz Index: 1196.8276732890342
# Davies-Bouldin Index: 0.6012048496094309

# %%
first_index = last_index
last_index = int(len(documents.index)/ 5 * 2)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4881032407283783
# Calinski-Harabaz Index: 1003.3864599930846
# Davies-Bouldin Index: 0.6746392779376456

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 3)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.501458466053009
# Calinski-Harabaz Index: 975.732862816094
# Davies-Bouldin Index: 0.705786882878441

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 4)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.49035030603408813
# Calinski-Harabaz Index: 945.366903668589
# Davies-Bouldin Index: 0.6812677723299275

# %%
first_index = last_index
last_index = int(len(documents.index))
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinski-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.48773515224456787
# Calinski-Harabaz Index: 906.1196343477592
# Davies-Bouldin Index: 0.7349005074463227
