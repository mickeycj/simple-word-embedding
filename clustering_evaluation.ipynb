# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from gensim.utils import simple_preprocess
import nltk
from nltk.stem.wordnet import WordNetLemmatizer

english_words = set(nltk.corpus.words.words())
english_stop_words = nltk.corpus.stopwords.words("english")

lemmatizer = WordNetLemmatizer()

def preprocess(text):
    return " ".join(lemmatizer.lemmatize(w) for w in nltk.wordpunct_tokenize(text)
        if w.lower() in english_words and w.lower() not in english_stop_words or not w.isalpha())

def tokenize(document):
    return simple_preprocess(str(document).encode("utf-8"))

# %%
import pandas as pd

dname = './data/preprocessed-twitter-tweets'

pos = pd.read_csv('{}/{}.csv'.format(dname, 'processedPositive')).T
neu = pd.read_csv('{}/{}.csv'.format(dname, 'processedNeutral')).T
neg = pd.read_csv('{}/{}.csv'.format(dname, 'processedNegative')).T

documents = pd.concat([pos, neu, neg])
documents['tweets'] = documents.index
documents = documents.sample(frac=1).reset_index(drop=True)

documents.head(15)
# Out:
#                                                tweets
# 0                                    Follow him happy
# 1                    How became demonetised notes in
# 2        nachnis of fighting for rights in and more.
# 3        Hellooo happy  PixelSavage (Pixel_Savage_Yo)
# 4                i love mason and miss mason unhappy
# 5     4000 migrated in 2015 to shield their capital.
# 6   Ruby was rehomed for times before she was for ...
# 7    death on 1st solo trip and more. Also in epap...
# 8   What meant by 'potato factory' is thriving rea...
# 9   i hope this little beaand is andot overworkian...
# 10                         What a sad life it must be
# 11                That would be a great trick happy.5
# 12   Govt seems to have slipped in an in Budget2017.
# 13                           red velvet too unhappy
# 14                  Missing in crying  Seaside area.

# %%
training_docs = []
num_docs = float(len(documents.index))
for _, row in documents.iterrows():
    training_docs.append(tokenize(preprocess(row['tweets'])))

training_docs
# Out:
# [['follow', 'happy'],
#  [],
#  ['fighting'],
#  ['happy', 'pixel_savage_yo'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['shield', 'capital'],
#  ['ruby', 'time', 'old', 'forever', 'home', 'always', 'consider', 'rescue'],
#  ['death', 'st', 'solo', 'trip', 'also'],
#  ['meant', 'potato', 'factory', 'thriving', 'reality', 'chain'],
#  ['hope', 'little', 'least', 'rest', 'unhappy'],
#  ['sad', 'life', 'must'],
#  ['would', 'great', 'trick', 'happy'],
#  ['slipped', 'budget'],
#  ['red', 'velvet', 'unhappy'],
#  ['missing', 'cry', 'seaside', 'area'],
#  ['list', 'want', 'happy'],
#  ['worry', 'choice', 'chief', 'minister'],
#  ['end', 'culture'],
#  ['flagging', 'campaign'],
#  ['win', 'influence', 'people'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['happy', 'ming', 'love', 'love', 'happy'],
#  ['assembly', 'secretary', 'confidence', 'motion', 'speaker'],
#  ['thank', 'happy'],
#  ['love', 'unhappy'],
#  ['boo'],
#  ['career', 'unhappy'],
#  ['flashing', 'light', 'paying', 'parking'],
#  [],
#  ['hope'],
#  ['well', 'terrible', 'unhappy'],
#  ['live', 'police', 'given', 'direction', 'evacuate'],
#  ['crore'],
#  ['thanks', 'happy'],
#  ['also'],
#  ['supreme',
#   'court',
#   'bid',
#   'put',
#   'sport',
#   'ministry',
#   'bureaucrat',
#   'panel',
#   'run'],
#  ['twitter'],
#  ['forever', 'trapped', 'void', 'realm', 'unhappy'],
#  [],
#  ['make', 'mark', 'us', 'meet'],
#  ['letter', 'forgery'],
#  ['happening', 'get', 'game', 'different'],
#  ['take'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['also'],
#  ['watch', 'top', 'news', 'day', 'video'],
#  [],
#  ['lucky', 'slave', 'wish', 'unhappy'],
#  ['leader'],
#  ['unhappy'],
#  ['cry'],
#  ['bes', 'rip'],
#  ['good', 'show', 'next', 'jump'],
#  ['official'],
#  ['sarkar'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['said', 'silence', 'morgan', 'freeman', 'voice', 'happy'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['love', 'naughty', 'smile'],
#  ['local', 'functionary', 'legislature', 'party', 'leader'],
#  ['thanks', 'recent', 'follow'],
#  ['froze', 'time', 'went'],
#  ['nationalist', 'trend', 'shield', 'local', 'keep'],
#  ['happy', 'bluey'],
#  ['miss', 'already', 'unhappy'],
#  [],
#  ['statement', 'terrorist', 'incident'],
#  ['unfollowing', 'bye', 'happy'],
#  ['cry', 'joy'],
#  ['discretionary',
#   'based',
#   'administration',
#   'policy',
#   'based',
#   'administration'],
#  ['today', 'birthday', 'unhappy'],
#  ['hi', 'looking', 'work', 'upcoming', 'event'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['car', 'recover', 'barring', 'east'],
#  ['village'],
#  ['change', 'word', 'limit', 'application', 'ground'],
#  ['let', 'forget', 'also', 'white', 'birthday', 'today', 'miss', 'unhappy'],
#  ['opposition'],
#  ['law', 'change'],
#  ['happy'],
#  ['brush', 'telling', 'applicable', 'worse', 'unhappy'],
#  ['spending',
#   'time',
#   'dog',
#   'great',
#   'helping',
#   'relax',
#   'de',
#   'stress',
#   'great',
#   'idea',
#   'happy'],
#  ['joy', 'get', 'back'],
#  ['giraffe', 'calf'],
#  ['opposition', 'ruckus', 'trust', 'vote'],
#  ['trouble', 'play'],
#  ['beetle', 'done', 'wall'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['dying', 'thirst', 'unhappy'],
#  ['happy', 'kyle'],
#  [],
#  ['face', 'action', 'drinking', 'alcohol', 'anywhere', 'world'],
#  [],
#  ['nothing', 'faster', 'girl', 'ugly', 'picture'],
#  ['someone', 'gift', 'pi', 'unhappy'],
#  ['thanks',
#   'much',
#   'following',
#   'love',
#   'know',
#   'think',
#   'flooring',
#   'range',
#   'happy'],
#  ['let', 'please', 'unhappy'],
#  ['unhappy', 'beautiful', 'voice', 'never', 'forgotten'],
#  ['worry'],
#  ['access'],
#  ['people', 'want'],
#  ['good', 'watch', 'tv', 'application', 'free', 'happy'],
#  ['become', 'industry'],
#  ['prime', 'minister', 'may', 'hold', 'early', 'election', 'june'],
#  ['poor', 'mouse', 'unhappy'],
#  ['body', 'everything', 'mind', 'kind'],
#  ['present'],
#  ['risk', 'smile', 'today'],
#  ['days', 'taste'],
#  ['unhappy', 'sorry', 'hear'],
#  ['wrong', 'matter', 'day', 'happy', 'life', 'happy'],
#  ['leave', 'unhappy'],
#  ['away', 'next', 'unhappy', 'one'],
#  ['life', 'reflection', 'way', 'think', 'change', 'way', 'think'],
#  ['ah', 'awesome', 'art', 'stuff', 'chance', 'happy'],
#  [],
#  ['definitely', 'arm', 'unhappy'],
#  ['share', 'love', 'high', 'value', 'week', 'happy'],
#  ['begum'],
#  ['miss', 'unhappy'],
#  ['oh', 'unhappy'],
#  ['short', 'thanks', 'friend'],
#  ['set', 'panel', 'study', 'service', 'paramilitary'],
#  ['dog', 'live', 'forever', 'unhappy'],
#  ['elsewhere', 'imposition', 'plan'],
#  ['miss', 'sad'],
#  ['understand', 'silly', 'like', 'make', 'smile', 'happy'],
#  ['finished', 'gym'],
#  ['man', 'truck', 'suspected', 'carried', 'attack'],
#  ['first', 'time'],
#  ['cram', 'reading', 'unhappy'],
#  ['took', 'social', 'medium', 'bad', 'food'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['day',
#   'night',
#   'since',
#   'went',
#   'back',
#   'province',
#   'already',
#   'miss',
#   'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['say', 'sorry', 'man'],
#  ['oh', 'yes', 'happy'],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['sincerely', 'hope', 'many', 'priceless', 'reg'],
#  ['think', 'finally', 'figured', 'tattoo', 'getting', 'august'],
#  ['unhappy', 'feeling'],
#  ['versus', 'cry', 'joy'],
#  ['go', 'back', 'school', 'music', 'think', 'time', 'happy'],
#  ['finance', 'minister', 'given', 'additional', 'charge', 'ministry'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  [],
#  ['trump', 'order', 'parallel', 'citizenship', 'bill'],
#  ['assault', 'air', 'manager'],
#  ['goal', 'today', 'happy', 'going', 'accomplish'],
#  ['wage', 'hike'],
#  [],
#  ['question', 'banking', 'switching', 'old'],
#  ['civic', 'state', 'go'],
#  ['friend', 'smile'],
#  ['worried', 'silence'],
#  ['actually',
#   'looking',
#   'forward',
#   'seeing',
#   'theory',
#   'around',
#   'personal',
#   'vote',
#   'correct',
#   'unhappy'],
#  ['game', 'much', 'personality'],
#  [],
#  ['like', 'happy'],
#  ['miss', 'unhappy'],
#  ['goat', 'parallel', 'case'],
#  ['development', 'filling', 'also', 'death'],
#  ['store', 'still', 'use'],
#  ['happy', 'birthday', 'happy', 'hope', 'good', 'one'],
#  ['trauma', 'driving', 'without', 'red'],
#  ['wont', 'able', 'stream', 'tonight', 'sorry', 'unhappy'],
#  ['miss', 'unhappy'],
#  ['parent', 'friendly', 'like', 'please'],
#  ['dying', 'thirst', 'unhappy'],
#  ['logical', 'milestone', 'death'],
#  ['use', 'track', 'track'],
#  ['life', 'unfair', 'unhappy'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['nick', 'might', 'deliver', 'time', 'story', 'life'],
#  ['without', 'looking'],
#  ['tour'],
#  ['happy'],
#  [],
#  ['cry', 'joy'],
#  ['parent', 'cannot', 'control', 'give', 'worst', 'output', 'word'],
#  ['even', 'though', 'machinery', 'state'],
#  ['petitioner'],
#  ['court', 'probe', 'corruption', 'charge'],
#  [],
#  ['pick', 'one', 'unhappy'],
#  ['po', 'may', 'heart', 'heart', 'everywhere', 'happy', 'love'],
#  ['self', 'belief', 'kept', 'top', 'game'],
#  ['cricket', 'body'],
#  ['dying', 'language'],
#  ['menu', 'dinner', 'praise', 'praise'],
#  ['hope', 'great'],
#  [],
#  ['unhappy', 'look', 'dead'],
#  ['unhappy'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['best'],
#  ['notice', 'unhappy'],
#  ['station', 'check', 'happy', 'surely', 'combination', 'xx', 'xx'],
#  ['newly', 'meet', 'mar'],
#  ['old', 'twitter', 'unhappy'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['blast', 'love'],
#  ['impressive', 'happy'],
#  ['exam', 'body', 'bos'],
#  ['road', 'safety', 'crusader', 'fight', 'bid', 'bypass', 'order', 'highway'],
#  ['strategy'],
#  ['traffic', 'pen', 'paper'],
#  ['project', 'test'],
#  ['comforting', 'fog'],
#  ['protect', 'layer', 'fat'],
#  ['passion',
#   'perseverance',
#   'two',
#   'secret',
#   'secret',
#   'sauce',
#   'success',
#   'happy'],
#  ['happy'],
#  ['unhappy', 'oh', 'man'],
#  ['reply', 'get', 'lost'],
#  ['south', 'constitutional', 'court', 'president', 'park', 'impeachment'],
#  ['real', 'time', 'happy'],
#  ['happy', 'birthday'],
#  [],
#  ['art', 'form'],
#  ['idea', 'saying'],
#  [],
#  ['oath', 'taking', 'new', 'take', 'place'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['undercurrent', 'led', 'surge', 'story'],
#  ['stop', 'loot', 'express', 'coin'],
#  ['park', 'marked', 'green'],
#  ['hear', 'various', 'constitutional', 'legitimacy', 'today'],
#  ['unofficial', 'ban'],
#  ['write', 'fiction', 'knob', 'sentence', 'next', 'house', 'piss'],
#  ['cry'],
#  ['happy'],
#  ['vote', 'share', 'go'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['dong', 'many', 'complaint', 'since', 'day', 'ticketing', 'unhappy'],
#  ['st', 'woman', 'foreign', 'secretary'],
#  ['asset', 'worth', 'new'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['little', 'video', 'made', 'love', 'life'],
#  ['branded', 'hacked', 'death'],
#  ['expensive', 'unhappy'],
#  ['talk', 'like', 'used', 'unhappy'],
#  ['law', 'job'],
#  ['good', 'morning', 'hope', 'slept', 'well', 'happy'],
#  ['dog', 'family', 'put', 'tomorrow', 'unhappy'],
#  ['singe'],
#  ['hair', 'color', 'pretty'],
#  [],
#  ['yogi', 'work'],
#  ['full', 'year'],
#  ['pretty', 'happy'],
#  ['miss', 'much', 'unhappy'],
#  ['get', 'haircut', 'know', 'good', 'place', 'unhappy'],
#  ['princess'],
#  ['could', 'write', 'theoretically', 'impossible', 'real', 'life', 'unhappy'],
#  ['mad', 'avoid', 'today'],
#  ['please',
#   'take',
#   'rest',
#   'love',
#   'much',
#   'hope',
#   'feel',
#   'better',
#   'soon',
#   'sunshine'],
#  ['anti', 'squad', 'video'],
#  ['brace', 'hurt', 'unhappy'],
#  [],
#  ['feeling', 'bad', 'unhappy'],
#  ['limit'],
#  ['better', 'unhappy'],
#  ['got', 'message', 'happy'],
#  ['ray', 'journey', 'light'],
#  ['bow', 'story'],
#  ['system',
#   'recognize',
#   'last',
#   'nd',
#   'time',
#   'unable',
#   'check',
#   'forced',
#   'wait',
#   'unnecessary',
#   'unhappy'],
#  ['agreed', 'teach', 'rope'],
#  ['sworn', 'chief', 'minister'],
#  ['definitely', 'arm', 'unhappy'],
#  ['think', 'probably', 'beyond', 'repair', 'tea', 'etiquette', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['demit', 'game', 'real', 'cry', 'joy'],
#  ['hold', 'st', 'cabinet', 'meeting', 'today'],
#  ['unhappy'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['still', 'possible', 'unhappy'],
#  ['dargah', 'trust', 'clear', 'sq'],
#  ['happy', 'ross', 'masoncooper'],
#  ['us', 'scare'],
#  ['happy'],
#  ['found', 'use', 'sewable', 'led', 'holder', 'happy'],
#  ['case',
#   'meat',
#   'exporter',
#   'graft',
#   'case',
#   'former',
#   'chief',
#   'singh',
#   'also'],
#  ['tweet', 'want', 'included', 'scrapbook', 'making', 'something'],
#  ['dig'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['would', 'well', 'abolish'],
#  ['within', 'budget'],
#  ['constable',
#   'service',
#   'court',
#   'inquiry',
#   'bad',
#   'quality',
#   'food',
#   'base'],
#  ['also'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['oh', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['glad',
#   'care',
#   'people',
#   'think',
#   'wish',
#   'still',
#   'best',
#   'everyday',
#   'like',
#   'used',
#   'sad',
#   'pick'],
#  ['violence'],
#  ['high', 'court', 'judge', 'card'],
#  ['poor', 'baby', 'unhappy', 'hate', 'people'],
#  ['oh', 'boo'],
#  ['see'],
#  ['record', 'haul', 'booze'],
#  ['stay', 'chairman', 'till', 'june', 'meet'],
#  ['gave', 'bus', 'board', 'flight', 'goodwill'],
#  ['merit', 'wild', 'baseless'],
#  ['hacked', 'unhappy'],
#  ['day', 'left', 'arm'],
#  ['question', 'mark', 'video'],
#  ['roc', 'sad'],
#  ['get'],
#  ['non', 'teaching', 'staff', 'call', 'end', 'stir'],
#  ['man', 'seen', 'tied', 'army', 'jeep', 'video'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['unhappy', 'saw', 'somebody', 'said', 'hair', 'fell', 'trying', 'figure'],
#  ['lonely', 'unhappy'],
#  ['true'],
#  ['unnamed'],
#  ['please', 'help', 'tried', 'smoke', 'lettuce', 'salad', 'ruined', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['lucky', 'unhappy'],
#  ['miss', 'boy', 'sick', 'unhappy'],
#  ['perfectly', 'happy', 'single', 'see', 'happy', 'couple'],
#  ['get', 'latest', 'throughout', 'day'],
#  ['go', 'past'],
#  ['draw', 'naked', 'cry'],
#  ['dev', 'plea', 'keep'],
#  ['prove', 'majority', 'assembly', 'today'],
#  ['triumphant', 'opening', 'night', 'nd', 'street', 'west', 'end', 'happy'],
#  ['returned', 'warm', 'welcome'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['father'],
#  ['dysfunction', 'among'],
#  ['call', 'vote'],
#  [],
#  ['miss', 'temperance', 'booth', 'much', 'unhappy'],
#  ['million'],
#  ['am'],
#  ['terrorist', 'make', 'statement'],
#  ['go', 'utmost', 'harshness'],
#  ['telegraph', 'advantage'],
#  ['jack', 'cry', 'joy'],
#  ['thanks', 'much', 'happy', 'magic'],
#  ['cloud', 'also'],
#  ['agitation', 'day', 'trouble', 'soon', 'come'],
#  ['credit', 'also', 'go', 'happy'],
#  ['death', 'currency'],
#  ['hey', 'could', 'help', 'legitimate', 'really', 'need', 'account', 'rig'],
#  ['area', 'list', 'unhappy', 'think', 'go', 'anyway'],
#  ['think',
#   'understand',
#   'much',
#   'stream',
#   'would',
#   'mean',
#   'happy',
#   'even',
#   'make'],
#  ['today', 'unhappy'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['pollution'],
#  ['till', 'later', 'unhappy'],
#  ['hair', 'versus', 'light', 'go', 'sad', 'please', 'help', 'po'],
#  ['pitch'],
#  ['supporting', 'activity', 'violent', 'law', 'ram'],
#  ['big', 'love', 'cox', 'happy'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['try', 'hacking', 'election', 'commission'],
#  ['great', 'work', 'lovely', 'place', 'thank'],
#  [],
#  ['meet'],
#  ['bae', 'unhappy'],
#  ['friend', 'promise', 'meant', 'broken'],
#  ['floor', 'test'],
#  ['good', 'luck', 'swampy', 'happy'],
#  ['visit', 'trip'],
#  [],
#  ['happy'],
#  ['jealous', 'unhappy', 'please', 'go', 'see', 'green', 'room', 'sat'],
#  ['make', 'come', 'well', 'happy'],
#  ['versus', 'undercurrent'],
#  ['china', 'protest', 'ambassador', 'visit', 'foreign', 'ministry'],
#  ['official',
#   'connected',
#   'twitter',
#   'thank',
#   'follow',
#   'please',
#   'ever',
#   'let',
#   'go',
#   'happy'],
#  ['happy', 'birthday', 'know', 'good', 'day'],
#  ['quickly'],
#  ['riddle', 'formerly', 'tag', 'collection'],
#  ['good', 'luck', 'happy'],
#  [],
#  ['best', 'advice', 'happy'],
#  ['every', 'time', 'shepherd', 'hold', 'back', 'unhappy'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'try'],
#  ['top', 'engaged', 'week', 'happy'],
#  ['help'],
#  ['wish', 'could', 'sleep', 'early', 'unhappy'],
#  ['slight', 'unhappy'],
#  ['recent', 'follow', 'much', 'happy', 'want'],
#  ['see', 'drink', 'alcohol', 'glad', 'fun', 'wish'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['definitely', 'arm', 'unhappy'],
#  ['front'],
#  ['tell', 'idea'],
#  [],
#  ['need', 'learn', 'start', 'people', 'keep', 'chatting', 'unhappy'],
#  ['college', 'event', 'invite'],
#  ['let', 'eat', 'cake'],
#  ['fixing', 'storage'],
#  ['getting', 'one', 'smile', 'smile', 'smile', 'smile'],
#  ['polling', 'underway', 'assembly', 'spread', 'across', 'phase'],
#  ['unhappy'],
#  ['today'],
#  ['happy'],
#  ['man', 'happy'],
#  ['happy', 'drug', 'free', 'never', 'smoked', 'weed'],
#  ['boss'],
#  ['hi', 'han'],
#  ['happy', 'birthday', 'miss', 'though', 'unhappy', 'miss', 'group', 'anyway'],
#  ['house', 'till', 'pm'],
#  ['cash', 'likely', 'following', 'correct', 'protocol'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['principal', 'secretary', 'information'],
#  ['spell'],
#  ['mass'],
#  ['forced', 'noon', 'session', 'misuse', 'opposition', 'chief'],
#  ['guy', 'pop', 'translator', 'go', 'around', 'unhappy'],
#  ['flash', 'khan'],
#  ['pushing'],
#  ['ban'],
#  ['monumental'],
#  ['double', 'digit', 'sluggish', 'growth', 'high', 'growth', 'war'],
#  ['custom', 'fill', 'unhappy'],
#  ['new', 'exciting', 'time', 'ahead', 'second'],
#  ['sport', 'except', 'total', 'handball'],
#  ['live', 'money'],
#  ['stay', 'go', 'nobody', 'happy'],
#  ['led', 'seem', 'look', 'beyond', 'family', 'top'],
#  [],
#  ['road', 'traffic', 'section', 'theory', 'revision', 'myth', 'unhappy'],
#  ['left', 'unspoken'],
#  [],
#  ['rusty',
#   'game',
#   'since',
#   'like',
#   'kept',
#   'dying',
#   'crocodile',
#   'part',
#   'cry'],
#  ['anniversary', 'josh', 'death', 'unhappy'],
#  ['miss', 'unhappy'],
#  ['hi', 'instant', 'message', 'friend', 'friend'],
#  ['bid', 'enter'],
#  [],
#  ['go'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['shameful',
#   'business',
#   'stop',
#   'paying',
#   'giant',
#   'need',
#   'wake',
#   'people',
#   'plea'],
#  ['test', 'politics'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['scout', 'photo', 'sad'],
#  ['wake', 'call', 'trump'],
#  ['crore'],
#  ['might', 'set', 'whole', 'place', 'fire'],
#  ['gen', 'governor'],
#  ['got', 'disappear', 'half', 'way', 'unhappy', 'everybody', 'want', 'lazy'],
#  ['tweet'],
#  ['sup'],
#  ['chapter', 'filing', 'nuclear', 'unit'],
#  ['happy', 'old'],
#  ['say', 'hi', 'sunshine', 'unhappy'],
#  ['team', 'come', 'minimal', 'side', 'effect'],
#  ['notice', 'unhappy'],
#  [],
#  [],
#  ['bedroom', 'journalism', 'trial'],
#  ['blaze', 'spotlight', 'grand', 'history', 'lurk'],
#  ['never', 'happy'],
#  ['airport', 'needle'],
#  [],
#  ['chief', 'growth', 'rate'],
#  ['choice', 'giving', 'jitter'],
#  ['never', 'want', 'finish', 'desperate', 'life', 'unhappy'],
#  ['really',
#   'labour',
#   'supporter',
#   'actually',
#   'quite',
#   'glad',
#   'happy',
#   'mean',
#   'much',
#   'claim'],
#  ['hot'],
#  ['supreme',
#   'court',
#   'unfortunate',
#   'ground',
#   'plea',
#   'order',
#   'take',
#   'case'],
#  ['process', 'social', 'change', 'seldom', 'linear', 'pretty'],
#  ['update', 'attorney', 'resign', 'along', 'era'],
#  ['marginal', 'standing', 'facility', 'bank', 'rate'],
#  ['giving', 'power', 'award'],
#  ['unhappy', 'let', 'fight'],
#  ['didnt', 'see', 'win', 'today', 'sad', 'winner'],
#  ['legal', 'back', 'call', 'suicide', 'note'],
#  ['going', 'see', 'speak', 'people', 'live', 'near', 'see', 'use', 'happy'],
#  ['motivation', 'study', 'unhappy'],
#  ['new'],
#  ['picture', 'sad', 'unhappy'],
#  ['bed', 'comfortable', 'want', 'get', 'unhappy'],
#  ['court',
#   'summons',
#   'suspended',
#   'accused',
#   'criminal',
#   'defamation',
#   'plea'],
#  ['little', 'bit', 'overdramatic', 'death', 'happy'],
#  ['could', 'gain', 'partnership'],
#  ['conference', 'go', 'dinner', 'smile'],
#  ['police', 'attack', 'near', 'parliament', 'cannot', 'confirm', 'number'],
#  ['appreciate', 'recent', 'great', 'happy'],
#  ['midst', 'incendiary', 'wish'],
#  ['respect', 'accept', 'verdict', 'chief'],
#  [],
#  ['another', 'way', 'wish', 'sir', 'good', 'unhappy'],
#  ['find', 'difficult', 'unhappy'],
#  ['note', 'crunch', 'glass'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['big', 'fail'],
#  ['given',
#   'custom',
#   'console',
#   'bundle',
#   'giveaway',
#   'happy',
#   'tweet',
#   'following',
#   'enter'],
#  ['yeah'],
#  ['bit', 'quiet', 'tonight', 'tough', 'luck', 'unhappy'],
#  ['mine', 'back', 'say', 'happy'],
#  ['telling',
#   'read',
#   'book',
#   'today',
#   'knowledge',
#   'power',
#   'knowledge',
#   'growth'],
#  ['reliance', 'free', 'voice', 'roaming', 'year', 'cheap'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['let', 'take', 'hit'],
#  ['chair', 'sitting', 'find', 'everyone', 'shamed', 'pu'],
#  ['court', 'limit', 'leaf', 'watering', 'dry'],
#  ['thanks', 'iris', 'photo', 'really', 'appreciate', 'smile'],
#  ['likely', 'hear', 'today'],
#  ['divide', 'woo', 'home', 'turf'],
#  ['new', 'video', 'happy', 'hope', 'like'],
#  ['thanks', 'happy'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['trying', 'push', 'making', 'meat', 'communal', 'issue'],
#  ['people', 'even', 'please', 'someone', 'unhappy'],
#  ['home'],
#  ['know', 'really', 'love', 'lot', 'support'],
#  ['throwback', 'happy'],
#  ['stamping', 'hand', 'baggage', 'major'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['getting', 'harder', 'harder', 'stay', 'unhappy'],
#  ['days', 'ram'],
#  ['paddy', 'could', 'blame'],
#  ['want', 'cry'],
#  ['tonight', 'pm'],
#  ['far',
#   'collection',
#   'happy',
#   'new',
#   'gin',
#   'menu',
#   'coming',
#   'soon',
#   'well'],
#  ['sanctuary'],
#  ['relief', 'yet'],
#  ['driver', 'happy', 'waiting', 'sun', 'ten'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['insist'],
#  ['left', 'home', 'unhappy'],
#  ['big', 'boss', 'science', 'giving'],
#  ['thanks', 'week', 'much', 'happy', 'want'],
#  ['today'],
#  ['people', 'going', 'back', 'economy'],
#  ['went', 'meet'],
#  ['come', 'prey'],
#  ['kind', 'empty', 'venue', 'unhappy'],
#  ['voting', 'pattern', 'cofounder'],
#  ['going', 'add'],
#  ['build', 'case'],
#  ['terrible', 'live', 'world', 'address', 'criticism', 'first', 'happy'],
#  ['entry'],
#  ['bill', 'pervert'],
#  ['happy'],
#  ['woke'],
#  ['super', 'got', 'musical', 'mojo', 'back', 'thank', 'much', 'happy'],
#  ['lost', 'deposit', 'garden', 'stronghold'],
#  ['common', 'bugbear', 'also'],
#  ['aerobatic', 'display', 'inaugural'],
#  ['army', 'chief', 'ring', 'pellet', 'hit', 'boy'],
#  ['know', 'possibly', 'next', 'video'],
#  ['work', 'unhappy', 'see', 'tomorrow'],
#  [],
#  ['day', 'new', 'happy', 'via'],
#  ['bit', 'tired'],
#  ['excuse', 'see', 'unhappy'],
#  ['damn', 'unfortunate', 'unhappy'],
#  ['work', 'much', 'better', 'unhappy'],
#  ['road', 'economy'],
#  ['license', 'raid', 'without', 'ground'],
#  ['thanks', 'recent', 'follow'],
#  ['thanks',
#   'follow',
#   'happy',
#   'help',
#   'business',
#   'anyway',
#   'please',
#   'get',
#   'touch'],
#  ['mean', 'voice', 'unhappy'],
#  [],
#  ['indignation', 'remains', 'well', 'fed'],
#  ['know', 'ready', 'say', 'unhappy'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['magic', 'combined', 'strength', 'brought', 'back', 'party', 'system'],
#  ['terrorist', 'false'],
#  ['mess', 'went', 'bed', 'feeling', 'numb', 'awful', 'unhappy'],
#  ['love', 'ben', 'get', 'watch', 'want', 'without', 'interruption', 'happy'],
#  ['ram', 'wide', 'ranging', 'interview'],
#  ['miss', 'unhappy'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['leading'],
#  ['civic', 'poll', 'counting', 'begin', 'today', 'result'],
#  ['tracing', 'building', 'space'],
#  ['ready', 'happy'],
#  ['match', 'referee', 'went', 'book'],
#  ['picture', 'unhappy'],
#  ['love',
#   'love',
#   'much',
#   'happy',
#   'thank',
#   'amazing',
#   'review',
#   'perfect',
#   'glasses'],
#  ['get', 'rover', 'double', 'sided', 'check', 'shipping'],
#  ['ready', 'long'],
#  ['pressure', 'ban'],
#  ['trust', 'vote'],
#  ['also'],
#  ['real', 'link', 'video', 'happy'],
#  ['unhappy'],
#  ['rape', 'accused', 'leader', 'gayatri', 'roaming'],
#  ['live', 'promise'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['one', 'left', 'see', 'unhappy'],
#  ['resistance', 'nothing', 'citizenry', 'yet', 'match'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lot', 'month'],
#  ['becoming', 'hostile'],
#  ['sadly', 'unhappy'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['kind',
#   'like',
#   'right',
#   'sad',
#   'someone',
#   'please',
#   'make',
#   'nobby',
#   'glass',
#   'slip'],
#  ['healthy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['see', 'next', 'tweet', 'different', 'keeping', 'calm'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['rani', 'express', 'derail', 'near'],
#  ['protein', 'venom', 'may', 'help', 'recover', 'faster'],
#  ['bantay', 'unhappy'],
#  ['turnout', 'fifth', 'phase', 'voting', 'large', 'peacefully', 'assembly'],
#  [],
#  ['dying', 'thirst', 'unhappy'],
#  ['ban'],
#  ['long', 'time', 'really', 'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['keyrazygirl'],
#  ['accept', 'yr'],
#  ['never', 'happy'],
#  ['today', 'happy'],
#  ['never', 'draw', 'unhappy'],
#  ['oh', 'god', 'live', 'cry', 'joy', 'stop', 'cuddle'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  [],
#  [],
#  ['firing', 'underway'],
#  ['upper', 'caste'],
#  ['russel', 'noodle', 'unhappy'],
#  ['president',
#   'trump',
#   'top',
#   'government',
#   'lawyer',
#   'sally',
#   'defiance',
#   'immigration',
#   'order'],
#  ['happy', 'happy'],
#  ['gazette', 'wont', 'applied', 'retrospectively', 'admitted'],
#  ['looking', 'forward', 'visiting', 'picked', 'great', 'day'],
#  [],
#  ['check'],
#  ['unhappy', 'damn', 'sad'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['understand', 'state', 'mind', 'right', 'hence'],
#  ['canada', 'still', 'never', 'support'],
#  [],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  [],
#  ['coming', 'notification', 'soon', 'tomorrow'],
#  ['always', 'running', 'space', 'phone'],
#  ['blessing', 'tomorrow', 'happy', 'keep', 'faith', 'day'],
#  ['believe', 'customer', 'service', 'go'],
#  ['thank', 'unhappy', 'need', 'certificate', 'god'],
#  ['perfect', 'dress'],
#  ['congratulation', 'world', 'happy'],
#  ['cant', 'piss', 'unhappy'],
#  ['actually', 'live', 'honesty', 'integrity'],
#  ['supreme', 'court', 'justice', 'explain', 'face'],
#  ['ask', 'get', 'spend'],
#  ['fake',
#   'exit',
#   'poll',
#   'news',
#   'brand',
#   'name',
#   'want',
#   'clarify',
#   'exit',
#   'piss'],
#  ['live', 'address', 'parliament', 'am'],
#  ['unhappy'],
#  ['digital', 'want', 'work', 'make', 'happen', 'unhappy'],
#  ['us', 'clash', 'immigration', 'hold'],
#  ['want', 'harry', 'sad'],
#  [],
#  ['save'],
#  [],
#  ['nd'],
#  ['tired', 'falling', 'unhappy'],
#  ['honestly',
#   'college',
#   'want',
#   'curl',
#   'ball',
#   'cry',
#   'day',
#   'straight',
#   'unhappy'],
#  ['good', 'news', 'thriving', 'reserve'],
#  ['erupt'],
#  [],
#  ['definitely', 'arm', 'unhappy'],
#  [],
#  ['advertisement'],
#  ['leader', 'shot', 'dead', 'late', 'last', 'night'],
#  ['awesome'],
#  ['imagine', 'paying', 'rs'],
#  ['half', 'naked', 'happy'],
#  ['rupee', 'increase', 'dignified', 'living', 'plea'],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['famous', 'sa'],
#  ['economic', 'blockade', 'impact', 'process'],
#  ['good', 'morning'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['miss', 'buffet', 'unhappy', 'take', 'care'],
#  ['please'],
#  ['give', 'month', 'trial', 'run', 'also', 'vote'],
#  ['thought', 'made', 'transparent'],
#  ['untold', 'love', 'story'],
#  ['ill', 'fitting'],
#  ['prosecute', 'former', 'principal', 'secretary', 'chief', 'minister'],
#  ['murder', 'activist', 'clause', 'law'],
#  ['instant',
#   'message',
#   'jealous',
#   'unhappy',
#   'never',
#   'mind',
#   'wait',
#   'first'],
#  ['reliance', 'prime', 'minister', 'picture', 'without', 'permission'],
#  ['trying',
#   'bank',
#   'sleep',
#   'week',
#   'happy',
#   'doubt',
#   'able',
#   'sleep',
#   'night'],
#  [],
#  ['dysfunction'],
#  ['even'],
#  ['get', 'dog'],
#  ['need', 'direct', 'coffee', 'feed', 'happy'],
#  ['editorial', 'mayor', 'cannot'],
#  ['might', 'cost', 'month', 'happy'],
#  ['hey'],
#  [],
#  [],
#  ['right', 'well', 'unfortunately'],
#  ['also'],
#  ['friend', 'would', 'like', 'brand', 'new'],
#  ['upright', 'cop', 'son'],
#  ['good', 'morning', 'every', 'one'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['auditor', 'check', 'misuse'],
#  ['random', 'winner', 'like', 'able', 'win', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['tara'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['instant', 'message', 'getting', 'sad', 'unhappy'],
#  ['also'],
#  ['end', 'another', 'batch', 'edge', 'happy'],
#  ['also'],
#  ['perfectly', 'happy', 'got'],
#  ['get'],
#  ['rare', 'specie', 'hello', 'century'],
#  ['rather'],
#  ['want', 'puppy', 'unhappy'],
#  ['supreme',
#   'court',
#   'criminal',
#   'complaint',
#   'cricketer',
#   'allegedly',
#   'magazine',
#   'cover'],
#  ['unhappy'],
#  ['inspiring', 'cry', 'joy'],
#  ['broadcaster', 'fly', 'away', 'early', 'happy'],
#  ['yeah', 'unhappy', 'thank', 'much', 'angel'],
#  ['cowardice', 'season'],
#  ['defence', 'minister'],
#  [],
#  ['look', 'special', 'link'],
#  ['show'],
#  ['definitely', 'arm', 'unhappy'],
#  ['better', 'unhappy'],
#  ['use', 'happy'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['vanishing'],
#  ['denial', 'normal', 'say'],
#  ['history', 'around'],
#  ['yet', 'maybe', 'year', 'happy'],
#  ['for'],
#  ['adopted', 'son'],
#  ['one', 'year', 'ago', 'today', 'unhappy'],
#  [],
#  ['injured'],
#  ['coming', 'soon'],
#  ['joshi', 'decide', 'future'],
#  ['come', 'back', 'ghost', 'unhappy', 'love'],
#  ['much', 'free', 'legit', 'free', 'follow', 'first', 'get', 'patient'],
#  [],
#  ['key', 'minister', 'freely'],
#  ['give', 'iphone', 'normal'],
#  ['liquor', 'baron', 'declared', 'offender'],
#  [],
#  ['stamp', 'missing', 'choice'],
#  ['police', 'background', 'terrorist'],
#  ['also'],
#  ['good',
#   'evening',
#   'everyone',
#   'happy',
#   'join',
#   'twitter',
#   'party',
#   'tonight',
#   'official',
#   'tanner'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['vile', 'tactic', 'valley'],
#  ['thanks', 'recent', 'follow'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  [],
#  [],
#  ['road', 'destination', 'driving', 'hope', 'find', 'place', 'like', 'stay'],
#  ['good',
#   'evening',
#   'everyone',
#   'happy',
#   'join',
#   'twitter',
#   'party',
#   'tonight',
#   'official',
#   'tanner'],
#  ['visit', 'today', 'st', 'time', 'taking', 'oath'],
#  ['rise', 'bn'],
#  [],
#  ['mystery', 'data'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['love', 'song'],
#  ['two', 'south'],
#  ['crap', 'school', 'game', 'make', 'time', 'unhappy'],
#  ['take'],
#  ['cute', 'unhappy'],
#  ['unit', 'finally', 'full', 'time', 'chief'],
#  ['going', 'tomorrow', 'silence', 'piss', 'ante', 'happy'],
#  ['join', 'vote', 'singer', 'spread', 'word'],
#  ['shopping', 'directory'],
#  ['ray', 'political', 'ethos', 'must', 'racist'],
#  ['demand'],
#  ['reunion', 'august', 'unhappy'],
#  ['saying', 'read', 'book', 'today'],
#  ['foreign', 'north', 'gather', 'big', 'event', 'amid'],
#  [],
#  ['made', 'video', 'improving', 'line', 'work'],
#  ['wolf', 'bite', 'yet', 'happy', 'help', 'get', 'steam'],
#  ['main', 'reason', 'drink', 'total', 'selflessness'],
#  ['nothing', 'date', 'make'],
#  ['hope', 'everything', 'go', 'right', 'unhappy'],
#  ['day', 'new', 'follower', 'happy', 'via'],
#  ['please', 'buy', 'blinking', 'headband'],
#  ['funny', 'happy'],
#  ['new', 'mother', 'change', 'date'],
#  ['art', 'living', 'back', 'damage'],
#  ['veteran', 'leader', 'party', 'camp'],
#  ['telegraph', 'today', 'article', 'envoy', 'former', 'colony'],
#  ['thanks'],
#  ['policeman'],
#  ['give',
#   'away',
#   'random',
#   'chance',
#   'win',
#   'usd',
#   'gift',
#   'card',
#   'winner',
#   'selected',
#   'happy'],
#  ['yard'],
#  ['theres', 'one', 'thing', 'want', 'change', 'last', 'name', 'happy'],
#  ['unconscious'],
#  ['want', 'follow', 'back', 'tweet', 'happy'],
#  ['see', 'hope'],
#  ['theory', 'population'],
#  ['look', 'good', 'blue', 'happy'],
#  ['share', 'love', 'high', 'value', 'week', 'happy', 'insight'],
#  ['talk'],
#  ['law', 'check', 'private'],
#  ['took', 'beyond', 'fixed'],
#  ['hey',
#   'everyone',
#   'harry',
#   'maple',
#   'syrup',
#   'breakfast',
#   'great',
#   'way',
#   'start',
#   'day',
#   'happy',
#   'miss'],
#  ['despite'],
#  ['happy'],
#  ['hotel', 'fire'],
#  ['entertaining', 'insightful', 'one', 'really', 'enjoying', 'lot', 'season'],
#  ['be', 'unhappy'],
#  ['reverse', 'special', 'link'],
#  ['rise'],
#  ['nice', 'morning', 'working', 'today', 'lovely', 'atmosphere'],
#  ['oh', 'baby', 'unhappy'],
#  ['beyond'],
#  ['sorry', 'always', 'ask', 'follow', 'happy'],
#  ['last', 'happy'],
#  ['hey', 'thanks', 'follow', 'coastal', 'living', 'mean', 'reply', 'photo'],
#  ['hair', 'color', 'pretty'],
#  ['bronchitis', 'love', 'happy'],
#  ['framed'],
#  ['minister'],
#  ['poor', 'baby', 'unhappy', 'hate', 'people'],
#  ['share', 'love', 'top', 'engaged', 'community', 'week', 'much', 'happy'],
#  ['hard', 'see', 'best', 'friend', 'another', 'girl', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['cute', 'unhappy'],
#  ['agriculture',
#   'sector',
#   'grow',
#   'per',
#   'cent',
#   'current',
#   'year',
#   'per',
#   'cent'],
#  ['tutorial',
#   'distinguishing',
#   'information',
#   'knowledge',
#   'start',
#   'pm',
#   'happy'],
#  ['love', 'happy'],
#  ['oh', 'mince', 'unhappy'],
#  ['day', 'sell', 'truck'],
#  ['super', 'wait', 'happy'],
#  ['plan', 'set'],
#  ['back', 'worry', 'silence'],
#  ['city'],
#  ['getting', 'morning', 'hassle', 'unhappy'],
#  ['would', 'trauma', 'ware', 'unhappy'],
#  ['taking', 'lunch', 'today', 'school', 'report', 'card'],
#  ['still', 'indictment'],
#  ['hello', 'everyone'],
#  ['come', 'volunteer', 'picture', 'house', 'next'],
#  ['sorry',
#   'tired',
#   'stream',
#   'get',
#   'sleep',
#   'try',
#   'fun',
#   'tomorrow',
#   'feeling',
#   'tonight'],
#  ['damn'],
#  ['may', 'go', 'away', 'happy'],
#  ['lawmaker', 'ticked'],
#  ['take', 'season'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['basketball', 'theyre', 'restrict', 'threw'],
#  ['fix', 'soon', 'delay', 'tomorrow', 'unhappy'],
#  ['love', 'cry', 'joy'],
#  [],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['second', 'list'],
#  ['took',
#   'full',
#   'drink',
#   'guess',
#   'could',
#   'say',
#   'instant',
#   'message',
#   'pretty',
#   'wild',
#   'never',
#   'forget',
#   'happy'],
#  ['turned', 'back', 'day', 'get', 'dual', 'stream', 'setup', 'sorted'],
#  ['really', 'serious', 'hope', 'judge', 'unhappy'],
#  ['standoff', 'left', 'entrance', 'thrown', 'side', 'many', 'hurt'],
#  ['quits'],
#  ['satisfied', 'policy'],
#  ['core', 'slow'],
#  ['yes', 'would', 'meddling', 'smile'],
#  [],
#  ['one', 'offering', 'poor', 'old', 'lady', 'seat', 'unhappy'],
#  [],
#  ['relief', 'small'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['go', 'know'],
#  ['good', 'luck', 'vote', 'smile'],
#  ['stunning', 'victory'],
#  ['demand', 'justice', 'right', 'cattle', 'trade'],
#  ['am', 'forget', 'eat', 'breakfast', 'happy'],
#  ['thanks',
#   'recent',
#   'follow',
#   'happy',
#   'connect',
#   'happy',
#   'great',
#   'get',
#   'free'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  ['even', 'care', 'unhappy'],
#  ['yore'],
#  ['would', 'love', 'win', 'gorgeous', 'nail', 'cute'],
#  ['march', 'siege', 'parliament'],
#  ['sorry', 'piss', 'unhappy'],
#  ['people', 'turned'],
#  [],
#  ['excited', 'event', 'next', 'week', 'come', 'happy'],
#  ['considered', 'came'],
#  ['government', 'cannot', 'make', 'mandatory', 'extending', 'welfare'],
#  ['likely', 'take', 'final', 'call'],
#  ['used', 'care', 'motivation', 'happy'],
#  ['say'],
#  ['upset'],
#  ['real', 'happy'],
#  ['smile'],
#  ['short', 'two', 'majority'],
#  ['man', 'phone', 'made', 'like', 'always', 'wink'],
#  ['unhappy'],
#  ['thanks', 'recent', 'follow'],
#  ['focus'],
#  ['looking', 'getting', 'list'],
#  ['available', 'unhappy'],
#  ['medical', 'body', 'handling', 'successful'],
#  ['finance', 'minister'],
#  ['got',
#   'favorite',
#   'boot',
#   'cut',
#   'jean',
#   'girl',
#   'safe',
#   'today',
#   'blessed',
#   'smile'],
#  ['slashed', 'research'],
#  ['way'],
#  ['rural', 'counter', 'call'],
#  ['lose'],
#  ['stress'],
#  ['follow', 'unhappy'],
#  ['much', 'cant', 'seem', 'unhappy'],
#  ['get', 'well', 'really', 'soon', 'jack', 'unhappy'],
#  ['visiting', 'prime', 'minister'],
#  ['unnamed'],
#  [],
#  ['plea', 'withdrawn'],
#  ['one', 'one', 'ease', 'problem', 'lot', 'thanks', 'cry', 'joy'],
#  ['random', 'twitch', 'happy'],
#  ['world', 'big', 'big', 'take', 'world', 'much', 'smile', 'happy'],
#  ['preacher', 'unhappy'],
#  ['also'],
#  ['relatable', 'unhappy'],
#  ['noon'],
#  ['yes', 'kind', 'funny', 'creepy', 'time', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['even', 'pro', 'poor', 'leader'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  [],
#  ['nice',
#   'really',
#   'nice',
#   'stuff',
#   'mostly',
#   'black',
#   'get',
#   'away',
#   'june',
#   'wedding',
#   'though',
#   'unhappy'],
#  ['little', 'happy'],
#  ['want', 'tell', 'fellow', 'want', 'think', 'kind', 'suck', 'unhappy'],
#  ['want', 'cry', 'unhappy'],
#  ['mack'],
#  ['operator', 'acquire', 'business', 'seven', 'spectrum'],
#  ['great'],
#  ['dying', 'thirst', 'unhappy'],
#  ['base', 'pitch'],
#  ['connection', 'men', 'polling', 'day', 'police'],
#  ['state', 'fourth', 'estate'],
#  ['old', 'unhappy'],
#  ['soldier', 'snow', 'take', 'mother', 'body', 'home'],
#  ['pill'],
#  ['agreed', 'feel', 'like', 'many', 'design', 'spending', 'next', 'couple'],
#  ['punishment', 'time', 'team', 'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['also'],
#  ['million', 'offering', 'smile'],
#  [],
#  ['half', 'time', 'load'],
#  ['two', 'encounter', 'nearly'],
#  ['relief', 'front', 'small', 'hit'],
#  ['thanks', 'follow'],
#  ['founder', 'happy'],
#  ['opt', 'fund', 'outfit'],
#  ['want',
#   'quit',
#   'fighting',
#   'type',
#   'election',
#   'losing',
#   'maiden',
#   'election',
#   'ani'],
#  ['customer', 'journey', 'keynote', 'partner', 'event', 'incredible', 'event'],
#  ['zac', 'back', 'way', 'sad', 'unhappy'],
#  ['share', 'love', 'thanks', 'top', 'new', 'week', 'happy'],
#  ['beating', 'two', 'anyway', 'stop', 'match'],
#  ['face', 'cat', 'dog', 'really', 'upsetting', 'unhappy'],
#  ['link', 'seventeen', 'concert'],
#  ['perspective', 'strife'],
#  ['bicycle', 'officer', 'learnt', 'ground', 'reality', 'dip', 'river'],
#  ['service', 'inquiry'],
#  ['upstairs', 'right', 'happy'],
#  ['hello', 'thank', 'much', 'following', 'love', 'read', 'happy', 'want'],
#  ['precious', 'really', 'miss', 'unhappy'],
#  ['happy', 'hope'],
#  ['learning'],
#  ['happy', 'meet', 'tax', 'happy'],
#  ['supreme',
#   'court',
#   'bail',
#   'scam',
#   'accused',
#   'wife',
#   'former',
#   'union',
#   'minister',
#   'sinh'],
#  ['think', 'pretty', 'enough', 'unhappy'],
#  ['record', 'show'],
#  ['meeting', 'governor'],
#  ['chaos', 'call', 'secret', 'vote'],
#  ['sword', 'left', 'gaping'],
#  ['formidable', 'madame', 'business'],
#  ['definitely', 'arm', 'unhappy'],
#  ['please', 'almost', 'unhappy'],
#  ['say'],
#  ['dragon'],
#  ['president', 'supporting', 'legislation', 'related'],
#  ['china', 'visit'],
#  ['way', 'tackle', 'world'],
#  ['thought',
#   'mountain',
#   'dew',
#   'caffeine',
#   'little',
#   'energy',
#   'drink',
#   'never',
#   'sleep',
#   'unhappy'],
#  [],
#  ['plus', 'want', 'win', 'silence', 'happy'],
#  ['also', 'making'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['thanks', 'happy'],
#  ['miss', 'unhappy'],
#  ['case'],
#  [],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['support'],
#  ['unhappy'],
#  ['wish', 'could', 'stay', 'bed', 'day', 'listen', 'rain', 'sad'],
#  ['high', 'court', 'waive', 'drought', 'hit'],
#  ['thumbnail', 'best', 'render', 'ever', 'dand'],
#  ['miss', 'miss', 'unhappy'],
#  ...]

# %%
from gensim.models import Word2Vec

w2v = Word2Vec(size=150, window=10, min_count=1, sg=1, workers=10)
w2v.build_vocab(training_docs)
w2v.train(sentences=training_docs, total_examples=len(training_docs), epochs=w2v.epochs)

w2v

# %%
def doc2vec(docs):
    last_indices = []
    testing_docs = []
    tokenized_docs = []

    for _, row in docs.iterrows():
        tokens = tokenize(preprocess(row['tweets']))
        if len(last_indices) > 0:
            last_indices.append(last_indices[len(last_indices) - 1] + len(tokens))
        else:
            last_indices.append(len(tokens))
        testing_docs.extend(tokens)
        tokenized_docs.append(tokens)

    return tokenized_docs, testing_docs, last_indices

from sklearn.cluster import MiniBatchKMeans

kmeans = MiniBatchKMeans(n_clusters=8, batch_size=750)

def stream_cluster(vectors, vector_size, last_indices):
    document_vectors = []
    first_index = 0
    
    for last_index in last_indices:
        min_vector = []
        max_vector = []
        for i in range(vector_size):
            v_list = [v[i] for v in vectors[first_index:last_index]]
            if len(v_list) > 0:
                min_vector.append(min(v_list))
                max_vector.append(max(v_list))
        if len(min_vector) > 0 and len(max_vector) > 0:
            min_vector.extend(max_vector)
            document_vectors.append(min_vector)
        first_index = last_index
    clustering = kmeans.partial_fit(document_vectors)
    
    return clustering, clustering.labels_, document_vectors

# %%
last_index = int(len(documents.index) / 5)
documents_test = documents[:last_index]

tokenized_docs, testing_docs, last_indices = doc2vec(documents_test)

tokenized_docs
# Out:
# [['follow', 'happy'],
#  [],
#  ['fighting'],
#  ['happy', 'pixel_savage_yo'],
#  ['love', 'mason', 'miss', 'mason', 'unhappy'],
#  ['shield', 'capital'],
#  ['ruby', 'time', 'old', 'forever', 'home', 'always', 'consider', 'rescue'],
#  ['death', 'st', 'solo', 'trip', 'also'],
#  ['meant', 'potato', 'factory', 'thriving', 'reality', 'chain'],
#  ['hope', 'little', 'least', 'rest', 'unhappy'],
#  ['sad', 'life', 'must'],
#  ['would', 'great', 'trick', 'happy'],
#  ['slipped', 'budget'],
#  ['red', 'velvet', 'unhappy'],
#  ['missing', 'cry', 'seaside', 'area'],
#  ['list', 'want', 'happy'],
#  ['worry', 'choice', 'chief', 'minister'],
#  ['end', 'culture'],
#  ['flagging', 'campaign'],
#  ['win', 'influence', 'people'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['happy', 'ming', 'love', 'love', 'happy'],
#  ['assembly', 'secretary', 'confidence', 'motion', 'speaker'],
#  ['thank', 'happy'],
#  ['love', 'unhappy'],
#  ['boo'],
#  ['career', 'unhappy'],
#  ['flashing', 'light', 'paying', 'parking'],
#  [],
#  ['hope'],
#  ['well', 'terrible', 'unhappy'],
#  ['live', 'police', 'given', 'direction', 'evacuate'],
#  ['crore'],
#  ['thanks', 'happy'],
#  ['also'],
#  ['supreme',
#   'court',
#   'bid',
#   'put',
#   'sport',
#   'ministry',
#   'bureaucrat',
#   'panel',
#   'run'],
#  ['twitter'],
#  ['forever', 'trapped', 'void', 'realm', 'unhappy'],
#  [],
#  ['make', 'mark', 'us', 'meet'],
#  ['letter', 'forgery'],
#  ['happening', 'get', 'game', 'different'],
#  ['take'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['also'],
#  ['watch', 'top', 'news', 'day', 'video'],
#  [],
#  ['lucky', 'slave', 'wish', 'unhappy'],
#  ['leader'],
#  ['unhappy'],
#  ['cry'],
#  ['bes', 'rip'],
#  ['good', 'show', 'next', 'jump'],
#  ['official'],
#  ['sarkar'],
#  ['constantly', 'back', 'clearly', 'something', 'wrong', 'pretended'],
#  ['said', 'silence', 'morgan', 'freeman', 'voice', 'happy'],
#  ['hey', 'thanks', 'top', 'new', 'week', 'much', 'happy'],
#  ['hard', 'fall', 'shame', 'looking', 'really', 'good', 'point'],
#  ['love', 'naughty', 'smile'],
#  ['local', 'functionary', 'legislature', 'party', 'leader'],
#  ['thanks', 'recent', 'follow'],
#  ['froze', 'time', 'went'],
#  ['nationalist', 'trend', 'shield', 'local', 'keep'],
#  ['happy', 'bluey'],
#  ['miss', 'already', 'unhappy'],
#  [],
#  ['statement', 'terrorist', 'incident'],
#  ['unfollowing', 'bye', 'happy'],
#  ['cry', 'joy'],
#  ['discretionary',
#   'based',
#   'administration',
#   'policy',
#   'based',
#   'administration'],
#  ['today', 'birthday', 'unhappy'],
#  ['hi', 'looking', 'work', 'upcoming', 'event'],
#  ['mian', 'gone', 'cute', 'happy', 'ugly', 'evil'],
#  ['car', 'recover', 'barring', 'east'],
#  ['village'],
#  ['change', 'word', 'limit', 'application', 'ground'],
#  ['let', 'forget', 'also', 'white', 'birthday', 'today', 'miss', 'unhappy'],
#  ['opposition'],
#  ['law', 'change'],
#  ['happy'],
#  ['brush', 'telling', 'applicable', 'worse', 'unhappy'],
#  ['spending',
#   'time',
#   'dog',
#   'great',
#   'helping',
#   'relax',
#   'de',
#   'stress',
#   'great',
#   'idea',
#   'happy'],
#  ['joy', 'get', 'back'],
#  ['giraffe', 'calf'],
#  ['opposition', 'ruckus', 'trust', 'vote'],
#  ['trouble', 'play'],
#  ['beetle', 'done', 'wall'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['dying', 'thirst', 'unhappy'],
#  ['happy', 'kyle'],
#  [],
#  ['face', 'action', 'drinking', 'alcohol', 'anywhere', 'world'],
#  [],
#  ['nothing', 'faster', 'girl', 'ugly', 'picture'],
#  ['someone', 'gift', 'pi', 'unhappy'],
#  ['thanks',
#   'much',
#   'following',
#   'love',
#   'know',
#   'think',
#   'flooring',
#   'range',
#   'happy'],
#  ['let', 'please', 'unhappy'],
#  ['unhappy', 'beautiful', 'voice', 'never', 'forgotten'],
#  ['worry'],
#  ['access'],
#  ['people', 'want'],
#  ['good', 'watch', 'tv', 'application', 'free', 'happy'],
#  ['become', 'industry'],
#  ['prime', 'minister', 'may', 'hold', 'early', 'election', 'june'],
#  ['poor', 'mouse', 'unhappy'],
#  ['body', 'everything', 'mind', 'kind'],
#  ['present'],
#  ['risk', 'smile', 'today'],
#  ['days', 'taste'],
#  ['unhappy', 'sorry', 'hear'],
#  ['wrong', 'matter', 'day', 'happy', 'life', 'happy'],
#  ['leave', 'unhappy'],
#  ['away', 'next', 'unhappy', 'one'],
#  ['life', 'reflection', 'way', 'think', 'change', 'way', 'think'],
#  ['ah', 'awesome', 'art', 'stuff', 'chance', 'happy'],
#  [],
#  ['definitely', 'arm', 'unhappy'],
#  ['share', 'love', 'high', 'value', 'week', 'happy'],
#  ['begum'],
#  ['miss', 'unhappy'],
#  ['oh', 'unhappy'],
#  ['short', 'thanks', 'friend'],
#  ['set', 'panel', 'study', 'service', 'paramilitary'],
#  ['dog', 'live', 'forever', 'unhappy'],
#  ['elsewhere', 'imposition', 'plan'],
#  ['miss', 'sad'],
#  ['understand', 'silly', 'like', 'make', 'smile', 'happy'],
#  ['finished', 'gym'],
#  ['man', 'truck', 'suspected', 'carried', 'attack'],
#  ['first', 'time'],
#  ['cram', 'reading', 'unhappy'],
#  ['took', 'social', 'medium', 'bad', 'food'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['day',
#   'night',
#   'since',
#   'went',
#   'back',
#   'province',
#   'already',
#   'miss',
#   'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['say', 'sorry', 'man'],
#  ['oh', 'yes', 'happy'],
#  ['want', 'learn', 'ugly', 'body', 'cry', 'joy'],
#  ['sincerely', 'hope', 'many', 'priceless', 'reg'],
#  ['think', 'finally', 'figured', 'tattoo', 'getting', 'august'],
#  ['unhappy', 'feeling'],
#  ['versus', 'cry', 'joy'],
#  ['go', 'back', 'school', 'music', 'think', 'time', 'happy'],
#  ['finance', 'minister', 'given', 'additional', 'charge', 'ministry'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  [],
#  ['trump', 'order', 'parallel', 'citizenship', 'bill'],
#  ['assault', 'air', 'manager'],
#  ['goal', 'today', 'happy', 'going', 'accomplish'],
#  ['wage', 'hike'],
#  [],
#  ['question', 'banking', 'switching', 'old'],
#  ['civic', 'state', 'go'],
#  ['friend', 'smile'],
#  ['worried', 'silence'],
#  ['actually',
#   'looking',
#   'forward',
#   'seeing',
#   'theory',
#   'around',
#   'personal',
#   'vote',
#   'correct',
#   'unhappy'],
#  ['game', 'much', 'personality'],
#  [],
#  ['like', 'happy'],
#  ['miss', 'unhappy'],
#  ['goat', 'parallel', 'case'],
#  ['development', 'filling', 'also', 'death'],
#  ['store', 'still', 'use'],
#  ['happy', 'birthday', 'happy', 'hope', 'good', 'one'],
#  ['trauma', 'driving', 'without', 'red'],
#  ['wont', 'able', 'stream', 'tonight', 'sorry', 'unhappy'],
#  ['miss', 'unhappy'],
#  ['parent', 'friendly', 'like', 'please'],
#  ['dying', 'thirst', 'unhappy'],
#  ['logical', 'milestone', 'death'],
#  ['use', 'track', 'track'],
#  ['life', 'unfair', 'unhappy'],
#  ['unhappy', 'nice', 'instant', 'message', 'really'],
#  ['order', 'ever', 'want', 'eat', 'may', 'great', 'day', 'happy'],
#  ['nick', 'might', 'deliver', 'time', 'story', 'life'],
#  ['without', 'looking'],
#  ['tour'],
#  ['happy'],
#  [],
#  ['cry', 'joy'],
#  ['parent', 'cannot', 'control', 'give', 'worst', 'output', 'word'],
#  ['even', 'though', 'machinery', 'state'],
#  ['petitioner'],
#  ['court', 'probe', 'corruption', 'charge'],
#  [],
#  ['pick', 'one', 'unhappy'],
#  ['po', 'may', 'heart', 'heart', 'everywhere', 'happy', 'love'],
#  ['self', 'belief', 'kept', 'top', 'game'],
#  ['cricket', 'body'],
#  ['dying', 'language'],
#  ['menu', 'dinner', 'praise', 'praise'],
#  ['hope', 'great'],
#  [],
#  ['unhappy', 'look', 'dead'],
#  ['unhappy'],
#  ['client', 'work', 'favorite', 'happy'],
#  ['best'],
#  ['notice', 'unhappy'],
#  ['station', 'check', 'happy', 'surely', 'combination', 'xx', 'xx'],
#  ['newly', 'meet', 'mar'],
#  ['old', 'twitter', 'unhappy'],
#  ['high', 'court', 'probe', 'sting', 'operation'],
#  ['blast', 'love'],
#  ['impressive', 'happy'],
#  ['exam', 'body', 'bos'],
#  ['road', 'safety', 'crusader', 'fight', 'bid', 'bypass', 'order', 'highway'],
#  ['strategy'],
#  ['traffic', 'pen', 'paper'],
#  ['project', 'test'],
#  ['comforting', 'fog'],
#  ['protect', 'layer', 'fat'],
#  ['passion',
#   'perseverance',
#   'two',
#   'secret',
#   'secret',
#   'sauce',
#   'success',
#   'happy'],
#  ['happy'],
#  ['unhappy', 'oh', 'man'],
#  ['reply', 'get', 'lost'],
#  ['south', 'constitutional', 'court', 'president', 'park', 'impeachment'],
#  ['real', 'time', 'happy'],
#  ['happy', 'birthday'],
#  [],
#  ['art', 'form'],
#  ['idea', 'saying'],
#  [],
#  ['oath', 'taking', 'new', 'take', 'place'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'want'],
#  ['undercurrent', 'led', 'surge', 'story'],
#  ['stop', 'loot', 'express', 'coin'],
#  ['park', 'marked', 'green'],
#  ['hear', 'various', 'constitutional', 'legitimacy', 'today'],
#  ['unofficial', 'ban'],
#  ['write', 'fiction', 'knob', 'sentence', 'next', 'house', 'piss'],
#  ['cry'],
#  ['happy'],
#  ['vote', 'share', 'go'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['dong', 'many', 'complaint', 'since', 'day', 'ticketing', 'unhappy'],
#  ['st', 'woman', 'foreign', 'secretary'],
#  ['asset', 'worth', 'new'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['little', 'video', 'made', 'love', 'life'],
#  ['branded', 'hacked', 'death'],
#  ['expensive', 'unhappy'],
#  ['talk', 'like', 'used', 'unhappy'],
#  ['law', 'job'],
#  ['good', 'morning', 'hope', 'slept', 'well', 'happy'],
#  ['dog', 'family', 'put', 'tomorrow', 'unhappy'],
#  ['singe'],
#  ['hair', 'color', 'pretty'],
#  [],
#  ['yogi', 'work'],
#  ['full', 'year'],
#  ['pretty', 'happy'],
#  ['miss', 'much', 'unhappy'],
#  ['get', 'haircut', 'know', 'good', 'place', 'unhappy'],
#  ['princess'],
#  ['could', 'write', 'theoretically', 'impossible', 'real', 'life', 'unhappy'],
#  ['mad', 'avoid', 'today'],
#  ['please',
#   'take',
#   'rest',
#   'love',
#   'much',
#   'hope',
#   'feel',
#   'better',
#   'soon',
#   'sunshine'],
#  ['anti', 'squad', 'video'],
#  ['brace', 'hurt', 'unhappy'],
#  [],
#  ['feeling', 'bad', 'unhappy'],
#  ['limit'],
#  ['better', 'unhappy'],
#  ['got', 'message', 'happy'],
#  ['ray', 'journey', 'light'],
#  ['bow', 'story'],
#  ['system',
#   'recognize',
#   'last',
#   'nd',
#   'time',
#   'unable',
#   'check',
#   'forced',
#   'wait',
#   'unnecessary',
#   'unhappy'],
#  ['agreed', 'teach', 'rope'],
#  ['sworn', 'chief', 'minister'],
#  ['definitely', 'arm', 'unhappy'],
#  ['think', 'probably', 'beyond', 'repair', 'tea', 'etiquette', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['demit', 'game', 'real', 'cry', 'joy'],
#  ['hold', 'st', 'cabinet', 'meeting', 'today'],
#  ['unhappy'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['still', 'possible', 'unhappy'],
#  ['dargah', 'trust', 'clear', 'sq'],
#  ['happy', 'ross', 'masoncooper'],
#  ['us', 'scare'],
#  ['happy'],
#  ['found', 'use', 'sewable', 'led', 'holder', 'happy'],
#  ['case',
#   'meat',
#   'exporter',
#   'graft',
#   'case',
#   'former',
#   'chief',
#   'singh',
#   'also'],
#  ['tweet', 'want', 'included', 'scrapbook', 'making', 'something'],
#  ['dig'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['would', 'well', 'abolish'],
#  ['within', 'budget'],
#  ['constable',
#   'service',
#   'court',
#   'inquiry',
#   'bad',
#   'quality',
#   'food',
#   'base'],
#  ['also'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['oh', 'unhappy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['glad',
#   'care',
#   'people',
#   'think',
#   'wish',
#   'still',
#   'best',
#   'everyday',
#   'like',
#   'used',
#   'sad',
#   'pick'],
#  ['violence'],
#  ['high', 'court', 'judge', 'card'],
#  ['poor', 'baby', 'unhappy', 'hate', 'people'],
#  ['oh', 'boo'],
#  ['see'],
#  ['record', 'haul', 'booze'],
#  ['stay', 'chairman', 'till', 'june', 'meet'],
#  ['gave', 'bus', 'board', 'flight', 'goodwill'],
#  ['merit', 'wild', 'baseless'],
#  ['hacked', 'unhappy'],
#  ['day', 'left', 'arm'],
#  ['question', 'mark', 'video'],
#  ['roc', 'sad'],
#  ['get'],
#  ['non', 'teaching', 'staff', 'call', 'end', 'stir'],
#  ['man', 'seen', 'tied', 'army', 'jeep', 'video'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['unhappy', 'saw', 'somebody', 'said', 'hair', 'fell', 'trying', 'figure'],
#  ['lonely', 'unhappy'],
#  ['true'],
#  ['unnamed'],
#  ['please', 'help', 'tried', 'smoke', 'lettuce', 'salad', 'ruined', 'unhappy'],
#  ['dying', 'thirst', 'unhappy'],
#  ['lucky', 'unhappy'],
#  ['miss', 'boy', 'sick', 'unhappy'],
#  ['perfectly', 'happy', 'single', 'see', 'happy', 'couple'],
#  ['get', 'latest', 'throughout', 'day'],
#  ['go', 'past'],
#  ['draw', 'naked', 'cry'],
#  ['dev', 'plea', 'keep'],
#  ['prove', 'majority', 'assembly', 'today'],
#  ['triumphant', 'opening', 'night', 'nd', 'street', 'west', 'end', 'happy'],
#  ['returned', 'warm', 'welcome'],
#  ['nd', 'cousin', 'maybe', 'thats', 'message', 'hockey'],
#  ['father'],
#  ['dysfunction', 'among'],
#  ['call', 'vote'],
#  [],
#  ['miss', 'temperance', 'booth', 'much', 'unhappy'],
#  ['million'],
#  ['am'],
#  ['terrorist', 'make', 'statement'],
#  ['go', 'utmost', 'harshness'],
#  ['telegraph', 'advantage'],
#  ['jack', 'cry', 'joy'],
#  ['thanks', 'much', 'happy', 'magic'],
#  ['cloud', 'also'],
#  ['agitation', 'day', 'trouble', 'soon', 'come'],
#  ['credit', 'also', 'go', 'happy'],
#  ['death', 'currency'],
#  ['hey', 'could', 'help', 'legitimate', 'really', 'need', 'account', 'rig'],
#  ['area', 'list', 'unhappy', 'think', 'go', 'anyway'],
#  ['think',
#   'understand',
#   'much',
#   'stream',
#   'would',
#   'mean',
#   'happy',
#   'even',
#   'make'],
#  ['today', 'unhappy'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['pollution'],
#  ['till', 'later', 'unhappy'],
#  ['hair', 'versus', 'light', 'go', 'sad', 'please', 'help', 'po'],
#  ['pitch'],
#  ['supporting', 'activity', 'violent', 'law', 'ram'],
#  ['big', 'love', 'cox', 'happy'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['try', 'hacking', 'election', 'commission'],
#  ['great', 'work', 'lovely', 'place', 'thank'],
#  [],
#  ['meet'],
#  ['bae', 'unhappy'],
#  ['friend', 'promise', 'meant', 'broken'],
#  ['floor', 'test'],
#  ['good', 'luck', 'swampy', 'happy'],
#  ['visit', 'trip'],
#  [],
#  ['happy'],
#  ['jealous', 'unhappy', 'please', 'go', 'see', 'green', 'room', 'sat'],
#  ['make', 'come', 'well', 'happy'],
#  ['versus', 'undercurrent'],
#  ['china', 'protest', 'ambassador', 'visit', 'foreign', 'ministry'],
#  ['official',
#   'connected',
#   'twitter',
#   'thank',
#   'follow',
#   'please',
#   'ever',
#   'let',
#   'go',
#   'happy'],
#  ['happy', 'birthday', 'know', 'good', 'day'],
#  ['quickly'],
#  ['riddle', 'formerly', 'tag', 'collection'],
#  ['good', 'luck', 'happy'],
#  [],
#  ['best', 'advice', 'happy'],
#  ['every', 'time', 'shepherd', 'hold', 'back', 'unhappy'],
#  ['thanks', 'top', 'engaged', 'community', 'week', 'happy', 'try'],
#  ['top', 'engaged', 'week', 'happy'],
#  ['help'],
#  ['wish', 'could', 'sleep', 'early', 'unhappy'],
#  ['slight', 'unhappy'],
#  ['recent', 'follow', 'much', 'happy', 'want'],
#  ['see', 'drink', 'alcohol', 'glad', 'fun', 'wish'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['definitely', 'arm', 'unhappy'],
#  ['front'],
#  ['tell', 'idea'],
#  [],
#  ['need', 'learn', 'start', 'people', 'keep', 'chatting', 'unhappy'],
#  ['college', 'event', 'invite'],
#  ['let', 'eat', 'cake'],
#  ['fixing', 'storage'],
#  ['getting', 'one', 'smile', 'smile', 'smile', 'smile'],
#  ['polling', 'underway', 'assembly', 'spread', 'across', 'phase'],
#  ['unhappy'],
#  ['today'],
#  ['happy'],
#  ['man', 'happy'],
#  ['happy', 'drug', 'free', 'never', 'smoked', 'weed'],
#  ['boss'],
#  ['hi', 'han'],
#  ['happy', 'birthday', 'miss', 'though', 'unhappy', 'miss', 'group', 'anyway'],
#  ['house', 'till', 'pm'],
#  ['cash', 'likely', 'following', 'correct', 'protocol'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['principal', 'secretary', 'information'],
#  ['spell'],
#  ['mass'],
#  ['forced', 'noon', 'session', 'misuse', 'opposition', 'chief'],
#  ['guy', 'pop', 'translator', 'go', 'around', 'unhappy'],
#  ['flash', 'khan'],
#  ['pushing'],
#  ['ban'],
#  ['monumental'],
#  ['double', 'digit', 'sluggish', 'growth', 'high', 'growth', 'war'],
#  ['custom', 'fill', 'unhappy'],
#  ['new', 'exciting', 'time', 'ahead', 'second'],
#  ['sport', 'except', 'total', 'handball'],
#  ['live', 'money'],
#  ['stay', 'go', 'nobody', 'happy'],
#  ['led', 'seem', 'look', 'beyond', 'family', 'top'],
#  [],
#  ['road', 'traffic', 'section', 'theory', 'revision', 'myth', 'unhappy'],
#  ['left', 'unspoken'],
#  [],
#  ['rusty',
#   'game',
#   'since',
#   'like',
#   'kept',
#   'dying',
#   'crocodile',
#   'part',
#   'cry'],
#  ['anniversary', 'josh', 'death', 'unhappy'],
#  ['miss', 'unhappy'],
#  ['hi', 'instant', 'message', 'friend', 'friend'],
#  ['bid', 'enter'],
#  [],
#  ['go'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['shameful',
#   'business',
#   'stop',
#   'paying',
#   'giant',
#   'need',
#   'wake',
#   'people',
#   'plea'],
#  ['test', 'politics'],
#  ['happy', 'like', 'never', 'studied', 'luckily', 'got', 'still', 'ha'],
#  ['scout', 'photo', 'sad'],
#  ['wake', 'call', 'trump'],
#  ['crore'],
#  ['might', 'set', 'whole', 'place', 'fire'],
#  ['gen', 'governor'],
#  ['got', 'disappear', 'half', 'way', 'unhappy', 'everybody', 'want', 'lazy'],
#  ['tweet'],
#  ['sup'],
#  ['chapter', 'filing', 'nuclear', 'unit'],
#  ['happy', 'old'],
#  ['say', 'hi', 'sunshine', 'unhappy'],
#  ['team', 'come', 'minimal', 'side', 'effect'],
#  ['notice', 'unhappy'],
#  [],
#  [],
#  ['bedroom', 'journalism', 'trial'],
#  ['blaze', 'spotlight', 'grand', 'history', 'lurk'],
#  ['never', 'happy'],
#  ['airport', 'needle'],
#  [],
#  ['chief', 'growth', 'rate'],
#  ['choice', 'giving', 'jitter'],
#  ['never', 'want', 'finish', 'desperate', 'life', 'unhappy'],
#  ['really',
#   'labour',
#   'supporter',
#   'actually',
#   'quite',
#   'glad',
#   'happy',
#   'mean',
#   'much',
#   'claim'],
#  ['hot'],
#  ['supreme',
#   'court',
#   'unfortunate',
#   'ground',
#   'plea',
#   'order',
#   'take',
#   'case'],
#  ['process', 'social', 'change', 'seldom', 'linear', 'pretty'],
#  ['update', 'attorney', 'resign', 'along', 'era'],
#  ['marginal', 'standing', 'facility', 'bank', 'rate'],
#  ['giving', 'power', 'award'],
#  ['unhappy', 'let', 'fight'],
#  ['didnt', 'see', 'win', 'today', 'sad', 'winner'],
#  ['legal', 'back', 'call', 'suicide', 'note'],
#  ['going', 'see', 'speak', 'people', 'live', 'near', 'see', 'use', 'happy'],
#  ['motivation', 'study', 'unhappy'],
#  ['new'],
#  ['picture', 'sad', 'unhappy'],
#  ['bed', 'comfortable', 'want', 'get', 'unhappy'],
#  ['court',
#   'summons',
#   'suspended',
#   'accused',
#   'criminal',
#   'defamation',
#   'plea'],
#  ['little', 'bit', 'overdramatic', 'death', 'happy'],
#  ['could', 'gain', 'partnership'],
#  ['conference', 'go', 'dinner', 'smile'],
#  ['police', 'attack', 'near', 'parliament', 'cannot', 'confirm', 'number'],
#  ['appreciate', 'recent', 'great', 'happy'],
#  ['midst', 'incendiary', 'wish'],
#  ['respect', 'accept', 'verdict', 'chief'],
#  [],
#  ['another', 'way', 'wish', 'sir', 'good', 'unhappy'],
#  ['find', 'difficult', 'unhappy'],
#  ['note', 'crunch', 'glass'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['big', 'fail'],
#  ['given',
#   'custom',
#   'console',
#   'bundle',
#   'giveaway',
#   'happy',
#   'tweet',
#   'following',
#   'enter'],
#  ['yeah'],
#  ['bit', 'quiet', 'tonight', 'tough', 'luck', 'unhappy'],
#  ['mine', 'back', 'say', 'happy'],
#  ['telling',
#   'read',
#   'book',
#   'today',
#   'knowledge',
#   'power',
#   'knowledge',
#   'growth'],
#  ['reliance', 'free', 'voice', 'roaming', 'year', 'cheap'],
#  ['sent', 'want', 'see', 'holding', 'trophy', 'unhappy', 'anyways'],
#  ['let', 'take', 'hit'],
#  ['chair', 'sitting', 'find', 'everyone', 'shamed', 'pu'],
#  ['court', 'limit', 'leaf', 'watering', 'dry'],
#  ['thanks', 'iris', 'photo', 'really', 'appreciate', 'smile'],
#  ['likely', 'hear', 'today'],
#  ['divide', 'woo', 'home', 'turf'],
#  ['new', 'video', 'happy', 'hope', 'like'],
#  ['thanks', 'happy'],
#  ['governor', 'take', 'decision', 'basis', 'well', 'credibility'],
#  ['trying', 'push', 'making', 'meat', 'communal', 'issue'],
#  ['people', 'even', 'please', 'someone', 'unhappy'],
#  ['home'],
#  ['know', 'really', 'love', 'lot', 'support'],
#  ['throwback', 'happy'],
#  ['stamping', 'hand', 'baggage', 'major'],
#  ['talking',
#   'driver',
#   'said',
#   'love',
#   'go',
#   'new',
#   'york',
#   'since',
#   'trump',
#   'probably'],
#  ['getting', 'harder', 'harder', 'stay', 'unhappy'],
#  ['days', 'ram'],
#  ['paddy', 'could', 'blame'],
#  ['want', 'cry'],
#  ['tonight', 'pm'],
#  ['far',
#   'collection',
#   'happy',
#   'new',
#   'gin',
#   'menu',
#   'coming',
#   'soon',
#   'well'],
#  ['sanctuary'],
#  ['relief', 'yet'],
#  ['driver', 'happy', 'waiting', 'sun', 'ten'],
#  ['fir', 'registered', 'minister', 'gang', 'rape', 'sexual', 'harassment'],
#  ['insist'],
#  ['left', 'home', 'unhappy'],
#  ['big', 'boss', 'science', 'giving'],
#  ['thanks', 'week', 'much', 'happy', 'want'],
#  ['today'],
#  ['people', 'going', 'back', 'economy'],
#  ['went', 'meet'],
#  ['come', 'prey'],
#  ['kind', 'empty', 'venue', 'unhappy'],
#  ['voting', 'pattern', 'cofounder'],
#  ['going', 'add'],
#  ['build', 'case'],
#  ['terrible', 'live', 'world', 'address', 'criticism', 'first', 'happy'],
#  ['entry'],
#  ['bill', 'pervert'],
#  ['happy'],
#  ['woke'],
#  ['super', 'got', 'musical', 'mojo', 'back', 'thank', 'much', 'happy'],
#  ['lost', 'deposit', 'garden', 'stronghold'],
#  ['common', 'bugbear', 'also'],
#  ['aerobatic', 'display', 'inaugural'],
#  ['army', 'chief', 'ring', 'pellet', 'hit', 'boy'],
#  ['know', 'possibly', 'next', 'video'],
#  ['work', 'unhappy', 'see', 'tomorrow'],
#  [],
#  ['day', 'new', 'happy', 'via'],
#  ['bit', 'tired'],
#  ['excuse', 'see', 'unhappy'],
#  ['damn', 'unfortunate', 'unhappy'],
#  ['work', 'much', 'better', 'unhappy'],
#  ['road', 'economy'],
#  ['license', 'raid', 'without', 'ground'],
#  ['thanks', 'recent', 'follow'],
#  ['thanks',
#   'follow',
#   'happy',
#   'help',
#   'business',
#   'anyway',
#   'please',
#   'get',
#   'touch'],
#  ['mean', 'voice', 'unhappy'],
#  [],
#  ['indignation', 'remains', 'well', 'fed'],
#  ['know', 'ready', 'say', 'unhappy'],
#  ['cant', 'stream', 'genie', 'stream', 'genie', 'still', 'genie', 'want'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['magic', 'combined', 'strength', 'brought', 'back', 'party', 'system'],
#  ['terrorist', 'false'],
#  ['mess', 'went', 'bed', 'feeling', 'numb', 'awful', 'unhappy'],
#  ['love', 'ben', 'get', 'watch', 'want', 'without', 'interruption', 'happy'],
#  ['ram', 'wide', 'ranging', 'interview'],
#  ['miss', 'unhappy'],
#  ['thinking', 'know', 'cute', 'happy'],
#  ['leading'],
#  ['civic', 'poll', 'counting', 'begin', 'today', 'result'],
#  ['tracing', 'building', 'space'],
#  ['ready', 'happy'],
#  ['match', 'referee', 'went', 'book'],
#  ['picture', 'unhappy'],
#  ['love',
#   'love',
#   'much',
#   'happy',
#   'thank',
#   'amazing',
#   'review',
#   'perfect',
#   'glasses'],
#  ['get', 'rover', 'double', 'sided', 'check', 'shipping'],
#  ['ready', 'long'],
#  ['pressure', 'ban'],
#  ['trust', 'vote'],
#  ['also'],
#  ['real', 'link', 'video', 'happy'],
#  ['unhappy'],
#  ['rape', 'accused', 'leader', 'gayatri', 'roaming'],
#  ['live', 'promise'],
#  ['absorbed', 'going', 'get', 'laugh', 'unhappy'],
#  ['one', 'left', 'see', 'unhappy'],
#  ['resistance', 'nothing', 'citizenry', 'yet', 'match'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great'],
#  ['lot', 'month'],
#  ['becoming', 'hostile'],
#  ['sadly', 'unhappy'],
#  ['crush', 'come', 'meet', 'without', 'filter', 'unhappy'],
#  ['kind',
#   'like',
#   'right',
#   'sad',
#   'someone',
#   'please',
#   'make',
#   'nobby',
#   'glass',
#   'slip'],
#  ['healthy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'get'],
#  ['see', 'next', 'tweet', 'different', 'keeping', 'calm'],
#  ['unhappy', 'mean', 'heck', 'decide', 'laundry', 'wrong', 'mention', 'dark'],
#  ['rani', 'express', 'derail', 'near'],
#  ['protein', 'venom', 'may', 'help', 'recover', 'faster'],
#  ['bantay', 'unhappy'],
#  ['turnout', 'fifth', 'phase', 'voting', 'large', 'peacefully', 'assembly'],
#  [],
#  ['dying', 'thirst', 'unhappy'],
#  ['ban'],
#  ['long', 'time', 'really', 'unhappy'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  ['keyrazygirl'],
#  ['accept', 'yr'],
#  ['never', 'happy'],
#  ['today', 'happy'],
#  ['never', 'draw', 'unhappy'],
#  ['oh', 'god', 'live', 'cry', 'joy', 'stop', 'cuddle'],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  [],
#  [],
#  ['firing', 'underway'],
#  ['upper', 'caste'],
#  ['russel', 'noodle', 'unhappy'],
#  ['president',
#   'trump',
#   'top',
#   'government',
#   'lawyer',
#   'sally',
#   'defiance',
#   'immigration',
#   'order'],
#  ['happy', 'happy'],
#  ['gazette', 'wont', 'applied', 'retrospectively', 'admitted'],
#  ['looking', 'forward', 'visiting', 'picked', 'great', 'day'],
#  [],
#  ['check'],
#  ['unhappy', 'damn', 'sad'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['understand', 'state', 'mind', 'right', 'hence'],
#  ['canada', 'still', 'never', 'support'],
#  [],
#  ['damn',
#   'there',
#   'people',
#   'sincerely',
#   'want',
#   'attend',
#   'birthday',
#   'party',
#   'people',
#   'try',
#   'fun',
#   'make',
#   'ca'],
#  [],
#  ['coming', 'notification', 'soon', 'tomorrow'],
#  ['always', 'running', 'space', 'phone'],
#  ['blessing', 'tomorrow', 'happy', 'keep', 'faith', 'day'],
#  ['believe', 'customer', 'service', 'go'],
#  ['thank', 'unhappy', 'need', 'certificate', 'god'],
#  ['perfect', 'dress'],
#  ['congratulation', 'world', 'happy'],
#  ['cant', 'piss', 'unhappy'],
#  ['actually', 'live', 'honesty', 'integrity'],
#  ['supreme', 'court', 'justice', 'explain', 'face'],
#  ['ask', 'get', 'spend'],
#  ['fake',
#   'exit',
#   'poll',
#   'news',
#   'brand',
#   'name',
#   'want',
#   'clarify',
#   'exit',
#   'piss'],
#  ['live', 'address', 'parliament', 'am'],
#  ['unhappy'],
#  ['digital', 'want', 'work', 'make', 'happen', 'unhappy'],
#  ['us', 'clash', 'immigration', 'hold'],
#  ['want', 'harry', 'sad'],
#  [],
#  ['save'],
#  [],
#  ['nd'],
#  ['tired', 'falling', 'unhappy'],
#  ['honestly',
#   'college',
#   'want',
#   'curl',
#   'ball',
#   'cry',
#   'day',
#   'straight',
#   'unhappy'],
#  ['good', 'news', 'thriving', 'reserve'],
#  ['erupt'],
#  [],
#  ['definitely', 'arm', 'unhappy'],
#  [],
#  ['advertisement'],
#  ['leader', 'shot', 'dead', 'late', 'last', 'night'],
#  ['awesome'],
#  ['imagine', 'paying', 'rs'],
#  ['half', 'naked', 'happy'],
#  ['rupee', 'increase', 'dignified', 'living', 'plea'],
#  ['speech', 'text', 'doesnt', 'understand', 'accent', 'unhappy'],
#  ['famous', 'sa'],
#  ['economic', 'blockade', 'impact', 'process'],
#  ['good', 'morning'],
#  ['transparency', 'looking', 'start', 'bottom'],
#  ['miss', 'buffet', 'unhappy', 'take', 'care'],
#  ['please'],
#  ['give', 'month', 'trial', 'run', 'also', 'vote'],
#  ['thought', 'made', 'transparent'],
#  ['untold', 'love', 'story'],
#  ['ill', 'fitting'],
#  ['prosecute', 'former', 'principal', 'secretary', 'chief', 'minister'],
#  ['murder', 'activist', 'clause', 'law'],
#  ['instant',
#   'message',
#   'jealous',
#   'unhappy',
#   'never',
#   'mind',
#   'wait',
#   'first'],
#  ['reliance', 'prime', 'minister', 'picture', 'without', 'permission'],
#  ['trying',
#   'bank',
#   'sleep',
#   'week',
#   'happy',
#   'doubt',
#   'able',
#   'sleep',
#   'night'],
#  [],
#  ['dysfunction'],
#  ['even'],
#  ['get', 'dog'],
#  ['need', 'direct', 'coffee', 'feed', 'happy'],
#  ['editorial', 'mayor', 'cannot'],
#  ['might', 'cost', 'month', 'happy'],
#  ['hey'],
#  [],
#  [],
#  ['right', 'well', 'unfortunately'],
#  ['also'],
#  ['friend', 'would', 'like', 'brand', 'new'],
#  ['upright', 'cop', 'son'],
#  ['good', 'morning', 'every', 'one'],
#  ['thanks',
#   'much',
#   'kind',
#   'look',
#   'forward',
#   'seeing',
#   'soon',
#   'buddy',
#   'smile'],
#  ['auditor', 'check', 'misuse'],
#  ['random', 'winner', 'like', 'able', 'win', 'happy'],
#  ['thanks', 'recent', 'follow', 'happy', 'connect', 'happy', 'great', 'want'],
#  ['tara'],
#  ['nothing', 'could', 'better', 'happy'],
#  ['instant', 'message', 'getting', 'sad', 'unhappy'],
#  ['also'],
#  ['end', 'another', 'batch', 'edge', 'happy'],
#  ['also'],
#  ['perfectly', 'happy', 'got'],
#  ['get'],
#  ['rare', 'specie', 'hello', 'century'],
#  ['rather'],
#  ['want', 'puppy', 'unhappy'],
#  ['supreme',
#   'court',
#   'criminal',
#   'complaint',
#   'cricketer',
#   'allegedly',
#   'magazine',
#   'cover'],
#  ['unhappy'],
#  ['inspiring', 'cry', 'joy'],
#  ['broadcaster', 'fly', 'away', 'early', 'happy'],
#  ['yeah', 'unhappy', 'thank', 'much', 'angel'],
#  ['cowardice', 'season'],
#  ['defence', 'minister'],
#  [],
#  ['look', 'special', 'link'],
#  ['show'],
#  ['definitely', 'arm', 'unhappy'],
#  ['better', 'unhappy'],
#  ['use', 'happy'],
#  ['poll', 'data', 'show', 'still', 'roost'],
#  ['vanishing'],
#  ['denial', 'normal', 'say'],
#  ['history', 'around'],
#  ['yet', 'maybe', 'year', 'happy'],
#  ['for'],
#  ['adopted', 'son'],
#  ['one', 'year', 'ago', 'today', 'unhappy'],
#  [],
#  ['injured'],
#  ['coming', 'soon'],
#  ['joshi', 'decide', 'future'],
#  ['come', 'back', 'ghost', 'unhappy', 'love'],
#  ['much', 'free', 'legit', 'free', 'follow', 'first', 'get', 'patient'],
#  [],
#  ['key', 'minister', 'freely'],
#  ['give', 'iphone', 'normal'],
#  ['liquor', 'baron', 'declared', 'offender'],
#  [],
#  ['stamp', 'missing', 'choice'],
#  ['police', 'background', 'terrorist'],
#  ['also'],
#  ['good',
#   'evening',
#   'everyone',
#   'happy',
#   'join',
#   'twitter',
#   'party',
#   'tonight',
#   'official',
#   'tanner'],
#  ['week', 'new', 'follower', 'happy', 'via'],
#  ['vile', 'tactic', 'valley'],
#  ['thanks', 'recent', 'follow'],
#  ['hi',
#   'tried',
#   'call',
#   'number',
#   'got',
#   'response',
#   'unhappy',
#   'please',
#   'share',
#   'another',
#   'suitable',
#   'time',
#   'alternate',
#   'number',
#   'cont'],
#  [],
#  [],
#  ['road', 'destination', 'driving', 'hope', 'find', 'place', 'like', 'stay'],
#  ['good',
#   'evening',
#   'everyone',
#   'happy',
#   'join',
#   'twitter',
#   'party',
#   'tonight',
#   'official',
#   'tanner'],
#  ['visit', 'today', 'st', 'time', 'taking', 'oath'],
#  ['rise', 'bn'],
#  [],
#  ['mystery', 'data'],
#  ['normally', 'feel', 'sick', 'drink', 'like', 'coffee'],
#  ['thanks', 'recent', 'follow', 'much', 'happy', 'want'],
#  ['love', 'song'],
#  ['two', 'south'],
#  ['crap', 'school', 'game', 'make', 'time', 'unhappy'],
#  ['take'],
#  ['cute', 'unhappy'],
#  ['unit', 'finally', 'full', 'time', 'chief'],
#  ['going', 'tomorrow', 'silence', 'piss', 'ante', 'happy'],
#  ['join', 'vote', 'singer', 'spread', 'word']]

# %%
vectors = list(map(lambda word: w2v.wv[word], testing_docs))

vectors[:1]
# Out:
# [array([-0.08834181, -0.06055463,  0.06258085, -0.0245199 ,  0.06082386,
#          0.00599433,  0.01328864,  0.03933259, -0.07060732,  0.02296185,
#         -0.03206814,  0.02855729,  0.02900007, -0.00964998,  0.02986188,
#          0.05972818, -0.04019231,  0.0324606 , -0.01360453,  0.0377456 ,
#         -0.00349328, -0.01173059, -0.03538696,  0.02079999, -0.02273198,
#         -0.0240435 , -0.02361206, -0.02080856,  0.00040294, -0.01269963,
#         -0.01324517,  0.02747713,  0.00269448, -0.03933906,  0.01882623,
#          0.06795495, -0.03604603, -0.06369546,  0.01837513, -0.00238435,
#          0.01799057,  0.02159044, -0.03718265, -0.0005188 , -0.02380586,
#          0.0128215 , -0.01987697,  0.00503257,  0.04433121, -0.03344968,
#         -0.03675985, -0.02851134,  0.02705334, -0.0340457 , -0.05263006,
#          0.04495753, -0.04050985, -0.0283006 , -0.00725221,  0.00035667,
#          0.05819903,  0.03475019, -0.01920024,  0.05105542,  0.01063198,
#          0.00908202, -0.07329476, -0.067671  ,  0.01283756, -0.00636188,
#          0.04259498, -0.00233543,  0.01098828,  0.02828797,  0.00265657,
#          0.0113844 ,  0.01862011,  0.05947993, -0.04260298,  0.03480572,
#          0.01235577,  0.03429087,  0.00127975, -0.00284291, -0.0016692 ,
#         -0.03836161,  0.00408891, -0.00420765, -0.00924627,  0.03049842,
#          0.00366628, -0.03073685, -0.00548112,  0.04188369,  0.02618858,
#          0.00592494, -0.04268974,  0.00994458,  0.02479574,  0.03528051,
#         -0.03613421,  0.02390161,  0.01606845,  0.01506531, -0.00440601,
#         -0.02075405, -0.00986255, -0.02556077,  0.01501867,  0.01145209,
#          0.01331923, -0.01210877,  0.01515814, -0.09432445,  0.00814635,
#          0.00352104,  0.03834007, -0.04386448,  0.07775627, -0.0193765 ,
#          0.01576306, -0.03147294, -0.05263422,  0.04702038,  0.00519762,
#          0.00040856,  0.01346573,  0.00167053, -0.01329342,  0.04842012,
#          0.03398444, -0.05891141,  0.02164212,  0.01056523,  0.02080252,
#         -0.01784989, -0.00610506, -0.03197132,  0.02179065,  0.02543537,
#         -0.02311438, -0.03532573, -0.00634694, -0.0264827 ,  0.01532541,
#          0.0018742 ,  0.03949402,  0.01645023, -0.0041011 , -0.01617955],
#        dtype=float32)]

# %%
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

from sklearn import metrics

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinksi-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4774351716041565
# Calinksi-Harabaz Index: 1297.2355956284641
# Davies-Bouldin Index: 0.7500911614999684

# %%
first_index = last_index
last_index = int(len(documents.index)/ 5 * 2)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinksi-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4759519100189209
# Calinksi-Harabaz Index: 1243.076520135763
# Davies-Bouldin Index: 0.7464461641714557

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 3)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinksi-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4573555588722229
# Calinksi-Harabaz Index: 1079.6613237010329
# Davies-Bouldin Index: 0.7776765581073123

# %%
first_index = last_index
last_index = int(len(documents.index) / 5 * 4)
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinksi-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4785693287849426
# Calinksi-Harabaz Index: 1275.2718197354347
# Davies-Bouldin Index: 0.7559754844376398

# %%
first_index = last_index
last_index = int(len(documents.index))
documents_test = documents[first_index:last_index]

_, testing_docs, last_indices = doc2vec(documents_test)
_, labels, document_vectors = stream_cluster(vectors, w2v.wv[testing_docs[0]].shape[0], last_indices)

print('Silhouette Coefficient: {}'.format(metrics.silhouette_score(document_vectors, labels)))
print('Calinksi-Harabaz Index: {}'.format(metrics.calinski_harabaz_score(document_vectors, labels)))
print('Davies-Bouldin Index: {}'.format(metrics.davies_bouldin_score(document_vectors, labels)))
# Out:
# Silhouette Coefficient: 0.4626476466655731
# Calinksi-Harabaz Index: 1070.4605617750144
# Davies-Bouldin Index: 0.7888986458392233
